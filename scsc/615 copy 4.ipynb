# %%
from read_data import *
from hyper import *
from alignment import *
from datasets.preprecossing import *

# %%
datas = pd.read_csv("./datas/data1/data_cell.csv").set_index("Unnamed: 0")
datas
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...  CD300LG       CD7  ELN     FCER2  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...      0.0  0.000000  0.0  1.262537
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...      0.0  0.000000  0.0  0.761836
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...      0.0  0.000000  0.0  0.000000
# ...                               ...  ...      ...       ...  ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...      0.0  0.817762  0.0  0.000000
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...      0.0  0.000000  0.0  0.000000
#
#                              KIR2DL1     NELL2  CA4  SOD3  CCL17  FCGR3A
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAAGATGCAGCGAACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACCATGTCCTAGTGA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACTCAGGTGTGACCC      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC      0.0  0.000000  0.0   0.0    0.0     0.0
# ...                              ...       ...  ...   ...    ...     ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGCCCTACAACGCACC      0.0  1.109585  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA      0.0  0.621233  0.0   0.0    0.0     0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ064_CTCATTAGTAAATACG      0.0  0.000000  0.0   0.0    0.0     0.0
#
# [33043 rows x 513 columns]

# %%
celltype  = cell_type1 = pd.read_csv("../../../capital/docs/tutorials/BRCA_EMTAB8107_CellMetainfo_table.tsv",sep="\t")
celltype
# Out:
#                               Cell     UMAP_1    UMAP_2  Cluster  \
# 0      sc5rJUQ024_AAACCTGGTCTCCACT  12.136345 -2.121436        5
# 1      sc5rJUQ024_AAAGATGCAGCGAACA -15.524519 -7.638500        5
# 2      sc5rJUQ024_AACCATGTCCTAGTGA -15.595183 -6.820365        5
# 3      sc5rJUQ024_AACTCAGGTGTGACCC -15.779087 -7.584647        5
# 4      sc5rJUQ024_AAGACCTGTCCGTGAC -14.804107 -7.505053        5
# ...                            ...        ...       ...      ...
# 33038  sc5rJUQ060_TGAGAGGAGTCCTCCT  -7.984505 -1.166239       15
# 33039  sc5rJUQ060_TGCCCTACAACGCACC  -7.716203 -1.429827       15
# 33040  sc5rJUQ060_TGTTCCGAGAGCCCAA  -7.371503 -1.509427       15
# 33041  sc5rJUQ064_AGTTGGTGTGCAGACA -13.337872  0.405348       15
# 33042  sc5rJUQ064_CTCATTAGTAAATACG   2.797375  9.734141       15
#
#       Celltype (malignancy) Celltype (major-lineage) Celltype (minor-lineage)  \
# 0              Immune cells                        B                        B
# 1              Immune cells                        B                        B
# 2              Immune cells                        B                        B
# 3              Immune cells                        B                        B
# 4              Immune cells                        B                        B
# ...                     ...                      ...                      ...
# 33038         Stromal cells                  Tprolif                  Tprolif
# 33039         Stromal cells                  Tprolif                  Tprolif
# 33040         Stromal cells                  Tprolif                  Tprolif
# 33041         Stromal cells                  Tprolif                  Tprolif
# 33042         Stromal cells                  Tprolif                  Tprolif
#
#       Patient    Sample Tissue
# 0         P41  Sample41  Tumor
# 1         P41  Sample41  Tumor
# 2         P41  Sample41  Tumor
# 3         P41  Sample41  Tumor
# 4         P41  Sample41  Tumor
# ...       ...       ...    ...
# 33038     P53  Sample53  Tumor
# 33039     P53  Sample53  Tumor
# 33040     P53  Sample53  Tumor
# 33041     P54  Sample54  Tumor
# 33042     P54  Sample54  Tumor
#
# [33043 rows x 10 columns]

# %%
adata1 = datas.copy()
adata1.loc[list(celltype['Cell']), 'Celltype'] = list(celltype['Celltype (minor-lineage)'])
adata1
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...       CD7  ELN     FCER2  KIR2DL1  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...  0.000000  0.0  1.262537      0.0
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...  0.000000  0.0  0.761836      0.0
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...  0.000000  0.0  0.000000      0.0
# ...                               ...  ...       ...  ...       ...      ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...  0.817762  0.0  0.000000      0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...  0.000000  0.0  0.000000      0.0
#
#                                 NELL2  CA4  SOD3  CCL17  FCGR3A  Celltype
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  0.0   0.0    0.0     0.0         B
# ...                               ...  ...   ...    ...     ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGCCCTACAACGCACC  1.109585  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.621233  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  0.0   0.0    0.0     0.0   Tprolif
#
# [33043 rows x 514 columns]

# %%
from scipy.spatial import KDTree
ans_value = []
ans_label = []
true_label = [];
now_labels = adata1['Celltype'].tolist();
c= -2
r= 7
now_label = 0;
now =  datas.values;
while len(now) != 0:
    rnd = np.random.randint(now.shape[0], size=1);
    rand_choice = now[rnd, :].reshape(-1)
    tree = KDTree(now);
    indices = tree.query_ball_point(rand_choice,r)
    points_within_k = now[indices]
    now = now.tolist();
    if(len(points_within_k)-1 < c):
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now_label +=1
            now.remove(i.tolist());
            true_label.append(now_labels[int(rnd)])
    else:
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now.remove(i.tolist());            
            true_label.append(now_labels[int(rnd)])
        now_label+=1;
    now = np.array(now);
    print("remain length: {}".format(len(now)))
    # for i in points_within_k:
    #     if(i == rand_choice).all():
    #         continue;
        
    # now.remove(rand_choice)
    # now.tolist().remove(rand_choice.tolist())
    # now = np.array(now)
    # break
# rand_choice == now
np.save('./datas/try/c_{}_r_{}_label.npy'.format(c,r),np.array(ans_label))
np.save('./datas/try/c_{}_r_{}_value.npy'.format(c,r),np.array(ans_value))
# Out:
# remain length: 31793
# remain length: 31340
# remain length: 31339
# remain length: 30232
# remain length: 30231
# remain length: 30230
# remain length: 30228
# remain length: 30166
# remain length: 30025
# remain length: 28487
# remain length: 21955
# remain length: 21946
# remain length: 20416
# remain length: 20246
# remain length: 20245
# remain length: 20244
# remain length: 20241
# remain length: 20239
# remain length: 20238
# remain length: 20237
# remain length: 20236
# remain length: 17919
# remain length: 17717
# remain length: 17714
# remain length: 17713
# remain length: 17691
# remain length: 17690
# remain length: 17688
# remain length: 17634
# remain length: 17630
# remain length: 17538
# remain length: 17537
# remain length: 17536
# remain length: 17495
# remain length: 17458
# remain length: 17454
# remain length: 17453
# remain length: 17452
# remain length: 17451
# remain length: 17216
# remain length: 17215
# remain length: 16968
# remain length: 16950
# remain length: 16949
# remain length: 16937
# remain length: 16799
# remain length: 16797
# remain length: 16791
# remain length: 16666
# remain length: 16648
# remain length: 16574
# remain length: 16522
# remain length: 16521
# remain length: 16492
# remain length: 16491
# remain length: 16479
# remain length: 16478
# remain length: 16477
# remain length: 16420
# remain length: 16419
# remain length: 16230
# remain length: 16131
# remain length: 16117
# remain length: 16116
# remain length: 16115
# remain length: 16114
# remain length: 16037
# remain length: 15916
# remain length: 15915
# remain length: 15914
# remain length: 15913
# remain length: 15912
# remain length: 15872
# remain length: 10765
# remain length: 10764
# remain length: 10763
# remain length: 10762
# remain length: 10760
# remain length: 10749
# remain length: 10744
# remain length: 10743
# remain length: 10742
# remain length: 10741
# remain length: 10740
# remain length: 10736
# remain length: 10733
# remain length: 10730
# remain length: 10729
# remain length: 10728
# remain length: 10726
# remain length: 10722
# remain length: 10721
# remain length: 10717
# remain length: 10715
# remain length: 10714
# remain length: 10713
# remain length: 10712
# remain length: 10711
# remain length: 10710
# remain length: 10707
# remain length: 10706
# remain length: 10705
# remain length: 10704
# remain length: 10703
# remain length: 10694
# remain length: 10693
# remain length: 10692
# remain length: 10691
# remain length: 10690
# remain length: 10689
# remain length: 10688
# remain length: 10687
# remain length: 10686
# remain length: 10685
# remain length: 10684
# remain length: 10683
# remain length: 10682
# remain length: 10681
# remain length: 10680
# remain length: 10679
# remain length: 10678
# remain length: 10677
# remain length: 10676
# remain length: 10675
# remain length: 10673
# remain length: 10672
# remain length: 10671
# remain length: 10669
# remain length: 10668
# remain length: 10667
# remain length: 10666
# remain length: 10662
# remain length: 10660
# remain length: 10659
# remain length: 10658
# remain length: 10657
# remain length: 10656
# remain length: 10654
# remain length: 10648
# remain length: 10647
# remain length: 10644
# remain length: 10642
# remain length: 10631
# remain length: 10630
# remain length: 10629
# remain length: 10628
# remain length: 10627
# remain length: 10626
# remain length: 10625
# remain length: 10624
# remain length: 10623
# remain length: 10622
# remain length: 10621
# remain length: 10619
# remain length: 10618
# remain length: 10606
# remain length: 10605
# remain length: 10603
# remain length: 10593
# remain length: 10592
# remain length: 10590
# remain length: 10589
# remain length: 10587
# remain length: 10586
# remain length: 10585
# remain length: 10584
# remain length: 10583
# remain length: 10582
# remain length: 10581
# remain length: 10579
# remain length: 10578
# remain length: 10577
# remain length: 10576
# remain length: 10568
# remain length: 10560
# remain length: 10559
# remain length: 10558
# remain length: 10557
# remain length: 10556
# remain length: 10555
# remain length: 10554
# remain length: 10547
# remain length: 10545
# remain length: 10544
# remain length: 10543
# remain length: 10542
# remain length: 10540
# remain length: 10539
# remain length: 10538
# remain length: 10537
# remain length: 10536
# remain length: 10535
# remain length: 10531
# remain length: 10530
# remain length: 10525
# remain length: 10524
# remain length: 10511
# remain length: 10510
# remain length: 10509
# remain length: 10508
# remain length: 10506
# remain length: 10505
# remain length: 10504
# remain length: 10503
# remain length: 10497
# remain length: 10495
# remain length: 10489
# remain length: 10488
# remain length: 10487
# remain length: 10486
# remain length: 10485
# remain length: 10484
# remain length: 10482
# remain length: 10480
# remain length: 10479
# remain length: 10478
# remain length: 10477
# remain length: 10476
# remain length: 10475
# remain length: 10470
# remain length: 10469
# remain length: 10468
# remain length: 10467
# remain length: 10466
# remain length: 10465
# remain length: 10464
# remain length: 10463
# remain length: 10462
# remain length: 10461
# remain length: 10459
# remain length: 10447
# remain length: 10446
# remain length: 10445
# remain length: 10444
# remain length: 10443
# remain length: 10440
# remain length: 10439
# remain length: 10438
# remain length: 10437
# remain length: 10436
# remain length: 10435
# remain length: 10434
# remain length: 10433
# remain length: 10432
# remain length: 10430
# remain length: 10429
# remain length: 10428
# remain length: 10427
# remain length: 10426
# remain length: 10425
# remain length: 10424
# remain length: 10423
# remain length: 10421
# remain length: 10420
# remain length: 10419
# remain length: 10418
# remain length: 10417
# remain length: 10416
# remain length: 10415
# remain length: 10414
# remain length: 10411
# remain length: 10409
# remain length: 10406
# remain length: 10405
# remain length: 10404
# remain length: 10403
# remain length: 10402
# remain length: 10397
# remain length: 10395
# remain length: 10394
# remain length: 10393
# remain length: 10392
# remain length: 10391
# remain length: 10390
# remain length: 10389
# remain length: 10388
# remain length: 10387
# remain length: 10386
# remain length: 10383
# remain length: 10382
# remain length: 10381
# remain length: 10380
# remain length: 10379
# remain length: 10375
# remain length: 10372
# remain length: 10371
# remain length: 10370
# remain length: 10369
# remain length: 10367
# remain length: 10366
# remain length: 10365
# remain length: 10364
# remain length: 10363
# remain length: 10362
# remain length: 10357
# remain length: 10356
# remain length: 10354
# remain length: 10353
# remain length: 10352
# remain length: 10351
# remain length: 10345
# remain length: 10343
# remain length: 10341
# remain length: 10340
# remain length: 10339
# remain length: 10336
# remain length: 10335
# remain length: 10328
# remain length: 10327
# remain length: 10326
# remain length: 10325
# remain length: 10323
# remain length: 10321
# remain length: 10320
# remain length: 10319
# remain length: 10318
# remain length: 10317
# remain length: 10316
# remain length: 10315
# remain length: 10314
# remain length: 10313
# remain length: 10312
# remain length: 10311
# remain length: 10310
# remain length: 10305
# remain length: 10304
# remain length: 10299
# remain length: 10298
# remain length: 10297
# remain length: 10295
# remain length: 10293
# remain length: 10291
# remain length: 10284
# remain length: 10283
# remain length: 10279
# remain length: 10278
# remain length: 10275
# remain length: 10274
# remain length: 10270
# remain length: 10269
# remain length: 10268
# remain length: 10267
# remain length: 10266
# remain length: 10264
# remain length: 10263
# remain length: 10261
# remain length: 10260
# remain length: 10259
# remain length: 10258
# remain length: 10257
# remain length: 10253
# remain length: 10252
# remain length: 10251
# remain length: 10248
# remain length: 10247
# remain length: 10246
# remain length: 10244
# remain length: 10243
# remain length: 10242
# remain length: 10241
# remain length: 10240
# remain length: 10238
# remain length: 10237
# remain length: 10236
# remain length: 10234
# remain length: 10233
# remain length: 10232
# remain length: 10231
# remain length: 10230
# remain length: 10229
# remain length: 10227
# remain length: 10226
# remain length: 10225
# remain length: 10224
# remain length: 10223
# remain length: 10219
# remain length: 10217
# remain length: 10216
# remain length: 10215
# remain length: 10211
# remain length: 10210
# remain length: 10209
# remain length: 10208
# remain length: 10207
# remain length: 10205
# remain length: 10204
# remain length: 10203
# remain length: 10201
# remain length: 10200
# remain length: 10199
# remain length: 10194
# remain length: 10193
# remain length: 10192
# remain length: 10191
# remain length: 10190
# remain length: 10189
# remain length: 10188
# remain length: 10187
# remain length: 10185
# remain length: 10184
# remain length: 10183
# remain length: 10182
# remain length: 10180
# remain length: 10178
# remain length: 10177
# remain length: 10176
# remain length: 10175
# remain length: 10170
# remain length: 10169
# remain length: 10168
# remain length: 10167
# remain length: 8788
# remain length: 8787
# remain length: 8786
# remain length: 8785
# remain length: 8784
# remain length: 8783
# remain length: 8782
# remain length: 8781
# remain length: 8780
# remain length: 8779
# remain length: 8778
# remain length: 8775
# remain length: 8774
# remain length: 8770
# remain length: 8769
# remain length: 8768
# remain length: 8767
# remain length: 8763
# remain length: 8762
# remain length: 8761
# remain length: 8759
# remain length: 8758
# remain length: 8757
# remain length: 8756
# remain length: 8755
# remain length: 8754
# remain length: 8753
# remain length: 8751
# remain length: 8750
# remain length: 8748
# remain length: 8747
# remain length: 8746
# remain length: 8745
# remain length: 8744
# remain length: 8740
# remain length: 8738
# remain length: 8737
# remain length: 8736
# remain length: 8735
# remain length: 8734
# remain length: 8733
# remain length: 8731
# remain length: 8730
# remain length: 8729
# remain length: 8728
# remain length: 8727
# remain length: 8726
# remain length: 8723
# remain length: 8722
# remain length: 8720
# remain length: 8719
# remain length: 8718
# remain length: 8717
# remain length: 8716
# remain length: 8715
# remain length: 8714
# remain length: 8711
# remain length: 8710
# remain length: 8709
# remain length: 8708
# remain length: 8707
# remain length: 8706
# remain length: 8705
# remain length: 8704
# remain length: 8703
# remain length: 8702
# remain length: 8701
# remain length: 8700
# remain length: 8699
# remain length: 8698
# remain length: 8697
# remain length: 8696
# remain length: 8695
# remain length: 8694
# remain length: 8693
# remain length: 8692
# remain length: 8691
# remain length: 8687
# remain length: 8686
# remain length: 8685
# remain length: 8684
# remain length: 8683
# remain length: 8682
# remain length: 8681
# remain length: 8680
# remain length: 8679
# remain length: 8678
# remain length: 8677
# remain length: 8676
# remain length: 8675
# remain length: 8674
# remain length: 8671
# remain length: 8670
# remain length: 8668
# remain length: 8667
# remain length: 8666
# remain length: 8665
# remain length: 8664
# remain length: 8663
# remain length: 8662
# remain length: 8661
# remain length: 8660
# remain length: 8657
# remain length: 8656
# remain length: 8655
# remain length: 8654
# remain length: 8652
# remain length: 8650
# remain length: 8649
# remain length: 8648
# remain length: 8647
# remain length: 8646
# remain length: 8645
# remain length: 8644
# remain length: 8643
# remain length: 8642
# remain length: 8639
# remain length: 8638
# remain length: 8637
# remain length: 8635
# remain length: 8634
# remain length: 8633
# remain length: 8632
# remain length: 8631
# remain length: 8630
# remain length: 8628
# remain length: 8627
# remain length: 8625
# remain length: 8624
# remain length: 8620
# remain length: 8619
# remain length: 8618
# remain length: 8617
# remain length: 8616
# remain length: 8615
# remain length: 8614
# remain length: 8613
# remain length: 8611
# remain length: 8610
# remain length: 8609
# remain length: 8606
# remain length: 8605
# remain length: 8604
# remain length: 8602
# remain length: 8601
# remain length: 8600
# remain length: 8599
# remain length: 8598
# remain length: 8597
# remain length: 8596
# remain length: 8595
# remain length: 8594
# remain length: 8593
# remain length: 8592
# remain length: 8591
# remain length: 8590
# remain length: 8589
# remain length: 8588
# remain length: 8587
# remain length: 8586
# remain length: 8585
# remain length: 8581
# remain length: 8580
# remain length: 8579
# remain length: 8575
# remain length: 8574
# remain length: 8573
# remain length: 8569
# remain length: 8568
# remain length: 156
# remain length: 155
# remain length: 154
# remain length: 153
# remain length: 152
# remain length: 151
# remain length: 150
# remain length: 149
# remain length: 148
# remain length: 147
# remain length: 146
# remain length: 145
# remain length: 144
# remain length: 143
# remain length: 142
# remain length: 141
# remain length: 140
# remain length: 139
# remain length: 138
# remain length: 137
# remain length: 136
# remain length: 135
# remain length: 134
# remain length: 133
# remain length: 132
# remain length: 131
# remain length: 130
# remain length: 129
# remain length: 128
# remain length: 127
# remain length: 126
# remain length: 125
# remain length: 124
# remain length: 123
# remain length: 122
# remain length: 121
# remain length: 120
# remain length: 119
# remain length: 118
# remain length: 117
# remain length: 116
# remain length: 115
# remain length: 114
# remain length: 113
# remain length: 112
# remain length: 111
# remain length: 110
# remain length: 109
# remain length: 108
# remain length: 107
# remain length: 106
# remain length: 105
# remain length: 104
# remain length: 103
# remain length: 102
# remain length: 101
# remain length: 100
# remain length: 99
# remain length: 98
# remain length: 97
# remain length: 96
# remain length: 95
# remain length: 94
# remain length: 93
# remain length: 92
# remain length: 91
# remain length: 90
# remain length: 89
# remain length: 88
# remain length: 87
# remain length: 86
# remain length: 85
# remain length: 84
# remain length: 83
# remain length: 82
# remain length: 81
# remain length: 80
# remain length: 79
# remain length: 78
# remain length: 77
# remain length: 76
# remain length: 75
# remain length: 74
# remain length: 73
# remain length: 72
# remain length: 71
# remain length: 70
# remain length: 69
# remain length: 68
# remain length: 67
# remain length: 66
# remain length: 65
# remain length: 64
# remain length: 63
# remain length: 62
# remain length: 61
# remain length: 60
# remain length: 59
# remain length: 58
# remain length: 57
# remain length: 56
# remain length: 55
# remain length: 54
# remain length: 53
# remain length: 52
# remain length: 51
# remain length: 50
# remain length: 49
# remain length: 48
# remain length: 47
# remain length: 46
# remain length: 45
# remain length: 44
# remain length: 43
# remain length: 42
# remain length: 41
# remain length: 40
# remain length: 39
# remain length: 38
# remain length: 37
# remain length: 36
# remain length: 35
# remain length: 34
# remain length: 33
# remain length: 32
# remain length: 31
# remain length: 30
# remain length: 29
# remain length: 28
# remain length: 27
# remain length: 26
# remain length: 25
# remain length: 24
# remain length: 23
# remain length: 22
# remain length: 21
# remain length: 20
# remain length: 19
# remain length: 18
# remain length: 17
# remain length: 16
# remain length: 15
# remain length: 14
# remain length: 13
# remain length: 12
# remain length: 11
# remain length: 10
# remain length: 9
# remain length: 8
# remain length: 7
# remain length: 6
# remain length: 5
# remain length: 4
# remain length: 3
# remain length: 2
# remain length: 1
# remain length: 0

# %%
v = pd.DataFrame(ans_value)
v['label'] = ans_label
ann1  = v.groupby("label").mean()

# %%
v1 = pd.DataFrame(true_label)
v1['label'] = ans_label
meta1 = v1.groupby("label").max()

# %%
meta1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 meta1.shape
#
# NameError: name 'meta1' is not defined

# %%
meta1.values
# Out:
# array([['Fibroblasts'],
#        ['CD8Tex'],
#        ['CD8Tcm'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
adata = anndata.AnnData(ann1)
adata.raw = adata
# same as adata = adata[:,adata.var['highly_variable']] but inplace
sc.tl.pca(
    adata,
    n_comps=50
)
sc.pp.neighbors(adata,
                n_neighbors=10,
                n_pcs=50,
                random_state=1234
                )
sc.tl.diffmap(adata,random_state=1234)
sc.tl.umap(adata,random_state=1234)
sc.tl.leiden(adata,random_state=1234)
sc.tl.paga(adata, groups='leiden')
# Out:
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_16141/220074476.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = anndata.AnnData(ann1)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
list(meta1)
# Out:
# [0]

# %%
adata.obs['celltype'] = meta1.values.tolist()

# %%
adata.obs
# Out:
#       leiden       celltype
# label
# 0          9  [Fibroblasts]
# 1          4       [CD8Tex]
# 2          0       [CD8Tcm]
# 3          6    [Malignant]
# 4          0       [CD8Tcm]
# ...      ...            ...
# 10166      6            [B]
# 10167     11            [B]
# 10168      1            [B]
# 10169      1            [B]
# 10170     11            [B]
#
# [10171 rows x 2 columns]

# %%
sc.pl.umap(adata, color="leiden")
# Out:
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
import argparse
import json
import logging
import os
import math
import numpy as np
import torch
import torch.utils.data as data
from tqdm import tqdm

import optim
# from config import config_args
from datasets.hc_dataset import HCDataset
from datasets.loading import load_data
from model.hyphc import HypHC
from utils.metrics import dasgupta_cost
from utils.training import add_flags_from_config, get_savedir

import networkx as nx

import matplotlib.pyplot as plt
from mst import mst

from utils.poincare import project,hyp_dist_djj
from utils.lca import hyp_lca
from utils.math import arctanh, tanh, arcosh

from utils.visualization import plot_tree_from_leaves,plot_geodesic



from utils.lca import hyp_lca

def hyp_lca_numpy(x, y):
    """Computes the hyperbolic LCA in numpy."""
    x = torch.from_numpy(x).view((1, 2))
    y = torch.from_numpy(y).view((1, 2))
    lca = hyp_lca(x, y, return_coord=True)
    return lca.view((2,)).numpy()
def is_leaf(tree, node):
    """check if node is a leaf in tree."""
    return len(list(tree.neighbors(node))) == 0
def complete_tree(tree, leaves_embeddings):
    """Get embeddings of internal nodes from leaves' embeddings using LCA construction."""

    def _complete_tree(embeddings, node):
        children = list(tree.neighbors(node))
        if len(children) == 2:
            left_c, right_c = children
            left_leaf = is_leaf(tree, left_c)
            right_leaf = is_leaf(tree, right_c)
            if left_leaf and right_leaf:
                pass
            elif left_leaf and not right_leaf:
                embeddings = _complete_tree(embeddings, right_c)
            elif right_leaf and not left_leaf:
                embeddings = _complete_tree(embeddings, left_c)
            else:
                embeddings = _complete_tree(embeddings, right_c)
                embeddings = _complete_tree(embeddings, left_c)
            embeddings[node] = hyp_lca_numpy(embeddings[left_c], embeddings[right_c])
        return embeddings

    n = leaves_embeddings.shape[0]
    tree_embeddings = np.zeros((2 * n - 1, 2))
    tree_embeddings[:n, :] = leaves_embeddings
    root = max(list(tree.nodes()))
    tree_embeddings = _complete_tree(tree_embeddings, root)
    return tree_embeddings
def train(model,dataloader,optimizer,similarities,epoches):
    best_cost = np.inf
    best_model = None
    counter = 0
    for epoch in range(epoches):
        model.train()
    total_loss = 0.0
    with tqdm(total=len(dataloader), unit='ex') as bar:
        for step, (triple_ids, triple_similarities) in enumerate(dataloader):
            # triple_ids = triple_ids.cuda()
            # triple_similarities = triple_similarities.cuda()
            loss = model.loss(triple_ids, triple_similarities)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            bar.update(1)
            bar.set_postfix(loss=f'{loss.item():.6f}')
            total_loss += loss
    total_loss = total_loss.item() / (step + 1.0)
    print("\t Epoch {} | average train loss: {:.6f}".format(epoch, total_loss))

    # keep best embeddings
    if (epoch + 1) % 1 == 0:
        tree = model.decode_tree(fast_decoding=1)
        cost = dasgupta_cost(tree, similarities)
        logging.info("{}:\t{:.4f}".format("Dasgupta's cost", cost))
        if cost < best_cost:
            counter = 0
            best_cost = cost
            best_model = model.state_dict()
        else:
            counter += 1
            if counter == 20:
#                 logging.info("Early stopping.")
                return

    # anneal temperature
    if (epoch + 1) % 30 == 0:
        model.anneal_temperature(0.5)
#         logging.info("Annealing temperature to: {}".format(model.temperature))
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.5
            lr = param_group['lr']
        print("Annealing learning rate to: {}".format(lr))

    print("Optimization finished.")
    if best_model is not None:
        # load best model
        model.load_state_dict(best_model)
def dist(x,y):
    return arcosh(1+ 2*( (x-y).norm(dim=-1, p=2, keepdim=True))/((1- y.norm(dim=-1, p=2, keepdim=True))*(1- x.norm(dim=-1, p=2, keepdim=True))));
def plot_tree_from_leaves_djj_1(ax, tree, leaves_embeddings, labels, color_seed=1234):
    """Plots a tree on leaves embeddings using the LCA construction."""
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)
    n = leaves_embeddings.shape[0]
    embeddings = complete_tree(tree, leaves_embeddings)
    colors = get_colors(labels, color_seed)
    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)
    
    for n1, n2 in tree.edges():
        x1 = embeddings[n1]
        x2 = embeddings[n2]
        plot_geodesic(x1, x2, ax)
    # ax.set_xlim(-1.05, 1.05)
    # ax.set_ylim(-1.05, 1.05)
    ax.axis("off")
    return ax
def sl_np_mst_ij(xs, S):
    xs = project(xs).detach().cpu()

    xs0 = xs[None, :, :]
    xs1 = xs[:, None, :]
    sim_mat = S(xs0, xs1)  # (n, n)
    similarities = sim_mat.numpy()
    n = similarities.shape[0]
    similarities=similarities.astype('double')
    ij, _ = mst.mst(similarities, n)
    return ij
class  UnionFind:
    
    def __init__(self, n , pos , c):
        self.n = n
        self.pos = pos
        self.c = c
        self.parent = [i for i in range(n)]
        self.rank = [0 for i in range(n)]
        self.vis = [0 for i in range(2*n-1)]
        self.vis2 = [0 for i in range(2*n-1)]
        self.mer = [-1 for i in range(2*n-1)]
        self._next_id = n
        self._tree = [-1 for i in range(2*n-1)]

        self._id = [i for i in range(n)]

    def _find(self, i):
        if self.parent[i] == i:
            return i
        else:
            self.parent[i] = self._find(self.parent[i])
            return self.parent[i]

    def find(self, i):
        if (i < 0) or (i > self.n):
            raise ValueError("Out of bounds index.")
        return self._find(i)

    def union(self,  i,  j, k=True):
        root_i = self._find(i)
        root_j = self._find(j)
        if root_i == root_j:
            return False
        else:
            
            if self.rank[root_i] < self.rank[root_j]:
                self.parent[root_i] = root_j
                if(k):
                    self._build(root_j, root_i)
                
            elif self.rank[root_i] > self.rank[root_j]:
                self.parent[root_j] = root_i
                if(k):
                    self._build(root_i, root_j)
                
            else:
                
                self.parent[root_j] = root_i
                self.rank[root_i] += 1
                if(k):
                    self._build(root_i, root_j)
                
            return True


    def merge(self,ij):
        for k in range(ij.shape[0]):
            a=ij[k,0];
            b=ij[k,1];
            if(self.mer[a]!=-1):
                a=self.mer[a];
            if(self.mer[b]!=-1):
                b=self.mer[b];
            self.union(a, b)

    def  _build(self, i, j):
#         print(self._tree[0],"----")
#         if(dist(self.pos[self._id[i]],self.pos[self._id[j]])<self.c):
            
            
#             print(i,j,'-',self._id[i],self._id[j]);
#             self.vis[self._id[i]]=1;
#             self.vis[self._id[j]]=1;
                
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self.pos[self._id[i]] = torch.tensor(new);
#             self.pos[self._id[j]] = torch.tensor(new);
            
#             self.search(self._id[i]);
#             self.search(self._id[j]);

#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
            
#         else:
            
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
        self.vis2[i]=1;
        self.vis2[j]=1;
        
        t=np.array(self.pos).tolist()
        new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
        t.append(new);
        self.pos=torch.tensor(t)
        
        self._tree[self._id[i]] = self._next_id
        self._tree[self._id[j]] = self._next_id
        self._id[i] = self._next_id
        self.check(i);
        self._next_id += 1

    def search(self,k):
#         for i in range(len(self.parent)):
#             if(self.parent[i]==k):
#                 self.parent[i]=self._next_id;
#         print(k==-1)

        for i in range(len(self._tree)):
            if(self.vis[i]):
                continue;            
            if(self._tree[i]==k):
                # print("sear")
                self._tree[i]=self._next_id;  
                
        for i in range(len(self._id)):
            if(self.vis[i]):
                continue;
            if(self._id[i]==k):
                # print("Sear")
                self._id[i]=self._next_id;  
                
    def check(self,t):
        minnum=math.inf
        minns=None;
        for i in range(self.n):
            if(self.vis[i] or self.vis2[i]):
                continue;
            distance = dist(self.pos[i],self.pos[-1]);
            if(distance<self.c and distance < minnum):
                minnum = distance
                minns = i;
                
#                 print("merge {} in {}".format(i,t))
#                 self.parent[i]=t;
#                 self.vis[i]=1;
#                 self.search(i);
        if(minns != None):
            # print("merge {} in {}".format(minns,self._next_id))
            self.vis[minns]=1;
            self.rank[minns]=-1;
            self.pos[minns] = self.pos[-1]
#             self.search(minns);
            self.mer[minns]=t;
            self.mer[self._next_id] = minns;
#             self.union(t,minns,False);
        
    def parent(self):
        return [self.parent[i] for i in range(self.n)]

    def tree(self):
        return [self._tree[i] for i in range(len(self._tree))]
def get_colors(y, color_seed=1234):
    """random color assignment for label classes."""
    np.random.seed(color_seed)
    colors = {}
    for k in np.unique(y):
        r = np.random.random()
        b = np.random.random()
        g = np.random.random()
        colors[k] = (r, g, b)
    return [colors[k] for k in y]


def get_Hyper_tree(data_path,start,end,lable,epoches,model_path=None,save_path='./',c=-1):
    np.random.seed(1234)
    torch.manual_seed(1234)
    # x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
    x, y_true, similarities = load_data(data_path,start,end,lable)
    print("{} length:{}".format(data_path,len(y_true)));
    dataset = HCDataset(x, y_true, similarities, num_samples=50000)
    dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
    if(model_path ==None):
        model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
        model.to("cpu")
        Optimizer = getattr(optim, 'RAdam')
        optimizer = Optimizer(model.parameters(),0.0005)
        train(model,dataloader,optimizer,similarities,epoches);
        torch.save(model,save_path+'model.pth');
    else:
        params = torch.load((model_path), map_location=torch.device('cpu'))
        model.load_state_dict(params, strict=False)
    model.eval()
    sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
    n=len(x);
    d = model.normalize_embeddings(model.embeddings.weight.data)
    d = project(d).detach().cpu()
    ijs = sl_np_mst_ij(d,sim_fn)
    uf = UnionFind(n,d,c)
    uf.merge(ijs)
    count=0

    tree = nx.DiGraph()
    for i, j in enumerate(uf.tree()[:-1]):
        if(j!=-1):
            tree.add_edge(j, i)
            
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(111)
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)

    n = len(d)
    embeddings = np.array(uf.pos)
    # for i in range(len(embeddings)):
    #     if(np.isnan(embeddings[i][0]) or embeddings[i][0] + embeddings[i][1] == 0):
    #         embeddings[i] = embeddings[i-1];
    #     pass;
    # print(embeddings)
    where_are_NaNs = np.isnan(embeddings)
    embeddings[where_are_NaNs] = 0
    vis = uf.vis
    # xlist=[]
    # ylist=[]
    # labels=[]

    # for i in range(n):
    #     if(uf.vis[i]!=1):
    #         xlist.append(embeddings[i,0]*20);
    #         ylist.append(embeddings[i,1]*20);
    #         labels.append(y_true[i]);
    # # colors = get_colors(labels, 1234)
    colors = get_colors(y_true, 1234)

    # ax.scatter(xlist, ylist, c=colors, s=50, alpha=0.6)

    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)

    for i in range(len(embeddings)):
        if(i<n):
            continue;
        if(uf.mer[i]!=-1):
            # print(i,'pass')
            pass;
        else:
            ax.scatter(embeddings[i][0]*20,embeddings[i][1]*20,color='black',s=20,alpha=0.7)

        

    for n1, n2 in tree.edges():
    #     if(uf.vis[n1]== 1 or uf.vis[n2]== 1 ):
    # #         print("1")
    #         pass
    #     else:
    #         x1 = embeddings[n1]
    #         x2 = embeddings[n2]
    # #         if(n1>=n):
    # #             if(uf.mer[n1]!=-1):
    # #                 pass;
    # #             else:
    # #                 count+=1;
    # #         if(n2>n):
    # #             if(uf.mer[n1]!=-1):
    # # # 
    # #                 pass;
    # #             else:
    # # #                 ax.scatter(x2[0]*20,x2[1]*20,color='black',s=20,alpha=0.7)
    # #                 count+=1
        
        
    #         plot_geodesic(x1, x2, ax)
    # #         print(x1,x2,n1,n2)
    # #         break
    #         pass

    #     ax.axis("off")
        x1 = embeddings[n1];
        x2 = embeddings[n2];
        plot_geodesic(x1,x2,ax)
    fig.savefig(save_path+"graph.png");
    np.save(save_path+"dataxy.npy",embeddings)
    np.save(save_path+"datalink.npy",list(tree.edges()))
    np.save(save_path+"datamerge.npy",uf.mer)

# %%
def cccfg(
        adata,
        gene_list,
        save_path="./",
    ):
    groupby = adata.uns["capital"]["tree"]["annotation"]
    filtered_data = adata.raw.to_adata()[:]
    filtered_data.to_df().to_csv(save_path+"data_cell.csv");
    adata.obs.to_csv(save_path+"data_type.csv")
    cluster_centroid_data = np.empty((0, filtered_data.n_vars))
    clustername = filtered_data.obs[groupby].unique().tolist()

    for i in clustername:
        a_cluster_data = filtered_data[filtered_data.obs[groupby] == "{}".format(
            i)].to_df()
        a_cluster_median = a_cluster_data.mean(axis=0).values
        cluster_centroid_data = np.vstack(
            (cluster_centroid_data, a_cluster_median)
        )
    cluster_centroid = pd.DataFrame(
        cluster_centroid_data,
        index=clustername,
        columns=filtered_data.var_names
    )
    cluster_centroid.to_csv(save_path+"datas.data",header=None);
    cluster_centroid.to_csv(save_path+"datas.csv");

    return cluster_centroid

# %%
set_initial_condition(adata)

# %%
cccfg(adata,'','./datas/merge5/')
# Out:
#          0         1         2         3         4         5             6    \
# 9   0.364415  0.000015  0.260051  0.147307  0.007031  0.003826  9.858546e-07
# 4   0.037136  0.032675  0.001431  0.974320  0.057658  0.001735  2.058439e-03
# 0   0.033441  0.068966  0.004831  0.720919  0.056275  0.002486  3.669101e-03
# 6   0.426171  0.030765  0.034321  0.773498  0.039597  0.002141  2.276581e-03
# 5   0.054386  0.070300  0.004760  0.482020  0.115914  0.000028  0.000000e+00
# 2   0.065348  0.123151  0.005716  0.249150  0.101490  0.008705  0.000000e+00
# 1   0.038906  0.166540  0.010188  0.144945  0.106879  0.003175  0.000000e+00
# 8   0.038386  0.011392  0.011656  1.537789  0.197932  0.008505  0.000000e+00
# 14  0.117218  0.005626  0.008197  0.452494  0.048476  0.000183  0.000000e+00
# 13  0.822098  0.001066  0.919238  0.133041  0.017571  0.000019  4.385418e-03
# 3   0.046240  0.085839  0.005184  0.252513  0.110252  0.001854  4.146107e-02
# 10  0.050080  0.004895  0.006109  0.345652  0.137248  0.003836  8.970802e-02
# 7   0.065682  0.179783  0.009617  0.535879  0.081672  0.000010  1.007366e-04
# 12  0.026437  0.034814  0.006872  0.407633  0.047044  0.005254  2.248690e-02
# 11  0.153454  0.035972  0.002568  0.808953  0.040087  0.000000  7.901345e-03
# 15  0.146623  0.000000  0.300967  0.153352  0.000000  0.000000  0.000000e+00
#
#          7         8         9    ...       503       504       505       506  \
# 9   0.131506  0.000001  0.005009  ...  0.000689  0.021768  0.203657  0.000001
# 4   0.018386  0.009732  0.132961  ...  0.000737  1.058752  0.001031  0.000000
# 0   0.040193  0.017476  0.078156  ...  0.000000  0.519447  0.001921  0.000032
# 6   0.131713  0.000080  0.041442  ...  0.074517  0.164194  0.047203  0.003992
# 5   0.040597  0.039625  0.140419  ...  0.001234  0.844546  0.002547  0.000000
# 2   0.071229  0.018079  0.207109  ...  0.001235  0.452753  0.001426  0.000691
# 1   0.039787  0.035906  0.246336  ...  0.000000  0.624039  0.001720  0.000000
# 8   0.139115  0.002978  0.031464  ...  0.002859  0.014681  0.005670  0.370006
# 14  0.311551  0.001895  0.020433  ...  0.000000  0.110031  0.024046  0.005987
# 13  0.048081  0.000000  0.014516  ...  0.000868  0.179278  0.424835  0.000047
# 3   0.050031  0.015445  0.144443  ...  0.001283  1.132517  0.003488  0.000000
# 10  0.041293  0.002658  0.120390  ...  0.000000  1.301750  0.000000  0.000000
# 7   0.078233  0.029561  0.222507  ...  0.000000  0.639902  0.000000  0.000000
# 12  0.019295  0.000000  0.088489  ...  0.000000  0.851486  0.000000  0.000000
# 11  0.254475  0.054830  0.066652  ...  0.000000  0.546679  0.008076  0.000000
# 15  0.158171  0.000000  0.000000  ...  0.289419  0.000000  0.064181  0.000000
#
#          507       508       509       510       511       512
# 9   0.000000  0.003334  0.008678  0.315406  0.000002  0.029915
# 4   0.007544  0.223187  0.000940  0.006532  0.000000  0.008868
# 0   0.001520  0.207136  0.001260  0.006019  0.000012  0.023990
# 6   0.000000  0.020061  0.031643  0.129569  0.004580  0.155253
# 5   0.000000  0.039963  0.002741  0.016569  0.000000  0.001676
# 2   0.000000  0.269413  0.000000  0.025739  0.000107  0.006866
# 1   0.000000  0.237154  0.000532  0.003977  0.000002  0.003176
# 8   0.000000  0.007432  0.002304  0.013903  0.003338  0.002799
# 14  0.000000  0.018464  0.000000  0.060447  0.000000  0.022451
# 13  0.000000  0.035336  0.000000  0.735509  0.008427  0.013994
# 3   0.028444  0.392780  0.002006  0.016264  0.000000  0.011348
# 10  0.042691  0.035372  0.000000  0.012177  0.000207  0.280742
# 7   0.000071  0.280773  0.000000  0.034875  0.000000  0.012014
# 12  0.013856  0.095850  0.000000  0.003392  0.000000  0.213912
# 11  0.002486  0.130353  0.000000  0.089644  0.000000  0.016705
# 15  0.000000  0.000000  0.235459  1.179871  0.000000  0.000000
#
# [16 rows x 513 columns]

# %%
x
# Out:
# array([[5.0428920062e-02, 2.0177977684e-06, 3.5986670705e-02, ...,
#         4.3646897126e-02, 2.3987760223e-07, 4.1397575551e-03],
#        [4.8530019204e-03, 4.2699414616e-03, 1.8697615895e-04, ...,
#         8.5358240273e-04, 0.0000000000e+00, 1.1588570151e-03],
#        [4.6578596709e-03, 9.6060633466e-03, 6.7289880304e-04, ...,
#         8.3833323753e-04, 1.6105458900e-06, 3.3414638071e-03],
#        ...,
#        [3.8098781041e-03, 5.0169941806e-03, 9.9030137916e-04, ...,
#         4.8877188800e-04, 0.0000000000e+00, 3.0826833695e-02],
#        [2.1586245796e-02, 5.0601391132e-03, 3.6123290470e-04, ...,
#         1.2610122228e-02, 0.0000000000e+00, 2.3498947166e-03],
#        [1.7938259164e-02, 0.0000000000e+00, 3.6821005584e-02, ...,
#         1.4434843719e-01, 0.0000000000e+00, 0.0000000000e+00]])

# %%
x, y_true, similarities = load_data('./datas/merge5/datas.data',1,514,0)
data_path = './datas/merge5/datas.data'
start = 1
end =514
lable = 0
model_path = None;
save_path = './datas/merge5/'
epoches=10
c=-1
np.random.seed(1234)
torch.manual_seed(1234)
# x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
x, y_true, similarities = load_data(data_path,start,end,lable)
print("{} length:{}".format(data_path,len(y_true)));
dataset = HCDataset(x, y_true, similarities, num_samples=50000)
dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
if(model_path ==None):
    model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
    model.to("cpu")
    Optimizer = getattr(optim, 'RAdam')
    optimizer = Optimizer(model.parameters(),0.0005)
    train(model,dataloader,optimizer,similarities,epoches);
    torch.save(model,save_path+'model.pth');
else:
    params = torch.load((model_path), map_location=torch.device('cpu'))
    model.load_state_dict(params, strict=False)
model.eval()
sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
n=len(x);
d = model.normalize_embeddings(model.embeddings.weight.data)
d = project(d).detach().cpu()
ijs = sl_np_mst_ij(d,sim_fn)
uf = UnionFind(n,d,c)
uf.merge(ijs)
count=0
# Out:
# ./datas/merge5/datas.data length:16
# Generating all pairs superset
# 100%|██████████| 1563/1563 [01:02<00:00, 24.94ex/s, loss=1.483952]
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_77525/836080252.py:147: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ij, _ = mst.mst(similarities, n)
# 	 Epoch 9 | average train loss: 1.525008
# Optimization finished.

# %%
from alignment import node
from alignment import show_tree
embeddings = np.array(uf.pos)

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break

# %%
def search_tree(now,c):
    
    if(len(now.son) != 2):
        return now;
    lson = search_tree(now.son[0],c);
    now.son[0] = lson;
    rson = search_tree(now.son[1],c);
    now.son[1] = rson
    # lson = now.son[0]
    # rson = now.son[1]
    if(np.linalg.norm(lson.value-rson.value)<=c):
        if(len(lson.son)>1 and len(rson.son)>1):
            pass
        elif(len(lson.son)>1):
            print(rson.name,lson.name)
            now = rson;
            now.son.append(lson);
        else:
            print(rson.name,lson.name)
            now = lson;
            now.son.append(rson)
    # exit(0)
    return now;

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break
show_tree(nodes1[-1]).show_fig()

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break
show_tree(nodes1[-1]).show_fig()

root  = search_tree(nodes1[-1],0.002)
show_tree(root).show_fig()
# Out:
# 15 3

# %%
values = [];
fathers = [];
save_path = "./datas/merge5/"
def search_merge_tree(now,ids,save_path,values,fathers):
    fathers.append(ids);
    values.append(now.name);
    now_id = len(values)-1;
    for son in now.son:
        search_merge_tree(son,now_id,save_path,values,fathers)
search_merge_tree(root,-1,0,values,fathers)
np.save(save_path+"dataxy.npy",values)
np.save(save_path+"datalink.npy",fathers)

# %%
fathers
# Out:
# [-1,
#  0,
#  1,
#  2,
#  2,
#  4,
#  5,
#  1,
#  7,
#  7,
#  0,
#  10,
#  10,
#  12,
#  12,
#  14,
#  14,
#  16,
#  17,
#  17,
#  16,
#  20,
#  20,
#  22,
#  22,
#  24,
#  24,
#  26]

# %%
np.save(save_path+"datamerge.npy",uf.mer)

# %%
nodes1[-1].son
# Out:
# [7, 13]

# %%
adata.obs.groupby('leiden').max()
# Out:
#              celltype
# leiden
# 0            [CD8Tex]
# 1            [CD8Tex]
# 2            [CD8Tex]
# 3            [CD8Tex]
# 4       [Fibroblasts]
# 5            [CD8Tex]
# 6         [Malignant]
# 7            [CD8Tex]
# 8            [CD8Tcm]
# 9       [Fibroblasts]
# 10           [CD8Tex]
# 11           [CD8Tex]
# 12           [CD8Tex]
# 13      [Endothelial]
# 14      [Fibroblasts]
# 15           [CD8Tex]

# %%
adata.obs
# Out:
#       leiden       celltype
# label
# 0          9  [Fibroblasts]
# 1          4       [CD8Tex]
# 2          0       [CD8Tcm]
# 3          6    [Malignant]
# 4          0       [CD8Tcm]
# ...      ...            ...
# 10166      6            [B]
# 10167     11            [B]
# 10168      1            [B]
# 10169      1            [B]
# 10170     11            [B]
#
# [10171 rows x 2 columns]

# %%
15 3
3 8
8 7
9 0
0 7
14 12
5 4
4 2
2 10

# %%
ann1.to_csv("./datas/merge5/ann1.csv")
meta1.to_csv("./datas/merge5/meta1.csv")
