# %%
from read_data import *
from hyper import *
from alignment import *
from datasets.preprecossing import *

# %%
datas = pd.read_csv("./datas/data1/data_cell.csv").set_index("Unnamed: 0")
datas
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...  CD300LG       CD7  ELN     FCER2  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...      0.0  0.000000  0.0  1.262537
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...      0.0  0.000000  0.0  0.761836
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...      0.0  0.000000  0.0  0.000000
# ...                               ...  ...      ...       ...  ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...      0.0  0.817762  0.0  0.000000
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...      0.0  0.000000  0.0  0.000000
#
#                              KIR2DL1     NELL2  CA4  SOD3  CCL17  FCGR3A
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAAGATGCAGCGAACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACCATGTCCTAGTGA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACTCAGGTGTGACCC      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC      0.0  0.000000  0.0   0.0    0.0     0.0
# ...                              ...       ...  ...   ...    ...     ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGCCCTACAACGCACC      0.0  1.109585  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA      0.0  0.621233  0.0   0.0    0.0     0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ064_CTCATTAGTAAATACG      0.0  0.000000  0.0   0.0    0.0     0.0
#
# [33043 rows x 513 columns]

# %%
celltype  = cell_type1 = pd.read_csv("../../../capital/docs/tutorials/BRCA_EMTAB8107_CellMetainfo_table.tsv",sep="\t")
celltype
# Out:
#                               Cell     UMAP_1    UMAP_2  Cluster  \
# 0      sc5rJUQ024_AAACCTGGTCTCCACT  12.136345 -2.121436        5
# 1      sc5rJUQ024_AAAGATGCAGCGAACA -15.524519 -7.638500        5
# 2      sc5rJUQ024_AACCATGTCCTAGTGA -15.595183 -6.820365        5
# 3      sc5rJUQ024_AACTCAGGTGTGACCC -15.779087 -7.584647        5
# 4      sc5rJUQ024_AAGACCTGTCCGTGAC -14.804107 -7.505053        5
# ...                            ...        ...       ...      ...
# 33038  sc5rJUQ060_TGAGAGGAGTCCTCCT  -7.984505 -1.166239       15
# 33039  sc5rJUQ060_TGCCCTACAACGCACC  -7.716203 -1.429827       15
# 33040  sc5rJUQ060_TGTTCCGAGAGCCCAA  -7.371503 -1.509427       15
# 33041  sc5rJUQ064_AGTTGGTGTGCAGACA -13.337872  0.405348       15
# 33042  sc5rJUQ064_CTCATTAGTAAATACG   2.797375  9.734141       15
#
#       Celltype (malignancy) Celltype (major-lineage) Celltype (minor-lineage)  \
# 0              Immune cells                        B                        B
# 1              Immune cells                        B                        B
# 2              Immune cells                        B                        B
# 3              Immune cells                        B                        B
# 4              Immune cells                        B                        B
# ...                     ...                      ...                      ...
# 33038         Stromal cells                  Tprolif                  Tprolif
# 33039         Stromal cells                  Tprolif                  Tprolif
# 33040         Stromal cells                  Tprolif                  Tprolif
# 33041         Stromal cells                  Tprolif                  Tprolif
# 33042         Stromal cells                  Tprolif                  Tprolif
#
#       Patient    Sample Tissue
# 0         P41  Sample41  Tumor
# 1         P41  Sample41  Tumor
# 2         P41  Sample41  Tumor
# 3         P41  Sample41  Tumor
# 4         P41  Sample41  Tumor
# ...       ...       ...    ...
# 33038     P53  Sample53  Tumor
# 33039     P53  Sample53  Tumor
# 33040     P53  Sample53  Tumor
# 33041     P54  Sample54  Tumor
# 33042     P54  Sample54  Tumor
#
# [33043 rows x 10 columns]

# %%
adata1 = datas.copy()
adata1.loc[list(celltype['Cell']), 'Celltype'] = list(celltype['Celltype (minor-lineage)'])
adata1
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...       CD7  ELN     FCER2  KIR2DL1  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...  0.000000  0.0  1.262537      0.0
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...  0.000000  0.0  0.761836      0.0
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...  0.000000  0.0  0.000000      0.0
# ...                               ...  ...       ...  ...       ...      ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...  0.817762  0.0  0.000000      0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...  0.000000  0.0  0.000000      0.0
#
#                                 NELL2  CA4  SOD3  CCL17  FCGR3A  Celltype
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  0.0   0.0    0.0     0.0         B
# ...                               ...  ...   ...    ...     ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGCCCTACAACGCACC  1.109585  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.621233  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  0.0   0.0    0.0     0.0   Tprolif
#
# [33043 rows x 514 columns]

# %%
from scipy.spatial import KDTree
ans_value = []
ans_label = []
true_label = [];
now_labels = adata1['Celltype'].tolist();
c= -2
r= 5
now_label = 0;
now =  datas.values;
while len(now) != 0:
    rnd = np.random.randint(now.shape[0], size=1);
    rand_choice = now[rnd, :].reshape(-1)
    tree = KDTree(now);
    indices = tree.query_ball_point(rand_choice,r)
    points_within_k = now[indices]
    now = now.tolist();
    if(len(points_within_k)-1 < c):
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now_label +=1
            now.remove(i.tolist());
            true_label.append(now_labels[int(rnd)])
    else:
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now.remove(i.tolist());            
            true_label.append(now_labels[int(rnd)])
        now_label+=1;
    now = np.array(now);
    print("remain length: {}".format(len(now)))
    # for i in points_within_k:
    #     if(i == rand_choice).all():
    #         continue;
        
    # now.remove(rand_choice)
    # now.tolist().remove(rand_choice.tolist())
    # now = np.array(now)
    # break
# rand_choice == now
np.save('./datas/try/c_{}_r_{}_label.npy'.format(c,r),np.array(ans_label))
np.save('./datas/try/c_{}_r_{}_value.npy'.format(c,r),np.array(ans_value))
# Out:
# remain length: 33042
# remain length: 28542
# remain length: 28541
# remain length: 28540
# remain length: 28539
# remain length: 28332
# remain length: 28322
# remain length: 28321
# remain length: 28320
# remain length: 28319
# remain length: 28179
# remain length: 28178
# remain length: 27244
# remain length: 27243
# remain length: 26958
# remain length: 26957
# remain length: 26956
# remain length: 26955
# remain length: 26909
# remain length: 24865
# remain length: 24864
# remain length: 24860
# remain length: 24859
# remain length: 24858
# remain length: 24857
# remain length: 24856
# remain length: 24855
# remain length: 24854
# remain length: 24853
# remain length: 24213
# remain length: 24212
# remain length: 24211
# remain length: 24210
# remain length: 24209
# remain length: 23973
# remain length: 23972
# remain length: 23971
# remain length: 23970
# remain length: 23969
# remain length: 23968
# remain length: 23886
# remain length: 23885
# remain length: 23849
# remain length: 23848
# remain length: 23847
# remain length: 23846
# remain length: 23845
# remain length: 23844
# remain length: 23843
# remain length: 23842
# remain length: 23827
# remain length: 23826
# remain length: 23756
# remain length: 23684
# remain length: 23683
# remain length: 23682
# remain length: 23681
# remain length: 23680
# remain length: 23475
# remain length: 23474
# remain length: 23473
# remain length: 23468
# remain length: 23467
# remain length: 23466
# remain length: 23465
# remain length: 23464
# remain length: 23463
# remain length: 23462
# remain length: 23461
# remain length: 23460
# remain length: 23455
# remain length: 23454
# remain length: 23453
# remain length: 23452
# remain length: 23451
# remain length: 23450
# remain length: 23449
# remain length: 23448
# remain length: 23447
# remain length: 23446
# remain length: 23445
# remain length: 23444
# remain length: 20749
# remain length: 20748
# remain length: 20747
# remain length: 20746
# remain length: 20745
# remain length: 20744
# remain length: 20743
# remain length: 20742
# remain length: 20741
# remain length: 20740
# remain length: 20730
# remain length: 20729
# remain length: 20728
# remain length: 20725
# remain length: 20724
# remain length: 20723
# remain length: 20722
# remain length: 20721
# remain length: 20720
# remain length: 20719
# remain length: 20718
# remain length: 20717
# remain length: 20716
# remain length: 20715
# remain length: 20714
# remain length: 20713
# remain length: 20712
# remain length: 20710
# remain length: 20709
# remain length: 20695
# remain length: 20694
# remain length: 20693
# remain length: 20649
# remain length: 20647
# remain length: 20646
# remain length: 20645
# remain length: 20644
# remain length: 20643
# remain length: 20642
# remain length: 20641
# remain length: 20640
# remain length: 20639
# remain length: 20638
# remain length: 20637
# remain length: 20636
# remain length: 20635
# remain length: 20634
# remain length: 20633
# remain length: 20632
# remain length: 20631
# remain length: 20629
# remain length: 20623
# remain length: 20622
# remain length: 20621
# remain length: 20620
# remain length: 20619
# remain length: 20618
# remain length: 20617
# remain length: 20614
# remain length: 20612
# remain length: 20611
# remain length: 20610
# remain length: 20609
# remain length: 20608
# remain length: 20607
# remain length: 20596
# remain length: 20595
# remain length: 20592
# remain length: 20591
# remain length: 20590
# remain length: 20589
# remain length: 20588
# remain length: 20587
# remain length: 20586
# remain length: 20585
# remain length: 20584
# remain length: 20583
# remain length: 20582
# remain length: 20581
# remain length: 20580
# remain length: 20579
# remain length: 20578
# remain length: 20577
# remain length: 20576
# remain length: 20575
# remain length: 20574
# remain length: 20573
# remain length: 20572
# remain length: 20558
# remain length: 20557
# remain length: 20551
# remain length: 20539
# remain length: 20538
# remain length: 20537
# remain length: 20536
# remain length: 20535
# remain length: 20534
# remain length: 20533
# remain length: 20532
# remain length: 20528
# remain length: 20527
# remain length: 20526
# remain length: 20525
# remain length: 20524
# remain length: 20523
# remain length: 20522
# remain length: 20521
# remain length: 20520
# remain length: 20519
# remain length: 20518
# remain length: 20517
# remain length: 20516
# remain length: 20515
# remain length: 20514
# remain length: 20513
# remain length: 20512
# remain length: 20511
# remain length: 20506
# remain length: 20505
# remain length: 20504
# remain length: 20503
# remain length: 20502
# remain length: 20501
# remain length: 20500
# remain length: 20499
# remain length: 20496
# remain length: 20495
# remain length: 20494
# remain length: 20492
# remain length: 20491
# remain length: 20490
# remain length: 20489
# remain length: 20488
# remain length: 20486
# remain length: 20485
# remain length: 20478
# remain length: 20477
# remain length: 20476
# remain length: 20475
# remain length: 20474
# remain length: 20473
# remain length: 20472
# remain length: 20471
# remain length: 20470
# remain length: 20468
# remain length: 20464
# remain length: 20463
# remain length: 20462
# remain length: 20442
# remain length: 20441
# remain length: 20440
# remain length: 20439
# remain length: 20438
# remain length: 20437
# remain length: 20436
# remain length: 20435
# remain length: 20434
# remain length: 20433
# remain length: 20432
# remain length: 20431
# remain length: 20430
# remain length: 20429
# remain length: 20426
# remain length: 20425
# remain length: 20424
# remain length: 20423
# remain length: 20422
# remain length: 20420
# remain length: 20419
# remain length: 20418
# remain length: 20417
# remain length: 20416
# remain length: 20415
# remain length: 20414
# remain length: 20413
# remain length: 20412
# remain length: 20411
# remain length: 20410
# remain length: 20400
# remain length: 20399
# remain length: 20398
# remain length: 20397
# remain length: 20396
# remain length: 20395
# remain length: 20394
# remain length: 20390
# remain length: 20389
# remain length: 20388
# remain length: 20387
# remain length: 20386
# remain length: 20385
# remain length: 20384
# remain length: 20383
# remain length: 20382
# remain length: 20381
# remain length: 20378
# remain length: 20334
# remain length: 20333
# remain length: 20332
# remain length: 20331
# remain length: 20330
# remain length: 20329
# remain length: 20328
# remain length: 20327
# remain length: 20326
# remain length: 20325
# remain length: 20324
# remain length: 20323
# remain length: 20310
# remain length: 20309
# remain length: 20302
# remain length: 20301
# remain length: 20300
# remain length: 20299
# remain length: 20298
# remain length: 20295
# remain length: 20294
# remain length: 20293
# remain length: 20292
# remain length: 20291
# remain length: 20290
# remain length: 20289
# remain length: 20287
# remain length: 20286
# remain length: 20285
# remain length: 20284
# remain length: 20283
# remain length: 20282
# remain length: 20281
# remain length: 20280
# remain length: 20279
# remain length: 20278
# remain length: 20277
# remain length: 20276
# remain length: 20275
# remain length: 20274
# remain length: 20273
# remain length: 20216
# remain length: 20215
# remain length: 20214
# remain length: 20212
# remain length: 20209
# remain length: 20208
# remain length: 20207
# remain length: 20206
# remain length: 20205
# remain length: 20204
# remain length: 20203
# remain length: 20202
# remain length: 20201
# remain length: 20200
# remain length: 20199
# remain length: 20198
# remain length: 20197
# remain length: 20196
# remain length: 20195
# remain length: 20194
# remain length: 20193
# remain length: 20192
# remain length: 20191
# remain length: 20190
# remain length: 20189
# remain length: 20188
# remain length: 20187
# remain length: 20186
# remain length: 20185
# remain length: 20184
# remain length: 20183
# remain length: 20182
# remain length: 20181
# remain length: 20180
# remain length: 20179
# remain length: 20178
# remain length: 20177
# remain length: 20176
# remain length: 20175
# remain length: 20174
# remain length: 20173
# remain length: 20172
# remain length: 20171
# remain length: 20168
# remain length: 20167
# remain length: 20161
# remain length: 20160
# remain length: 20159
# remain length: 20158
# remain length: 20157
# remain length: 20156
# remain length: 20155
# remain length: 20154
# remain length: 20153
# remain length: 20152
# remain length: 20134
# remain length: 20133
# remain length: 20132
# remain length: 20131
# remain length: 20130
# remain length: 20122
# remain length: 20121
# remain length: 20120
# remain length: 20118
# remain length: 20117
# remain length: 20116
# remain length: 20115
# remain length: 20114
# remain length: 20113
# remain length: 20102
# remain length: 20101
# remain length: 20100
# remain length: 20099
# remain length: 20098
# remain length: 20097
# remain length: 20096
# remain length: 20095
# remain length: 20088
# remain length: 20087
# remain length: 20086
# remain length: 20085
# remain length: 20084
# remain length: 20083
# remain length: 20082
# remain length: 20081
# remain length: 20079
# remain length: 20078
# remain length: 20077
# remain length: 20076
# remain length: 20075
# remain length: 20074
# remain length: 20073
# remain length: 20067
# remain length: 20066
# remain length: 20065
# remain length: 20064
# remain length: 20063
# remain length: 20062
# remain length: 20061
# remain length: 20057
# remain length: 20056
# remain length: 20055
# remain length: 20054
# remain length: 20053
# remain length: 20052
# remain length: 20051
# remain length: 20050
# remain length: 20049
# remain length: 20048
# remain length: 20047
# remain length: 5
# remain length: 4
# remain length: 3
# remain length: 2
# remain length: 1
# remain length: 0

# %%
v = pd.DataFrame(ans_value)
v['label'] = ans_label
ann1  = v.groupby("label").mean()

# %%
v1 = pd.DataFrame(true_label)
v1['label'] = ans_label
meta1 = v1.groupby("label").max()

# %%
meta1.shape
# Out:
# (19422, 1)

# %%
meta1.values
# Out:
# array([['CD8Tcm'],
#        ['Malignant'],
#        ['CD8Tcm'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
adata = anndata.AnnData(ann1)
adata.raw = adata
# same as adata = adata[:,adata.var['highly_variable']] but inplace
sc.tl.pca(
    adata,
    n_comps=50
)
sc.pp.neighbors(adata,
                n_neighbors=10,
                n_pcs=50,
                random_state=1234
                )
sc.tl.diffmap(adata,random_state=1234)
sc.tl.umap(adata,random_state=1234)
sc.tl.leiden(adata,random_state=1234)
sc.tl.paga(adata, groups='leiden')
# Out:
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_9747/220074476.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = anndata.AnnData(ann1)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
list(meta1)
# Out:
# [0]

# %%
adata.obs['celltype'] = meta1.values.tolist()

# %%
adata.obs
# Out:
#       leiden       celltype
# label
# 0          2       [CD8Tcm]
# 1          7    [Malignant]
# 2          0       [CD8Tcm]
# 3         14  [Fibroblasts]
# 4          6       [CD8Tex]
# ...      ...            ...
# 19417      1            [B]
# 19418     14            [B]
# 19419      6            [B]
# 19420      4            [B]
# 19421      3            [B]
#
# [19422 rows x 2 columns]

# %%
sc.pl.umap(adata, color="leiden")
# Out:
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
import argparse
import json
import logging
import os
import math
import numpy as np
import torch
import torch.utils.data as data
from tqdm import tqdm

import optim
# from config import config_args
from datasets.hc_dataset import HCDataset
from datasets.loading import load_data
from model.hyphc import HypHC
from utils.metrics import dasgupta_cost
from utils.training import add_flags_from_config, get_savedir

import networkx as nx

import matplotlib.pyplot as plt
from mst import mst

from utils.poincare import project,hyp_dist_djj
from utils.lca import hyp_lca
from utils.math import arctanh, tanh, arcosh

from utils.visualization import plot_tree_from_leaves,plot_geodesic



from utils.lca import hyp_lca

def hyp_lca_numpy(x, y):
    """Computes the hyperbolic LCA in numpy."""
    x = torch.from_numpy(x).view((1, 2))
    y = torch.from_numpy(y).view((1, 2))
    lca = hyp_lca(x, y, return_coord=True)
    return lca.view((2,)).numpy()
def is_leaf(tree, node):
    """check if node is a leaf in tree."""
    return len(list(tree.neighbors(node))) == 0
def complete_tree(tree, leaves_embeddings):
    """Get embeddings of internal nodes from leaves' embeddings using LCA construction."""

    def _complete_tree(embeddings, node):
        children = list(tree.neighbors(node))
        if len(children) == 2:
            left_c, right_c = children
            left_leaf = is_leaf(tree, left_c)
            right_leaf = is_leaf(tree, right_c)
            if left_leaf and right_leaf:
                pass
            elif left_leaf and not right_leaf:
                embeddings = _complete_tree(embeddings, right_c)
            elif right_leaf and not left_leaf:
                embeddings = _complete_tree(embeddings, left_c)
            else:
                embeddings = _complete_tree(embeddings, right_c)
                embeddings = _complete_tree(embeddings, left_c)
            embeddings[node] = hyp_lca_numpy(embeddings[left_c], embeddings[right_c])
        return embeddings

    n = leaves_embeddings.shape[0]
    tree_embeddings = np.zeros((2 * n - 1, 2))
    tree_embeddings[:n, :] = leaves_embeddings
    root = max(list(tree.nodes()))
    tree_embeddings = _complete_tree(tree_embeddings, root)
    return tree_embeddings
def train(model,dataloader,optimizer,similarities,epoches):
    best_cost = np.inf
    best_model = None
    counter = 0
    for epoch in range(epoches):
        model.train()
    total_loss = 0.0
    with tqdm(total=len(dataloader), unit='ex') as bar:
        for step, (triple_ids, triple_similarities) in enumerate(dataloader):
            # triple_ids = triple_ids.cuda()
            # triple_similarities = triple_similarities.cuda()
            loss = model.loss(triple_ids, triple_similarities)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            bar.update(1)
            bar.set_postfix(loss=f'{loss.item():.6f}')
            total_loss += loss
    total_loss = total_loss.item() / (step + 1.0)
    print("\t Epoch {} | average train loss: {:.6f}".format(epoch, total_loss))

    # keep best embeddings
    if (epoch + 1) % 1 == 0:
        tree = model.decode_tree(fast_decoding=1)
        cost = dasgupta_cost(tree, similarities)
        logging.info("{}:\t{:.4f}".format("Dasgupta's cost", cost))
        if cost < best_cost:
            counter = 0
            best_cost = cost
            best_model = model.state_dict()
        else:
            counter += 1
            if counter == 20:
#                 logging.info("Early stopping.")
                return

    # anneal temperature
    if (epoch + 1) % 30 == 0:
        model.anneal_temperature(0.5)
#         logging.info("Annealing temperature to: {}".format(model.temperature))
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.5
            lr = param_group['lr']
        print("Annealing learning rate to: {}".format(lr))

    print("Optimization finished.")
    if best_model is not None:
        # load best model
        model.load_state_dict(best_model)
def dist(x,y):
    return arcosh(1+ 2*( (x-y).norm(dim=-1, p=2, keepdim=True))/((1- y.norm(dim=-1, p=2, keepdim=True))*(1- x.norm(dim=-1, p=2, keepdim=True))));
def plot_tree_from_leaves_djj_1(ax, tree, leaves_embeddings, labels, color_seed=1234):
    """Plots a tree on leaves embeddings using the LCA construction."""
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)
    n = leaves_embeddings.shape[0]
    embeddings = complete_tree(tree, leaves_embeddings)
    colors = get_colors(labels, color_seed)
    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)
    
    for n1, n2 in tree.edges():
        x1 = embeddings[n1]
        x2 = embeddings[n2]
        plot_geodesic(x1, x2, ax)
    # ax.set_xlim(-1.05, 1.05)
    # ax.set_ylim(-1.05, 1.05)
    ax.axis("off")
    return ax
def sl_np_mst_ij(xs, S):
    xs = project(xs).detach().cpu()

    xs0 = xs[None, :, :]
    xs1 = xs[:, None, :]
    sim_mat = S(xs0, xs1)  # (n, n)
    similarities = sim_mat.numpy()
    n = similarities.shape[0]
    similarities=similarities.astype('double')
    ij, _ = mst.mst(similarities, n)
    return ij
class  UnionFind:
    
    def __init__(self, n , pos , c):
        self.n = n
        self.pos = pos
        self.c = c
        self.parent = [i for i in range(n)]
        self.rank = [0 for i in range(n)]
        self.vis = [0 for i in range(2*n-1)]
        self.vis2 = [0 for i in range(2*n-1)]
        self.mer = [-1 for i in range(2*n-1)]
        self._next_id = n
        self._tree = [-1 for i in range(2*n-1)]

        self._id = [i for i in range(n)]

    def _find(self, i):
        if self.parent[i] == i:
            return i
        else:
            self.parent[i] = self._find(self.parent[i])
            return self.parent[i]

    def find(self, i):
        if (i < 0) or (i > self.n):
            raise ValueError("Out of bounds index.")
        return self._find(i)

    def union(self,  i,  j, k=True):
        root_i = self._find(i)
        root_j = self._find(j)
        if root_i == root_j:
            return False
        else:
            
            if self.rank[root_i] < self.rank[root_j]:
                self.parent[root_i] = root_j
                if(k):
                    self._build(root_j, root_i)
                
            elif self.rank[root_i] > self.rank[root_j]:
                self.parent[root_j] = root_i
                if(k):
                    self._build(root_i, root_j)
                
            else:
                
                self.parent[root_j] = root_i
                self.rank[root_i] += 1
                if(k):
                    self._build(root_i, root_j)
                
            return True


    def merge(self,ij):
        for k in range(ij.shape[0]):
            a=ij[k,0];
            b=ij[k,1];
            if(self.mer[a]!=-1):
                a=self.mer[a];
            if(self.mer[b]!=-1):
                b=self.mer[b];
            self.union(a, b)

    def  _build(self, i, j):
#         print(self._tree[0],"----")
#         if(dist(self.pos[self._id[i]],self.pos[self._id[j]])<self.c):
            
            
#             print(i,j,'-',self._id[i],self._id[j]);
#             self.vis[self._id[i]]=1;
#             self.vis[self._id[j]]=1;
                
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self.pos[self._id[i]] = torch.tensor(new);
#             self.pos[self._id[j]] = torch.tensor(new);
            
#             self.search(self._id[i]);
#             self.search(self._id[j]);

#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
            
#         else:
            
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
        self.vis2[i]=1;
        self.vis2[j]=1;
        
        t=np.array(self.pos).tolist()
        new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
        t.append(new);
        self.pos=torch.tensor(t)
        
        self._tree[self._id[i]] = self._next_id
        self._tree[self._id[j]] = self._next_id
        self._id[i] = self._next_id
        self.check(i);
        self._next_id += 1

    def search(self,k):
#         for i in range(len(self.parent)):
#             if(self.parent[i]==k):
#                 self.parent[i]=self._next_id;
#         print(k==-1)

        for i in range(len(self._tree)):
            if(self.vis[i]):
                continue;            
            if(self._tree[i]==k):
                # print("sear")
                self._tree[i]=self._next_id;  
                
        for i in range(len(self._id)):
            if(self.vis[i]):
                continue;
            if(self._id[i]==k):
                # print("Sear")
                self._id[i]=self._next_id;  
                
    def check(self,t):
        minnum=math.inf
        minns=None;
        for i in range(self.n):
            if(self.vis[i] or self.vis2[i]):
                continue;
            distance = dist(self.pos[i],self.pos[-1]);
            if(distance<self.c and distance < minnum):
                minnum = distance
                minns = i;
                
#                 print("merge {} in {}".format(i,t))
#                 self.parent[i]=t;
#                 self.vis[i]=1;
#                 self.search(i);
        if(minns != None):
            # print("merge {} in {}".format(minns,self._next_id))
            self.vis[minns]=1;
            self.rank[minns]=-1;
            self.pos[minns] = self.pos[-1]
#             self.search(minns);
            self.mer[minns]=t;
            self.mer[self._next_id] = minns;
#             self.union(t,minns,False);
        
    def parent(self):
        return [self.parent[i] for i in range(self.n)]

    def tree(self):
        return [self._tree[i] for i in range(len(self._tree))]
def get_colors(y, color_seed=1234):
    """random color assignment for label classes."""
    np.random.seed(color_seed)
    colors = {}
    for k in np.unique(y):
        r = np.random.random()
        b = np.random.random()
        g = np.random.random()
        colors[k] = (r, g, b)
    return [colors[k] for k in y]


def get_Hyper_tree(data_path,start,end,lable,epoches,model_path=None,save_path='./',c=-1):
    np.random.seed(1234)
    torch.manual_seed(1234)
    # x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
    x, y_true, similarities = load_data(data_path,start,end,lable)
    print("{} length:{}".format(data_path,len(y_true)));
    dataset = HCDataset(x, y_true, similarities, num_samples=50000)
    dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
    if(model_path ==None):
        model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
        model.to("cpu")
        Optimizer = getattr(optim, 'RAdam')
        optimizer = Optimizer(model.parameters(),0.0005)
        train(model,dataloader,optimizer,similarities,epoches);
        torch.save(model,save_path+'model.pth');
    else:
        params = torch.load((model_path), map_location=torch.device('cpu'))
        model.load_state_dict(params, strict=False)
    model.eval()
    sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
    n=len(x);
    d = model.normalize_embeddings(model.embeddings.weight.data)
    d = project(d).detach().cpu()
    ijs = sl_np_mst_ij(d,sim_fn)
    uf = UnionFind(n,d,c)
    uf.merge(ijs)
    count=0

    tree = nx.DiGraph()
    for i, j in enumerate(uf.tree()[:-1]):
        if(j!=-1):
            tree.add_edge(j, i)
            
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(111)
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)

    n = len(d)
    embeddings = np.array(uf.pos)
    # for i in range(len(embeddings)):
    #     if(np.isnan(embeddings[i][0]) or embeddings[i][0] + embeddings[i][1] == 0):
    #         embeddings[i] = embeddings[i-1];
    #     pass;
    # print(embeddings)
    where_are_NaNs = np.isnan(embeddings)
    embeddings[where_are_NaNs] = 0
    vis = uf.vis
    # xlist=[]
    # ylist=[]
    # labels=[]

    # for i in range(n):
    #     if(uf.vis[i]!=1):
    #         xlist.append(embeddings[i,0]*20);
    #         ylist.append(embeddings[i,1]*20);
    #         labels.append(y_true[i]);
    # # colors = get_colors(labels, 1234)
    colors = get_colors(y_true, 1234)

    # ax.scatter(xlist, ylist, c=colors, s=50, alpha=0.6)

    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)

    for i in range(len(embeddings)):
        if(i<n):
            continue;
        if(uf.mer[i]!=-1):
            # print(i,'pass')
            pass;
        else:
            ax.scatter(embeddings[i][0]*20,embeddings[i][1]*20,color='black',s=20,alpha=0.7)

        

    for n1, n2 in tree.edges():
    #     if(uf.vis[n1]== 1 or uf.vis[n2]== 1 ):
    # #         print("1")
    #         pass
    #     else:
    #         x1 = embeddings[n1]
    #         x2 = embeddings[n2]
    # #         if(n1>=n):
    # #             if(uf.mer[n1]!=-1):
    # #                 pass;
    # #             else:
    # #                 count+=1;
    # #         if(n2>n):
    # #             if(uf.mer[n1]!=-1):
    # # # 
    # #                 pass;
    # #             else:
    # # #                 ax.scatter(x2[0]*20,x2[1]*20,color='black',s=20,alpha=0.7)
    # #                 count+=1
        
        
    #         plot_geodesic(x1, x2, ax)
    # #         print(x1,x2,n1,n2)
    # #         break
    #         pass

    #     ax.axis("off")
        x1 = embeddings[n1];
        x2 = embeddings[n2];
        plot_geodesic(x1,x2,ax)
    fig.savefig(save_path+"graph.png");
    np.save(save_path+"dataxy.npy",embeddings)
    np.save(save_path+"datalink.npy",list(tree.edges()))
    np.save(save_path+"datamerge.npy",uf.mer)

# %%
def cccfg(
        adata,
        gene_list,
        save_path="./",
    ):
    groupby = adata.uns["capital"]["tree"]["annotation"]
    filtered_data = adata.raw.to_adata()[:]
    filtered_data.to_df().to_csv(save_path+"data_cell.csv");
    adata.obs.to_csv(save_path+"data_type.csv")
    cluster_centroid_data = np.empty((0, filtered_data.n_vars))
    clustername = filtered_data.obs[groupby].unique().tolist()

    for i in clustername:
        a_cluster_data = filtered_data[filtered_data.obs[groupby] == "{}".format(
            i)].to_df()
        a_cluster_median = a_cluster_data.mean(axis=0).values
        cluster_centroid_data = np.vstack(
            (cluster_centroid_data, a_cluster_median)
        )
    cluster_centroid = pd.DataFrame(
        cluster_centroid_data,
        index=clustername,
        columns=filtered_data.var_names
    )
    cluster_centroid.to_csv(save_path+"datas.data",header=None);
    cluster_centroid.to_csv(save_path+"datas.csv");

    return cluster_centroid

# %%
set_initial_condition(adata)

# %%
cccfg(adata,'','./datas/merge4/')
# Out:
#          0         1         2         3         4         5             6    \
# 2   0.038365  0.031421  0.001897  0.933053  0.068371  0.002022  4.757188e-03
# 7   0.255901  0.005704  0.015239  0.202533  0.016925  0.003015  5.297253e-08
# 0   0.029900  0.153420  0.007350  0.137175  0.097119  0.003539  0.000000e+00
# 14  0.773751  0.006209  0.963780  0.123174  0.028500  0.000472  1.682078e-03
# 6   0.053135  0.164754  0.005190  0.584688  0.085083  0.001811  0.000000e+00
# 13  0.062132  0.009266  0.003355  0.618225  0.014355  0.000400  0.000000e+00
# 15  0.556280  0.001249  0.181043  0.102481  0.039346  0.000000  0.000000e+00
# 4   0.038184  0.074223  0.004328  0.219159  0.105869  0.001039  5.224663e-02
# 8   0.223460  0.001310  0.310426  0.110038  0.001015  0.005620  4.545441e-07
# 18  0.112076  0.047929  0.000000  0.145580  0.075746  0.000000  0.000000e+00
# 5   0.044123  0.059538  0.004252  0.521701  0.114679  0.000518  0.000000e+00
# 1   0.029955  0.086310  0.003434  0.657147  0.058404  0.003024  5.930651e-03
# 9   0.677667  0.046188  0.008951  1.452987  0.069025  0.003458  0.000000e+00
# 3   0.029738  0.018299  0.009219  1.522702  0.177396  0.006014  0.000000e+00
# 11  0.072176  0.017809  0.004914  0.477501  0.029665  0.001767  1.007664e-03
# 12  0.047151  0.004536  0.006248  0.344641  0.130715  0.004009  8.742054e-02
# 16  0.024390  0.022473  0.000000  0.472670  0.031090  0.007609  3.069767e-02
# 17  0.289683  0.016726  0.000000  0.811399  0.035261  0.002035  6.372862e-03
# 10  0.134626  0.063257  0.005005  0.589460  0.051846  0.003396  6.462790e-03
# 19  0.027583  0.103446  0.042750  1.222125  0.169919  0.000000  0.000000e+00
# 20  0.117299  0.000000  0.240773  0.122682  0.000000  0.000000  0.000000e+00
#
#          7         8         9    ...           503       504       505  \
# 2   0.018960  0.013001  0.131800  ...  9.134006e-04  1.065142  0.001280
# 7   0.105613  0.000009  0.010118  ...  3.460207e-03  0.038181  0.050688
# 0   0.030902  0.027302  0.247274  ...  6.139796e-04  0.667327  0.001987
# 14  0.031238  0.000115  0.020433  ...  3.024777e-03  0.112556  0.410405
# 6   0.072290  0.023525  0.208959  ...  0.000000e+00  0.650772  0.000078
# 13  0.035979  0.000029  0.005778  ...  3.011537e-01  0.033545  0.123636
# 15  0.050446  0.000000  0.009333  ...  5.462280e-03  0.074569  0.095930
# 4   0.045065  0.019276  0.136511  ...  5.141349e-04  1.221238  0.002520
# 8   0.067202  0.001078  0.001255  ...  2.288977e-07  0.008944  0.323918
# 18  0.006118  0.011452  0.131021  ...  4.290148e-03  0.415527  0.001329
# 5   0.040140  0.035550  0.135334  ...  0.000000e+00  0.904318  0.002920
# 1   0.041959  0.014728  0.107586  ...  0.000000e+00  0.538807  0.002551
# 9   0.042880  0.000963  0.018803  ...  7.959560e-03  0.107260  0.006013
# 3   0.121476  0.001296  0.034362  ...  1.026098e-03  0.003051  0.001569
# 11  0.273859  0.002814  0.015425  ...  5.056874e-04  0.099587  0.006941
# 12  0.037843  0.003001  0.110464  ...  0.000000e+00  1.294039  0.000000
# 16  0.018806  0.000000  0.073570  ...  0.000000e+00  0.813676  0.000000
# 17  0.030887  0.000000  0.446637  ...  0.000000e+00  0.055179  0.000000
# 10  0.215671  0.033173  0.156819  ...  0.000000e+00  0.531327  0.004050
# 19  0.070248  0.000000  0.098129  ...  0.000000e+00  0.553075  0.000000
# 20  0.126536  0.000000  0.000000  ...  2.315353e-01  0.000000  0.154034
#
#              506       507       508       509       510       511       512
# 2   0.000000e+00  0.009084  0.231559  0.001026  0.006550  0.000000  0.011280
# 7   1.823864e-07  0.000000  0.013651  0.002195  0.193595  0.001568  0.013828
# 0   0.000000e+00  0.000000  0.243783  0.000211  0.005375  0.000581  0.002309
# 14  2.233798e-03  0.000000  0.027796  0.000000  0.718275  0.003232  0.005653
# 6   0.000000e+00  0.000000  0.264880  0.000000  0.028982  0.000000  0.006807
# 13  2.354926e-03  0.000000  0.011131  0.220026  0.015241  0.000000  0.008824
# 15  0.000000e+00  0.000000  0.009258  0.012131  0.928789  0.000000  0.006016
# 4   0.000000e+00  0.036021  0.346177  0.000777  0.014518  0.000000  0.007348
# 8   0.000000e+00  0.000000  0.001521  0.001371  0.130897  0.001073  0.021016
# 18  0.000000e+00  0.000000  0.156679  0.000000  0.100623  0.000000  0.000000
# 5   0.000000e+00  0.000000  0.042851  0.001479  0.012232  0.000000  0.001984
# 1   5.726679e-04  0.002790  0.261841  0.000765  0.003359  0.000323  0.021859
# 9   4.883476e-03  0.000000  0.013388  0.001131  0.015086  0.013898  0.635857
# 3   3.773381e-01  0.000000  0.001530  0.000000  0.006585  0.001903  0.002610
# 11  6.657601e-03  0.000000  0.016286  0.000000  0.024882  0.000000  0.010600
# 12  0.000000e+00  0.047069  0.032915  0.000000  0.015392  0.001283  0.316624
# 16  0.000000e+00  0.018114  0.077817  0.000000  0.003392  0.000000  0.294991
# 17  0.000000e+00  0.000000  0.018447  0.000000  0.000041  0.000000  0.013405
# 10  0.000000e+00  0.001006  0.174082  0.000000  0.085048  0.000000  0.021709
# 19  1.894622e-01  0.000000  0.159834  0.000000  0.000000  0.000000  0.013005
# 20  0.000000e+00  0.000000  0.000000  0.122696  1.381750  0.000000  0.000000
#
# [21 rows x 513 columns]

# %%
x, y_true, similarities = load_data('./datas/merge4/datas.data',1,514,0)
data_path = './datas/merge4/datas.data'
start = 1
end =514
lable = 0
model_path = None;
save_path = './datas/merge4/'
epoches=10
c=-1
np.random.seed(1234)
torch.manual_seed(1234)
# x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
x, y_true, similarities = load_data(data_path,start,end,lable)
print("{} length:{}".format(data_path,len(y_true)));
dataset = HCDataset(x, y_true, similarities, num_samples=50000)
dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
if(model_path ==None):
    model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
    model.to("cpu")
    Optimizer = getattr(optim, 'RAdam')
    optimizer = Optimizer(model.parameters(),0.0005)
    train(model,dataloader,optimizer,similarities,epoches);
    torch.save(model,save_path+'model.pth');
else:
    params = torch.load((model_path), map_location=torch.device('cpu'))
    model.load_state_dict(params, strict=False)
model.eval()
sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
n=len(x);
d = model.normalize_embeddings(model.embeddings.weight.data)
d = project(d).detach().cpu()
ijs = sl_np_mst_ij(d,sim_fn)
uf = UnionFind(n,d,c)
uf.merge(ijs)
count=0
# Out:
# ./datas/merge4/datas.data length:21
# Generating all pairs superset
# 100%|██████████| 1563/1563 [01:24<00:00, 18.57ex/s, loss=1.454685]
# 	 Epoch 9 | average train loss: 1.483795
# Optimization finished.
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_9747/836080252.py:147: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ij, _ = mst.mst(similarities, n)

# %%
from alignment import node
from alignment import show_tree
embeddings = np.array(uf.pos)

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break

# %%
def search_tree(now,c):
    if(len(now.son) != 2):
        return now;
    lson = search_tree(now.son[0],c);
    now.son[0] = lson;
    rson = search_tree(now.son[1],c);
    now.son[1] = rson
    # lson = now.son[0]
    # rson = now.son[1]
    if(np.linalg.norm(lson.value-rson.value)<=c):
        if(len(lson.son)>1 and len(rson.son)>1):
            pass
        elif(len(lson.son)>1):
            print(rson.name,lson.name)
            now = rson;
            now.son.append(lson);
        else:
            print(rson.name,lson.name)
            now = lson;
            now.son.append(rson)
    # exit(0)
    return now;

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break
show_tree(nodes1[-1]).show_fig()

# %%
search_tree(nodes1[-1],0.018)
show_tree(nodes1[-1]).show_fig()
# Out:
# 14 1
# 1 5
# 8 6
# 17 12
# 7 0
# 0 10
# 16 11
# 11 2
# 2 10
# 10 15
# 9 4

# %%
adata.obs.groupby('leiden').max()
# Out:
#              celltype
# leiden
# 0       [Fibroblasts]
# 1       [Fibroblasts]
# 2         [Malignant]
# 3       [Fibroblasts]
# 4       [Fibroblasts]
# 5         [Malignant]
# 6       [Fibroblasts]
# 7         [Malignant]
# 8       [Fibroblasts]
# 9         [Malignant]
# 10      [Fibroblasts]
# 11        [Malignant]
# 12      [Fibroblasts]
# 13      [Fibroblasts]
# 14      [Fibroblasts]
# 15        [Malignant]
# 16      [Endothelial]
# 17      [Fibroblasts]
# 18      [Fibroblasts]
# 19           [CD8Tcm]
# 20      [Endothelial]

# %%
14 1
1 5
8 6
17 12
7 0
0 10
16 11
11 2
2 10
10 15
9 4

# %%
ann1.to_csv("./datas/merge4/ann1.csv")
meta1.to_csv("./datas/merge4/meta1.csv")

# %%
save_path = './datas/merge4/'
tree = nx.DiGraph()
for i, j in enumerate(uf.tree()[:-1]):
    if(j!=-1):
        tree.add_edge(j, i)
np.save(save_path+"dataxy.npy",embeddings)
np.save(save_path+"datalink.npy",list(tree.edges()))
np.save(save_path+"datamerge.npy",uf.mer)

# %%
tree.edges()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 tree.edges()
#
# AttributeError: 'KDTree' object has no attribute 'edges'
