# %%
from read_data import *
from hyper import *
from alignment import *
from datasets.preprecossing import *

# %%
datas = pd.read_csv("./datas/data1/data_cell.csv").set_index("Unnamed: 0")
datas
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...  CD300LG       CD7  ELN     FCER2  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...      0.0  0.000000  0.0  1.262537
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...      0.0  0.000000  0.0  0.761836
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...      0.0  0.000000  0.0  0.000000
# ...                               ...  ...      ...       ...  ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...      0.0  0.817762  0.0  0.000000
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...      0.0  0.000000  0.0  0.000000
#
#                              KIR2DL1     NELL2  CA4  SOD3  CCL17  FCGR3A
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAAGATGCAGCGAACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACCATGTCCTAGTGA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACTCAGGTGTGACCC      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC      0.0  0.000000  0.0   0.0    0.0     0.0
# ...                              ...       ...  ...   ...    ...     ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGCCCTACAACGCACC      0.0  1.109585  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA      0.0  0.621233  0.0   0.0    0.0     0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ064_CTCATTAGTAAATACG      0.0  0.000000  0.0   0.0    0.0     0.0
#
# [33043 rows x 513 columns]

# %%
celltype  = cell_type1 = pd.read_csv("../../../capital/docs/tutorials/BRCA_EMTAB8107_CellMetainfo_table.tsv",sep="\t")
celltype
# Out:
#                               Cell     UMAP_1    UMAP_2  Cluster  \
# 0      sc5rJUQ024_AAACCTGGTCTCCACT  12.136345 -2.121436        5
# 1      sc5rJUQ024_AAAGATGCAGCGAACA -15.524519 -7.638500        5
# 2      sc5rJUQ024_AACCATGTCCTAGTGA -15.595183 -6.820365        5
# 3      sc5rJUQ024_AACTCAGGTGTGACCC -15.779087 -7.584647        5
# 4      sc5rJUQ024_AAGACCTGTCCGTGAC -14.804107 -7.505053        5
# ...                            ...        ...       ...      ...
# 33038  sc5rJUQ060_TGAGAGGAGTCCTCCT  -7.984505 -1.166239       15
# 33039  sc5rJUQ060_TGCCCTACAACGCACC  -7.716203 -1.429827       15
# 33040  sc5rJUQ060_TGTTCCGAGAGCCCAA  -7.371503 -1.509427       15
# 33041  sc5rJUQ064_AGTTGGTGTGCAGACA -13.337872  0.405348       15
# 33042  sc5rJUQ064_CTCATTAGTAAATACG   2.797375  9.734141       15
#
#       Celltype (malignancy) Celltype (major-lineage) Celltype (minor-lineage)  \
# 0              Immune cells                        B                        B
# 1              Immune cells                        B                        B
# 2              Immune cells                        B                        B
# 3              Immune cells                        B                        B
# 4              Immune cells                        B                        B
# ...                     ...                      ...                      ...
# 33038         Stromal cells                  Tprolif                  Tprolif
# 33039         Stromal cells                  Tprolif                  Tprolif
# 33040         Stromal cells                  Tprolif                  Tprolif
# 33041         Stromal cells                  Tprolif                  Tprolif
# 33042         Stromal cells                  Tprolif                  Tprolif
#
#       Patient    Sample Tissue
# 0         P41  Sample41  Tumor
# 1         P41  Sample41  Tumor
# 2         P41  Sample41  Tumor
# 3         P41  Sample41  Tumor
# 4         P41  Sample41  Tumor
# ...       ...       ...    ...
# 33038     P53  Sample53  Tumor
# 33039     P53  Sample53  Tumor
# 33040     P53  Sample53  Tumor
# 33041     P54  Sample54  Tumor
# 33042     P54  Sample54  Tumor
#
# [33043 rows x 10 columns]

# %%
adata1 = datas.copy()
adata1.loc[list(celltype['Cell']), 'Celltype'] = list(celltype['Celltype (minor-lineage)'])
adata1
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...       CD7  ELN     FCER2  KIR2DL1  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...  0.000000  0.0  1.262537      0.0
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...  0.000000  0.0  0.761836      0.0
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...  0.000000  0.0  0.000000      0.0
# ...                               ...  ...       ...  ...       ...      ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...  0.817762  0.0  0.000000      0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...  0.000000  0.0  0.000000      0.0
#
#                                 NELL2  CA4  SOD3  CCL17  FCGR3A  Celltype
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  0.0   0.0    0.0     0.0         B
# ...                               ...  ...   ...    ...     ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGCCCTACAACGCACC  1.109585  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.621233  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  0.0   0.0    0.0     0.0   Tprolif
#
# [33043 rows x 514 columns]

# %%
from scipy.spatial import KDTree
ans_value = []
ans_label = []
true_label = [];
now_labels = adata1['Celltype'].tolist();
c= -2
r= 2
now_label = 0;
now =  datas.values;
while len(now) != 0:
    rnd = np.random.randint(now.shape[0], size=1);
    rand_choice = now[rnd, :].reshape(-1)
    tree = KDTree(now);
    indices = tree.query_ball_point(rand_choice,r)
    points_within_k = now[indices]
    now = now.tolist();
    if(len(points_within_k)-1 < c):
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now_label +=1
            now.remove(i.tolist());
            true_label.append(now_labels[int(rnd)])
    else:
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now.remove(i.tolist());            
            true_label.append(now_labels[int(rnd)])
        now_label+=1;
    now = np.array(now);
    print("remain length: {}".format(len(now)))
    # for i in points_within_k:
    #     if(i == rand_choice).all():
    #         continue;
        
    # now.remove(rand_choice)
    # now.tolist().remove(rand_choice.tolist())
    # now = np.array(now)
    # break
# rand_choice == now
np.save('./datas/try/c_{}_r_{}_label.npy'.format(c,r),np.array(ans_label))
np.save('./datas/try/c_{}_r_{}_value.npy'.format(c,r),np.array(ans_value))
# Out:
# remain length: 33042
# remain length: 33041
# remain length: 33040
# remain length: 33039
# remain length: 33038
# remain length: 33037
# remain length: 33036
# remain length: 33035
# remain length: 33034
# remain length: 33033
# remain length: 33032
# remain length: 33031
# remain length: 33030
# remain length: 33029
# remain length: 33028
# remain length: 33027
# remain length: 33026
# remain length: 33025
# remain length: 33024
# remain length: 33023
# remain length: 33022
# remain length: 33021
# remain length: 33020
# remain length: 33019
# remain length: 33018
# remain length: 33017
# remain length: 33016
# remain length: 33015
# remain length: 33014
# remain length: 33013
# remain length: 33012
# remain length: 33011
# remain length: 33010
# remain length: 33009
# remain length: 33008
# remain length: 33007
# remain length: 33006
# remain length: 33005
# remain length: 33004
# remain length: 33003
# remain length: 33002
# remain length: 33001
# remain length: 33000
# remain length: 32999
# remain length: 32998
# remain length: 32997
# remain length: 32996
# remain length: 32995
# remain length: 32994
# remain length: 32993
# remain length: 32992
# remain length: 32991
# remain length: 32990
# remain length: 32989
# remain length: 32988
# remain length: 32987
# remain length: 32986
# remain length: 32985
# remain length: 32984
# remain length: 32983
# remain length: 32931
# remain length: 32930
# remain length: 32929
# remain length: 32928
# remain length: 32927
# remain length: 32926
# remain length: 32925
# remain length: 32924
# remain length: 32923
# remain length: 32922
# remain length: 32921
# remain length: 30858
# remain length: 30857
# remain length: 30856
# remain length: 30855
# remain length: 30854
# remain length: 30853
# remain length: 30846
# remain length: 30845
# remain length: 30844
# remain length: 30836
# remain length: 30835
# remain length: 30834
# remain length: 30833
# remain length: 30832
# remain length: 30831
# remain length: 30830
# remain length: 30829
# remain length: 30828
# remain length: 30827
# remain length: 30825
# remain length: 30824
# remain length: 30823
# remain length: 30822
# remain length: 30821
# remain length: 30820
# remain length: 30819
# remain length: 30818
# remain length: 30817
# remain length: 30816
# remain length: 30815
# remain length: 30801
# remain length: 30800
# remain length: 30799
# remain length: 30798
# remain length: 30797
# remain length: 30796
# remain length: 30795
# remain length: 30794
# remain length: 30792
# remain length: 30791
# remain length: 30790
# remain length: 30773
# remain length: 30772
# remain length: 30771
# remain length: 30770
# remain length: 30769
# remain length: 30768
# remain length: 30767
# remain length: 30766
# remain length: 30763
# remain length: 30762
# remain length: 30761
# remain length: 30760
# remain length: 30759
# remain length: 30758
# remain length: 30757
# remain length: 30756
# remain length: 30755
# remain length: 30754
# remain length: 30753
# remain length: 30752
# remain length: 30751
# remain length: 30750
# remain length: 30749
# remain length: 30748
# remain length: 30747
# remain length: 30746
# remain length: 30745
# remain length: 30744
# remain length: 30743
# remain length: 30742
# remain length: 30741
# remain length: 30740
# remain length: 30739
# remain length: 30738
# remain length: 30737
# remain length: 30736
# remain length: 30735
# remain length: 30734
# remain length: 30733
# remain length: 30732
# remain length: 30731
# remain length: 30730
# remain length: 30729
# remain length: 30728
# remain length: 30725
# remain length: 30724
# remain length: 30723
# remain length: 30722
# remain length: 30721
# remain length: 30720
# remain length: 30719
# remain length: 30718
# remain length: 30717
# remain length: 30716
# remain length: 30709
# remain length: 30708
# remain length: 30707
# remain length: 30706
# remain length: 30705
# remain length: 30704
# remain length: 30703
# remain length: 30702
# remain length: 30701
# remain length: 30700
# remain length: 30699
# remain length: 30689
# remain length: 30688
# remain length: 30687
# remain length: 30686
# remain length: 30685
# remain length: 30684
# remain length: 30683
# remain length: 30682
# remain length: 30681
# remain length: 30680
# remain length: 30679
# remain length: 30678
# remain length: 30677
# remain length: 30676
# remain length: 30675
# remain length: 30674
# remain length: 30673
# remain length: 30672
# remain length: 30671
# remain length: 30670
# remain length: 30669
# remain length: 30668
# remain length: 30667
# remain length: 30666
# remain length: 30665
# remain length: 30664
# remain length: 30663
# remain length: 30662
# remain length: 30661
# remain length: 30660
# remain length: 30659
# remain length: 30654
# remain length: 30653
# remain length: 30652
# remain length: 30651
# remain length: 30650
# remain length: 30649
# remain length: 30648
# remain length: 30647
# remain length: 30646
# remain length: 30645
# remain length: 30644
# remain length: 30643
# remain length: 30642
# remain length: 30641
# remain length: 30640
# remain length: 30639
# remain length: 30638
# remain length: 30637
# remain length: 30630
# remain length: 30629
# remain length: 30627
# remain length: 30626
# remain length: 30625
# remain length: 30624
# remain length: 30623
# remain length: 30622
# remain length: 30621
# remain length: 30618
# remain length: 30617
# remain length: 30616
# remain length: 30615
# remain length: 30614
# remain length: 30613
# remain length: 30612
# remain length: 30611
# remain length: 30610
# remain length: 30609
# remain length: 30608
# remain length: 30607
# remain length: 30606
# remain length: 30605
# remain length: 30604
# remain length: 30603
# remain length: 30602
# remain length: 30601
# remain length: 30600
# remain length: 30599
# remain length: 30598
# remain length: 30597
# remain length: 30596
# remain length: 30595
# remain length: 30594
# remain length: 30593
# remain length: 30592
# remain length: 30591
# remain length: 30590
# remain length: 30589
# remain length: 30588
# remain length: 30587
# remain length: 30586
# remain length: 30585
# remain length: 30584
# remain length: 30583
# remain length: 30582
# remain length: 30581
# remain length: 30580
# remain length: 30579
# remain length: 30578
# remain length: 30575
# remain length: 30574
# remain length: 30573
# remain length: 30572
# remain length: 30571
# remain length: 30570
# remain length: 30569
# remain length: 30564
# remain length: 30563
# remain length: 30562
# remain length: 30561
# remain length: 30560
# remain length: 30559
# remain length: 30558
# remain length: 30557
# remain length: 30556
# remain length: 30555
# remain length: 30554
# remain length: 30553
# remain length: 30552
# remain length: 30551
# remain length: 30550
# remain length: 30549
# remain length: 30548
# remain length: 30547
# remain length: 30546
# remain length: 30545
# remain length: 30544
# remain length: 30543
# remain length: 30542
# remain length: 30541
# remain length: 30540
# remain length: 30539
# remain length: 30538
# remain length: 30537
# remain length: 30536
# remain length: 30535
# remain length: 30533
# remain length: 30532
# remain length: 30531
# remain length: 30530
# remain length: 30529
# remain length: 30528
# remain length: 30527
# remain length: 30526
# remain length: 30525
# remain length: 30524
# remain length: 30523
# remain length: 30522
# remain length: 30521
# remain length: 30520
# remain length: 30519
# remain length: 30518
# remain length: 30516
# remain length: 30515
# remain length: 30514
# remain length: 30513
# remain length: 30512
# remain length: 30511
# remain length: 30510
# remain length: 30509
# remain length: 30508
# remain length: 30507
# remain length: 30506
# remain length: 30505
# remain length: 30504
# remain length: 30503
# remain length: 30502
# remain length: 30501
# remain length: 30500
# remain length: 30499
# remain length: 30498
# remain length: 30497
# remain length: 30496
# remain length: 30495
# remain length: 30494
# remain length: 30493
# remain length: 30492
# remain length: 30491
# remain length: 30490
# remain length: 30489
# remain length: 30488
# remain length: 30487
# remain length: 30486
# remain length: 30485
# remain length: 30484
# remain length: 30483
# remain length: 30482
# remain length: 30481
# remain length: 30480
# remain length: 30479
# remain length: 30478
# remain length: 30476
# remain length: 30475
# remain length: 30474
# remain length: 30473
# remain length: 30472
# remain length: 30471
# remain length: 30470
# remain length: 30469
# remain length: 30466
# remain length: 30465
# remain length: 30464
# remain length: 30462
# remain length: 30461
# remain length: 30460
# remain length: 30452
# remain length: 30451
# remain length: 30449
# remain length: 30448
# remain length: 30447
# remain length: 30446
# remain length: 30445
# remain length: 30444
# remain length: 30443
# remain length: 30442
# remain length: 30441
# remain length: 30440
# remain length: 30439
# remain length: 30438
# remain length: 30437
# remain length: 30436
# remain length: 30435
# remain length: 30434
# remain length: 30433
# remain length: 30432
# remain length: 30431
# remain length: 30430
# remain length: 30429
# remain length: 30428
# remain length: 30427
# remain length: 30426
# remain length: 30425
# remain length: 30424
# remain length: 30423
# remain length: 30422
# remain length: 30421
# remain length: 30420
# remain length: 30419
# remain length: 30418
# remain length: 30417
# remain length: 30416
# remain length: 30415
# remain length: 30414
# remain length: 30413
# remain length: 30412
# remain length: 30411
# remain length: 30410
# remain length: 30409
# remain length: 30408
# remain length: 30407
# remain length: 30406
# remain length: 30405
# remain length: 30404
# remain length: 30403
# remain length: 30402
# remain length: 30401
# remain length: 30400
# remain length: 30399
# remain length: 30398
# remain length: 30397
# remain length: 30396
# remain length: 30394
# remain length: 30393
# remain length: 30392
# remain length: 30391
# remain length: 30390
# remain length: 30389
# remain length: 30388
# remain length: 30387
# remain length: 30386
# remain length: 30385
# remain length: 30384
# remain length: 30383
# remain length: 30382
# remain length: 30381
# remain length: 30380
# remain length: 30379
# remain length: 30378
# remain length: 30377
# remain length: 30376
# remain length: 30375
# remain length: 30374
# remain length: 30373
# remain length: 30372
# remain length: 30371
# remain length: 30370
# remain length: 30369
# remain length: 30368
# remain length: 30367
# remain length: 30366
# remain length: 30365
# remain length: 30364
# remain length: 30363
# remain length: 30362
# remain length: 30361
# remain length: 30350
# remain length: 30347
# remain length: 30346
# remain length: 30345
# remain length: 30344
# remain length: 30343
# remain length: 30342
# remain length: 30341
# remain length: 30340
# remain length: 30339
# remain length: 30338
# remain length: 30337
# remain length: 30336
# remain length: 30335
# remain length: 30334
# remain length: 30333
# remain length: 30332
# remain length: 30331
# remain length: 30330
# remain length: 30329
# remain length: 30328
# remain length: 30327
# remain length: 30326
# remain length: 30325
# remain length: 30324
# remain length: 30323
# remain length: 30322
# remain length: 30321
# remain length: 30320
# remain length: 30319
# remain length: 30318
# remain length: 30317
# remain length: 30316
# remain length: 30313
# remain length: 30312
# remain length: 30311
# remain length: 30310
# remain length: 30309
# remain length: 30308
# remain length: 30307
# remain length: 30306
# remain length: 30305
# remain length: 30304
# remain length: 30303
# remain length: 30302
# remain length: 30301
# remain length: 30300
# remain length: 30299
# remain length: 30298
# remain length: 30297
# remain length: 30296
# remain length: 30295
# remain length: 30294
# remain length: 30293
# remain length: 30292
# remain length: 30291
# remain length: 30288
# remain length: 30287
# remain length: 30286
# remain length: 30285
# remain length: 30284
# remain length: 30283
# remain length: 30282
# remain length: 30281
# remain length: 30280
# remain length: 30279
# remain length: 30278
# remain length: 30277
# remain length: 30276
# remain length: 30275
# remain length: 30274
# remain length: 30273
# remain length: 30272
# remain length: 30271
# remain length: 30270
# remain length: 30269
# remain length: 30268
# remain length: 30267
# remain length: 30266
# remain length: 30265
# remain length: 30264
# remain length: 30263
# remain length: 30262
# remain length: 30261
# remain length: 30260
# remain length: 30259
# remain length: 30258
# remain length: 30257
# remain length: 30256
# remain length: 30255
# remain length: 30254
# remain length: 30253
# remain length: 30252
# remain length: 30251
# remain length: 30250
# remain length: 30249
# remain length: 30248
# remain length: 30247
# remain length: 30246
# remain length: 30245
# remain length: 30244
# remain length: 30243
# remain length: 30242
# remain length: 30241
# remain length: 30240
# remain length: 30239
# remain length: 30238
# remain length: 30237
# remain length: 30236
# remain length: 30235
# remain length: 30234
# remain length: 30233
# remain length: 30232
# remain length: 30231
# remain length: 30230
# remain length: 30229
# remain length: 30228
# remain length: 30227
# remain length: 30226
# remain length: 30225
# remain length: 30224
# remain length: 30218
# remain length: 30217
# remain length: 30216
# remain length: 30215
# remain length: 30214
# remain length: 30213
# remain length: 30212
# remain length: 30211
# remain length: 30210
# remain length: 30209
# remain length: 30208
# remain length: 30207
# remain length: 30206
# remain length: 30205
# remain length: 30204
# remain length: 30202
# remain length: 30201
# remain length: 30200
# remain length: 30199
# remain length: 30196
# remain length: 30195
# remain length: 30194
# remain length: 30193
# remain length: 30192
# remain length: 30191
# remain length: 30190
# remain length: 30189
# remain length: 30188
# remain length: 30187
# remain length: 30186
# remain length: 30185
# remain length: 30184
# remain length: 30183
# remain length: 30182
# remain length: 30181
# remain length: 30180
# remain length: 30179
# remain length: 30178
# remain length: 30177
# remain length: 30176
# remain length: 30175
# remain length: 30174
# remain length: 30173
# remain length: 30172
# remain length: 30171
# remain length: 30170
# remain length: 30169
# remain length: 30168
# remain length: 30167
# remain length: 30166
# remain length: 30165
# remain length: 30164
# remain length: 30163
# remain length: 30162
# remain length: 30155
# remain length: 30154
# remain length: 30153
# remain length: 30152
# remain length: 30151
# remain length: 30149
# remain length: 30148
# remain length: 30147
# remain length: 30146
# remain length: 30142
# remain length: 30139
# remain length: 30138
# remain length: 30137
# remain length: 30136
# remain length: 30135
# remain length: 30134
# remain length: 30133
# remain length: 30132
# remain length: 30131
# remain length: 30130
# remain length: 30129
# remain length: 30128
# remain length: 30126
# remain length: 30125
# remain length: 30124
# remain length: 30123
# remain length: 30122
# remain length: 30121
# remain length: 30120
# remain length: 30119
# remain length: 30118
# remain length: 30117
# remain length: 30116
# remain length: 30115
# remain length: 30109
# remain length: 30108
# remain length: 30107
# remain length: 30106
# remain length: 30105
# remain length: 30104
# remain length: 30103
# remain length: 30100
# remain length: 30099
# remain length: 30098
# remain length: 30097
# remain length: 30096
# remain length: 30095
# remain length: 30094
# remain length: 30093
# remain length: 30092
# remain length: 30091
# remain length: 30090
# remain length: 30089
# remain length: 30087
# remain length: 30086
# remain length: 30085
# remain length: 30084
# remain length: 30083
# remain length: 30082
# remain length: 30081
# remain length: 30080
# remain length: 30079
# remain length: 30078
# remain length: 30077
# remain length: 30067
# remain length: 30066
# remain length: 30065
# remain length: 30064
# remain length: 30063
# remain length: 30062
# remain length: 30061
# remain length: 30060
# remain length: 30059
# remain length: 30058
# remain length: 30057
# remain length: 30056
# remain length: 30055
# remain length: 30054
# remain length: 30053
# remain length: 30052
# remain length: 30051
# remain length: 30050
# remain length: 30049
# remain length: 30048
# remain length: 30047
# remain length: 30046
# remain length: 30045
# remain length: 30044
# remain length: 30043
# remain length: 30042
# remain length: 30041
# remain length: 30040
# remain length: 30039
# remain length: 30038
# remain length: 30037
# remain length: 30036
# remain length: 30035
# remain length: 118
# remain length: 117
# remain length: 116
# remain length: 115
# remain length: 114
# remain length: 113
# remain length: 112
# remain length: 111
# remain length: 110
# remain length: 109
# remain length: 108
# remain length: 107
# remain length: 106
# remain length: 105
# remain length: 104
# remain length: 103
# remain length: 102
# remain length: 101
# remain length: 100
# remain length: 99
# remain length: 98
# remain length: 97
# remain length: 96
# remain length: 95
# remain length: 94
# remain length: 93
# remain length: 92
# remain length: 91
# remain length: 90
# remain length: 89
# remain length: 88
# remain length: 87
# remain length: 86
# remain length: 85
# remain length: 84
# remain length: 83
# remain length: 82
# remain length: 81
# remain length: 80
# remain length: 79
# remain length: 78
# remain length: 77
# remain length: 76
# remain length: 75
# remain length: 74
# remain length: 73
# remain length: 72
# remain length: 71
# remain length: 70
# remain length: 69
# remain length: 68
# remain length: 67
# remain length: 66
# remain length: 65
# remain length: 64
# remain length: 63
# remain length: 62
# remain length: 61
# remain length: 60
# remain length: 59
# remain length: 58
# remain length: 57
# remain length: 56
# remain length: 55
# remain length: 54
# remain length: 53
# remain length: 52
# remain length: 51
# remain length: 50
# remain length: 49
# remain length: 48
# remain length: 47
# remain length: 46
# remain length: 45
# remain length: 44
# remain length: 43
# remain length: 42
# remain length: 41
# remain length: 40
# remain length: 39
# remain length: 38
# remain length: 37
# remain length: 36
# remain length: 35
# remain length: 34
# remain length: 33
# remain length: 32
# remain length: 31
# remain length: 30
# remain length: 29
# remain length: 28
# remain length: 27
# remain length: 26
# remain length: 25
# remain length: 24
# remain length: 23
# remain length: 22
# remain length: 21
# remain length: 20
# remain length: 19
# remain length: 18
# remain length: 17
# remain length: 16
# remain length: 15
# remain length: 14
# remain length: 13
# remain length: 12
# remain length: 11
# remain length: 10
# remain length: 9
# remain length: 8
# remain length: 7
# remain length: 6
# remain length: 5
# remain length: 4
# remain length: 3
# remain length: 2
# remain length: 1
# remain length: 0

# %%
v = pd.DataFrame(ans_value)
v['label'] = ans_label
ann1  = v.groupby("label").mean()

# %%
v1 = pd.DataFrame(true_label)
v1['label'] = ans_label
meta1 = v1.groupby("label").max()

# %%
meta1.shape
# Out:
# (31523, 1)

# %%
meta1.values
# Out:
# array([['CD8Tex'],
#        ['CD8Tex'],
#        ['CD8Tcm'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
adata = anndata.AnnData(ann1)
adata.raw = adata
# same as adata = adata[:,adata.var['highly_variable']] but inplace
sc.tl.pca(
    adata,
    n_comps=50
)
sc.pp.neighbors(adata,
                n_neighbors=10,
                n_pcs=50,
                random_state=1234
                )
sc.tl.diffmap(adata,random_state=1234)
sc.tl.umap(adata,random_state=1234)
sc.tl.leiden(adata,random_state=1234)
sc.tl.paga(adata, groups='leiden')
# Out:
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_9796/220074476.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = anndata.AnnData(ann1)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
list(meta1)
# Out:
# [0]

# %%
adata.obs['celltype'] = meta1.values.tolist()

# %%
adata.obs
# Out:
#       leiden  celltype
# label
# 0          2  [CD8Tex]
# 1          2  [CD8Tex]
# 2          0  [CD8Tcm]
# 3          2  [CD8Tcm]
# 4          6       [B]
# ...      ...       ...
# 31518      1       [B]
# 31519      5       [B]
# 31520     12       [B]
# 31521     14       [B]
# 31522      3       [B]
#
# [31523 rows x 2 columns]

# %%
sc.pl.umap(adata, color="leiden")
# Out:
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
import argparse
import json
import logging
import os
import math
import numpy as np
import torch
import torch.utils.data as data
from tqdm import tqdm

import optim
# from config import config_args
from datasets.hc_dataset import HCDataset
from datasets.loading import load_data
from model.hyphc import HypHC
from utils.metrics import dasgupta_cost
from utils.training import add_flags_from_config, get_savedir

import networkx as nx

import matplotlib.pyplot as plt
from mst import mst

from utils.poincare import project,hyp_dist_djj
from utils.lca import hyp_lca
from utils.math import arctanh, tanh, arcosh

from utils.visualization import plot_tree_from_leaves,plot_geodesic



from utils.lca import hyp_lca

def hyp_lca_numpy(x, y):
    """Computes the hyperbolic LCA in numpy."""
    x = torch.from_numpy(x).view((1, 2))
    y = torch.from_numpy(y).view((1, 2))
    lca = hyp_lca(x, y, return_coord=True)
    return lca.view((2,)).numpy()
def is_leaf(tree, node):
    """check if node is a leaf in tree."""
    return len(list(tree.neighbors(node))) == 0
def complete_tree(tree, leaves_embeddings):
    """Get embeddings of internal nodes from leaves' embeddings using LCA construction."""

    def _complete_tree(embeddings, node):
        children = list(tree.neighbors(node))
        if len(children) == 2:
            left_c, right_c = children
            left_leaf = is_leaf(tree, left_c)
            right_leaf = is_leaf(tree, right_c)
            if left_leaf and right_leaf:
                pass
            elif left_leaf and not right_leaf:
                embeddings = _complete_tree(embeddings, right_c)
            elif right_leaf and not left_leaf:
                embeddings = _complete_tree(embeddings, left_c)
            else:
                embeddings = _complete_tree(embeddings, right_c)
                embeddings = _complete_tree(embeddings, left_c)
            embeddings[node] = hyp_lca_numpy(embeddings[left_c], embeddings[right_c])
        return embeddings

    n = leaves_embeddings.shape[0]
    tree_embeddings = np.zeros((2 * n - 1, 2))
    tree_embeddings[:n, :] = leaves_embeddings
    root = max(list(tree.nodes()))
    tree_embeddings = _complete_tree(tree_embeddings, root)
    return tree_embeddings
def train(model,dataloader,optimizer,similarities,epoches):
    best_cost = np.inf
    best_model = None
    counter = 0
    for epoch in range(epoches):
        model.train()
    total_loss = 0.0
    with tqdm(total=len(dataloader), unit='ex') as bar:
        for step, (triple_ids, triple_similarities) in enumerate(dataloader):
            # triple_ids = triple_ids.cuda()
            # triple_similarities = triple_similarities.cuda()
            loss = model.loss(triple_ids, triple_similarities)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            bar.update(1)
            bar.set_postfix(loss=f'{loss.item():.6f}')
            total_loss += loss
    total_loss = total_loss.item() / (step + 1.0)
    print("\t Epoch {} | average train loss: {:.6f}".format(epoch, total_loss))

    # keep best embeddings
    if (epoch + 1) % 1 == 0:
        tree = model.decode_tree(fast_decoding=1)
        cost = dasgupta_cost(tree, similarities)
        logging.info("{}:\t{:.4f}".format("Dasgupta's cost", cost))
        if cost < best_cost:
            counter = 0
            best_cost = cost
            best_model = model.state_dict()
        else:
            counter += 1
            if counter == 20:
#                 logging.info("Early stopping.")
                return

    # anneal temperature
    if (epoch + 1) % 30 == 0:
        model.anneal_temperature(0.5)
#         logging.info("Annealing temperature to: {}".format(model.temperature))
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.5
            lr = param_group['lr']
        print("Annealing learning rate to: {}".format(lr))

    print("Optimization finished.")
    if best_model is not None:
        # load best model
        model.load_state_dict(best_model)
def dist(x,y):
    return arcosh(1+ 2*( (x-y).norm(dim=-1, p=2, keepdim=True))/((1- y.norm(dim=-1, p=2, keepdim=True))*(1- x.norm(dim=-1, p=2, keepdim=True))));
def plot_tree_from_leaves_djj_1(ax, tree, leaves_embeddings, labels, color_seed=1234):
    """Plots a tree on leaves embeddings using the LCA construction."""
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)
    n = leaves_embeddings.shape[0]
    embeddings = complete_tree(tree, leaves_embeddings)
    colors = get_colors(labels, color_seed)
    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)
    
    for n1, n2 in tree.edges():
        x1 = embeddings[n1]
        x2 = embeddings[n2]
        plot_geodesic(x1, x2, ax)
    # ax.set_xlim(-1.05, 1.05)
    # ax.set_ylim(-1.05, 1.05)
    ax.axis("off")
    return ax
def sl_np_mst_ij(xs, S):
    xs = project(xs).detach().cpu()

    xs0 = xs[None, :, :]
    xs1 = xs[:, None, :]
    sim_mat = S(xs0, xs1)  # (n, n)
    similarities = sim_mat.numpy()
    n = similarities.shape[0]
    similarities=similarities.astype('double')
    ij, _ = mst.mst(similarities, n)
    return ij
class  UnionFind:
    
    def __init__(self, n , pos , c):
        self.n = n
        self.pos = pos
        self.c = c
        self.parent = [i for i in range(n)]
        self.rank = [0 for i in range(n)]
        self.vis = [0 for i in range(2*n-1)]
        self.vis2 = [0 for i in range(2*n-1)]
        self.mer = [-1 for i in range(2*n-1)]
        self._next_id = n
        self._tree = [-1 for i in range(2*n-1)]

        self._id = [i for i in range(n)]

    def _find(self, i):
        if self.parent[i] == i:
            return i
        else:
            self.parent[i] = self._find(self.parent[i])
            return self.parent[i]

    def find(self, i):
        if (i < 0) or (i > self.n):
            raise ValueError("Out of bounds index.")
        return self._find(i)

    def union(self,  i,  j, k=True):
        root_i = self._find(i)
        root_j = self._find(j)
        if root_i == root_j:
            return False
        else:
            
            if self.rank[root_i] < self.rank[root_j]:
                self.parent[root_i] = root_j
                if(k):
                    self._build(root_j, root_i)
                
            elif self.rank[root_i] > self.rank[root_j]:
                self.parent[root_j] = root_i
                if(k):
                    self._build(root_i, root_j)
                
            else:
                
                self.parent[root_j] = root_i
                self.rank[root_i] += 1
                if(k):
                    self._build(root_i, root_j)
                
            return True


    def merge(self,ij):
        for k in range(ij.shape[0]):
            a=ij[k,0];
            b=ij[k,1];
            if(self.mer[a]!=-1):
                a=self.mer[a];
            if(self.mer[b]!=-1):
                b=self.mer[b];
            self.union(a, b)

    def  _build(self, i, j):
#         print(self._tree[0],"----")
#         if(dist(self.pos[self._id[i]],self.pos[self._id[j]])<self.c):
            
            
#             print(i,j,'-',self._id[i],self._id[j]);
#             self.vis[self._id[i]]=1;
#             self.vis[self._id[j]]=1;
                
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self.pos[self._id[i]] = torch.tensor(new);
#             self.pos[self._id[j]] = torch.tensor(new);
            
#             self.search(self._id[i]);
#             self.search(self._id[j]);

#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
            
#         else:
            
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
        self.vis2[i]=1;
        self.vis2[j]=1;
        
        t=np.array(self.pos).tolist()
        new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
        t.append(new);
        self.pos=torch.tensor(t)
        
        self._tree[self._id[i]] = self._next_id
        self._tree[self._id[j]] = self._next_id
        self._id[i] = self._next_id
        self.check(i);
        self._next_id += 1

    def search(self,k):
#         for i in range(len(self.parent)):
#             if(self.parent[i]==k):
#                 self.parent[i]=self._next_id;
#         print(k==-1)

        for i in range(len(self._tree)):
            if(self.vis[i]):
                continue;            
            if(self._tree[i]==k):
                # print("sear")
                self._tree[i]=self._next_id;  
                
        for i in range(len(self._id)):
            if(self.vis[i]):
                continue;
            if(self._id[i]==k):
                # print("Sear")
                self._id[i]=self._next_id;  
                
    def check(self,t):
        minnum=math.inf
        minns=None;
        for i in range(self.n):
            if(self.vis[i] or self.vis2[i]):
                continue;
            distance = dist(self.pos[i],self.pos[-1]);
            if(distance<self.c and distance < minnum):
                minnum = distance
                minns = i;
                
#                 print("merge {} in {}".format(i,t))
#                 self.parent[i]=t;
#                 self.vis[i]=1;
#                 self.search(i);
        if(minns != None):
            # print("merge {} in {}".format(minns,self._next_id))
            self.vis[minns]=1;
            self.rank[minns]=-1;
            self.pos[minns] = self.pos[-1]
#             self.search(minns);
            self.mer[minns]=t;
            self.mer[self._next_id] = minns;
#             self.union(t,minns,False);
        
    def parent(self):
        return [self.parent[i] for i in range(self.n)]

    def tree(self):
        return [self._tree[i] for i in range(len(self._tree))]
def get_colors(y, color_seed=1234):
    """random color assignment for label classes."""
    np.random.seed(color_seed)
    colors = {}
    for k in np.unique(y):
        r = np.random.random()
        b = np.random.random()
        g = np.random.random()
        colors[k] = (r, g, b)
    return [colors[k] for k in y]


def get_Hyper_tree(data_path,start,end,lable,epoches,model_path=None,save_path='./',c=-1):
    np.random.seed(1234)
    torch.manual_seed(1234)
    # x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
    x, y_true, similarities = load_data(data_path,start,end,lable)
    print("{} length:{}".format(data_path,len(y_true)));
    dataset = HCDataset(x, y_true, similarities, num_samples=50000)
    dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
    if(model_path ==None):
        model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
        model.to("cpu")
        Optimizer = getattr(optim, 'RAdam')
        optimizer = Optimizer(model.parameters(),0.0005)
        train(model,dataloader,optimizer,similarities,epoches);
        torch.save(model,save_path+'model.pth');
    else:
        params = torch.load((model_path), map_location=torch.device('cpu'))
        model.load_state_dict(params, strict=False)
    model.eval()
    sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
    n=len(x);
    d = model.normalize_embeddings(model.embeddings.weight.data)
    d = project(d).detach().cpu()
    ijs = sl_np_mst_ij(d,sim_fn)
    uf = UnionFind(n,d,c)
    uf.merge(ijs)
    count=0

    tree = nx.DiGraph()
    for i, j in enumerate(uf.tree()[:-1]):
        if(j!=-1):
            tree.add_edge(j, i)
            
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(111)
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)

    n = len(d)
    embeddings = np.array(uf.pos)
    # for i in range(len(embeddings)):
    #     if(np.isnan(embeddings[i][0]) or embeddings[i][0] + embeddings[i][1] == 0):
    #         embeddings[i] = embeddings[i-1];
    #     pass;
    # print(embeddings)
    where_are_NaNs = np.isnan(embeddings)
    embeddings[where_are_NaNs] = 0
    vis = uf.vis
    # xlist=[]
    # ylist=[]
    # labels=[]

    # for i in range(n):
    #     if(uf.vis[i]!=1):
    #         xlist.append(embeddings[i,0]*20);
    #         ylist.append(embeddings[i,1]*20);
    #         labels.append(y_true[i]);
    # # colors = get_colors(labels, 1234)
    colors = get_colors(y_true, 1234)

    # ax.scatter(xlist, ylist, c=colors, s=50, alpha=0.6)

    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)

    for i in range(len(embeddings)):
        if(i<n):
            continue;
        if(uf.mer[i]!=-1):
            # print(i,'pass')
            pass;
        else:
            ax.scatter(embeddings[i][0]*20,embeddings[i][1]*20,color='black',s=20,alpha=0.7)

        

    for n1, n2 in tree.edges():
    #     if(uf.vis[n1]== 1 or uf.vis[n2]== 1 ):
    # #         print("1")
    #         pass
    #     else:
    #         x1 = embeddings[n1]
    #         x2 = embeddings[n2]
    # #         if(n1>=n):
    # #             if(uf.mer[n1]!=-1):
    # #                 pass;
    # #             else:
    # #                 count+=1;
    # #         if(n2>n):
    # #             if(uf.mer[n1]!=-1):
    # # # 
    # #                 pass;
    # #             else:
    # # #                 ax.scatter(x2[0]*20,x2[1]*20,color='black',s=20,alpha=0.7)
    # #                 count+=1
        
        
    #         plot_geodesic(x1, x2, ax)
    # #         print(x1,x2,n1,n2)
    # #         break
    #         pass

    #     ax.axis("off")
        x1 = embeddings[n1];
        x2 = embeddings[n2];
        plot_geodesic(x1,x2,ax)
    fig.savefig(save_path+"graph.png");
    np.save(save_path+"dataxy.npy",embeddings)
    np.save(save_path+"datalink.npy",list(tree.edges()))
    np.save(save_path+"datamerge.npy",uf.mer)

# %%
def cccfg(
        adata,
        gene_list,
        save_path="./",
    ):
    groupby = adata.uns["capital"]["tree"]["annotation"]
    filtered_data = adata.raw.to_adata()[:]
    filtered_data.to_df().to_csv(save_path+"data_cell.csv");
    adata.obs.to_csv(save_path+"data_type.csv")
    cluster_centroid_data = np.empty((0, filtered_data.n_vars))
    clustername = filtered_data.obs[groupby].unique().tolist()

    for i in clustername:
        a_cluster_data = filtered_data[filtered_data.obs[groupby] == "{}".format(
            i)].to_df()
        a_cluster_median = a_cluster_data.mean(axis=0).values
        cluster_centroid_data = np.vstack(
            (cluster_centroid_data, a_cluster_median)
        )
    cluster_centroid = pd.DataFrame(
        cluster_centroid_data,
        index=clustername,
        columns=filtered_data.var_names
    )
    cluster_centroid.to_csv(save_path+"datas.data",header=None);
    cluster_centroid.to_csv(save_path+"datas.csv");

    return cluster_centroid

# %%
set_initial_condition(adata)

# %%
cccfg(adata,'','./datas/merge3/')
# Out:
#          0         1         2         3         4         5         6    \
# 2   0.033355  0.076612  0.003535  0.668406  0.055588  0.002564  0.009167
# 0   0.032277  0.154226  0.007941  0.145200  0.097371  0.003728  0.000000
# 8   0.047603  0.020748  0.131156  ...  0.000485  1.206089  0.003241  0.000000
# 12  0.070920  0.022856  0.203750  ...  0.000000  0.653131  0.000759  0.000000
# 13  0.226880  0.002137  0.009108  ...  0.000311  0.065524  0.004976  0.006155
# 15  0.040696  0.000000  0.003908  ...  0.001492  0.016943  0.141430  0.000000
# 4   0.029744  0.000132  0.002857  ...  0.186221  0.016986  0.151159  0.000961
# 9   0.027786  0.000000  0.004614  ...  0.001393  0.032148  0.494199  0.001340
# 19  0.038118  0.003023  0.112771  ...  0.000000  1.289951  0.000000  0.000000
# 16  0.014835  0.000888  0.003513  ...  0.000000  0.030185  0.109749  0.000000
# 11  0.078090  0.000190  0.011437  ...  0.001564  0.034598  0.009794  0.000164
# 18  0.225153  0.035039  0.154631  ...  0.000000  0.535004  0.003595  0.000000
# 23  0.028075  0.000000  0.020292  ...  0.000000  0.084962  0.017770  0.000000
# 24  0.071921  0.000000  0.087151  ...  0.000000  0.543438  0.000000  0.193973
# 25  0.126536  0.000000  0.000000  ...  0.231535  0.000000  0.154034  0.000000
#
#          507       508       509       510       511       512
# 2   0.003993  0.236335  0.000699  0.002943  0.000295  0.047829
# 0   0.000000  0.241416  0.000000  0.006783  0.000544  0.002872
# 6   0.000000  0.001797  0.000000  0.006741  0.001862  0.002790
# 5   0.007871  0.237711  0.000594  0.006375  0.000000  0.006618
# 7   0.000000  0.009266  0.001550  0.009248  0.006396  0.853399
# 20  0.000000  0.011876  0.001244  0.197676  0.000000  0.008192
# 3   0.000000  0.027938  0.000358  0.044310  0.000000  0.000000
# 22  0.000000  0.015283  0.000000  0.173713  0.000000  0.000000
# 1   0.000000  0.003267  0.000109  0.147331  0.000510  0.008443
# 21  0.000000  0.001329  0.000000  0.001905  0.000000  0.005121
# 14  0.000000  0.001529  0.000989  0.008553  0.028950  0.589604
# 17  0.000000  0.001864  0.000000  0.497344  0.000000  0.000330
# 10  0.000000  0.039367  0.001535  0.011767  0.000000  0.002060
# 8   0.036420  0.343312  0.001264  0.014684  0.000000  0.008444
# 12  0.000000  0.252003  0.000000  0.030477  0.000000  0.006746
# 13  0.000000  0.012038  0.000000  0.019395  0.000000  0.012925
# 15  0.000000  0.004300  0.006035  0.909445  0.000000  0.006052
# 4   0.000000  0.006020  0.112716  0.019774  0.000000  0.004191
# 9   0.000000  0.016522  0.000830  0.722726  0.000000  0.002687
# 19  0.045563  0.028257  0.000000  0.014180  0.001293  0.317881
# 16  0.001978  0.005403  0.000000  0.076620  0.000712  0.002980
# 11  0.000000  0.030604  0.001291  0.225918  0.001841  0.005566
# 18  0.001107  0.175250  0.000000  0.090007  0.000000  0.023890
# 23  0.000000  0.009020  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.163640  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.122696  1.381750  0.000000  0.000000
#
# [26 rows x 513 columns]

# %%
x, y_true, similarities = load_data('./datas/merge3/datas.data',1,514,0)
data_path = './datas/merge3/datas.data'
start = 1
end =514
lable = 0
model_path = None;
save_path = './datas/merge3/'
epoches=10
c=-1
np.random.seed(1234)
torch.manual_seed(1234)
# x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
x, y_true, similarities = load_data(data_path,start,end,lable)
print("{} length:{}".format(data_path,len(y_true)));
dataset = HCDataset(x, y_true, similarities, num_samples=50000)
dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
if(model_path ==None):
    model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
    model.to("cpu")
    Optimizer = getattr(optim, 'RAdam')
    optimizer = Optimizer(model.parameters(),0.0005)
    train(model,dataloader,optimizer,similarities,epoches);
    torch.save(model,save_path+'model.pth');
else:
    params = torch.load((model_path), map_location=torch.device('cpu'))
    model.load_state_dict(params, strict=False)
model.eval()
sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
n=len(x);
d = model.normalize_embeddings(model.embeddings.weight.data)
d = project(d).detach().cpu()
ijs = sl_np_mst_ij(d,sim_fn)
uf = UnionFind(n,d,c)
uf.merge(ijs)
count=0
# Out:
# ./datas/merge3/datas.data length:26
# Generating all pairs superset
# 100%|██████████| 1563/1563 [01:00<00:00, 25.90ex/s, loss=1.368644]
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_9796/836080252.py:147: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ij, _ = mst.mst(similarities, n)
# 	 Epoch 9 | average train loss: 1.424096
# Optimization finished.

# %%
from alignment import node
from alignment import show_tree
embeddings = np.array(uf.pos)

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break

# %%
def search_tree(now,c):
    if(len(now.son) != 2):
        return now;
    lson = search_tree(now.son[0],c);
    now.son[0] = lson;
    rson = search_tree(now.son[1],c);
    now.son[1] = rson
    # lson = now.son[0]
    # rson = now.son[1]
    if(np.linalg.norm(lson.value-rson.value)<=c):
        if(len(lson.son)>1 and len(rson.son)>1):
            pass
        elif(len(lson.son)>1):
            print(rson.name,lson.name)
            now = rson;
            now.son.append(lson);
        else:
            print(rson.name,lson.name)
            now = lson;
            now.son.append(rson)
    # exit(0)
    return now;

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break
show_tree(nodes1[-1]).show_fig()

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break
# show_tree(nodes1[-1]).show_fig()

search_tree(nodes1[-1],0.02)
show_tree(nodes1[-1]).show_fig()
# Out:
# 20 11
# 11 21
# 21 17
# 16 8
# 10 4
# 19 12
# 22 3
# 3 0
# 0 23
# 23 13

# %%
adata.obs.groupby('leiden').max()
# Out:
#                 celltype
# leiden
# 0            [Malignant]
# 1            [Malignant]
# 2               [Plasma]
# 3            [Malignant]
# 4            [Malignant]
# 5               [Plasma]
# 6                 [Mast]
# 7                 [Mast]
# 8            [Malignant]
# 9       [Myofibroblasts]
# 10              [Plasma]
# 11           [Malignant]
# 12             [Tprolif]
# 13              [Plasma]
# 14                [Mast]
# 15              [Plasma]
# 16           [Malignant]
# 17           [Malignant]
# 18           [Malignant]
# 19             [Tprolif]
# 20           [Malignant]
# 21                [Mast]
# 22           [Malignant]
# 23              [CD8Tex]
# 24           [Malignant]
# 25           [Malignant]

# %%
ann1.to_csv("./datas/merge3/ann1.csv")
meta1.to_csv("./datas/merge3/meta1.csv")

# %%
12 - 21  0.001
23 - 25 0.002
1  - 18 0.0025
7 - 19 0.003
20 - 0 0.004
0-1 1-6 0.0081
22 - 13 0.012
24 -4 0.014
11 -8 0.017
23 -10 0.0185
33 - 15 0.01\
