# %%
from read_data import *
from hyper import *
from alignment import *
from datasets.preprecossing import *

# %%
datas = pd.read_csv("./datas/data1/data_cell.csv").set_index("Unnamed: 0")
datas
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...  CD300LG       CD7  ELN     FCER2  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...      0.0  0.000000  0.0  1.262537
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...      0.0  0.000000  0.0  0.761836
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...      0.0  0.000000  0.0  0.000000
# ...                               ...  ...      ...       ...  ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...      0.0  0.817762  0.0  0.000000
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...      0.0  0.000000  0.0  0.000000
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...      0.0  0.000000  0.0  0.000000
#
#                              KIR2DL1     NELL2  CA4  SOD3  CCL17  FCGR3A
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAAGATGCAGCGAACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACCATGTCCTAGTGA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AACTCAGGTGTGACCC      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC      0.0  0.000000  0.0   0.0    0.0     0.0
# ...                              ...       ...  ...   ...    ...     ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGCCCTACAACGCACC      0.0  1.109585  0.0   0.0    0.0     0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA      0.0  0.621233  0.0   0.0    0.0     0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA      0.0  0.000000  0.0   0.0    0.0     0.0
# sc5rJUQ064_CTCATTAGTAAATACG      0.0  0.000000  0.0   0.0    0.0     0.0
#
# [33043 rows x 513 columns]

# %%
adata1 = datas.copy()
adata1.loc[list(celltype['Cell']), 'Celltype'] = list(celltype['Celltype (minor-lineage)'])
adata1
# Out:
#                              APOE    TNFSF8  MFAP4  HLA-DPA1  RP11-796E2.4  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT   0.0  0.000000    0.0  1.757945           0.0
# sc5rJUQ024_AAAGATGCAGCGAACA   0.0  0.000000    0.0  1.522635           0.0
# sc5rJUQ024_AACCATGTCCTAGTGA   0.0  0.761836    0.0  1.410930           0.0
# sc5rJUQ024_AACTCAGGTGTGACCC   0.0  0.000000    0.0  1.222122           0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC   0.0  0.000000    0.0  1.094174           0.0
# ...                           ...       ...    ...       ...           ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT   0.0  0.000000    0.0  1.632651           0.0
# sc5rJUQ060_TGCCCTACAACGCACC   0.0  0.000000    0.0  1.109585           0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA   0.0  0.000000    0.0  0.621233           0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA   0.0  0.000000    0.0  0.609237           0.0
# sc5rJUQ064_CTCATTAGTAAATACG   0.0  0.000000    0.0  0.000000           0.0
#
#                              CTD-2587M2.1  KIR3DL1  IGLV3-21  TRAV36DV7  \
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAAGATGCAGCGAACA           0.0      0.0  0.828858        0.0
# sc5rJUQ024_AACCATGTCCTAGTGA           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AACTCAGGTGTGACCC           0.0      0.0  0.000000        0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC           0.0      0.0  0.000000        0.0
# ...                                   ...      ...       ...        ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGCCCTACAACGCACC           0.0      0.0  0.000000        0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA           0.0      0.0  0.000000        0.0
# sc5rJUQ064_CTCATTAGTAAATACG           0.0      0.0  0.000000        0.0
#
#                                TESPA1  ...       CD7  ELN     FCER2  KIR2DL1  \
# Unnamed: 0                             ...
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  ...  0.000000  0.0  1.262537      0.0
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  ...  0.000000  0.0  0.761836      0.0
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  ...  0.000000  0.0  0.000000      0.0
# ...                               ...  ...       ...  ...       ...      ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGCCCTACAACGCACC  0.000000  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.000000  ...  0.817762  0.0  0.000000      0.0
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.425277  ...  0.000000  0.0  0.000000      0.0
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  ...  0.000000  0.0  0.000000      0.0
#
#                                 NELL2  CA4  SOD3  CCL17  FCGR3A  Celltype
# Unnamed: 0
# sc5rJUQ024_AAACCTGGTCTCCACT  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAAGATGCAGCGAACA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACCATGTCCTAGTGA  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AACTCAGGTGTGACCC  0.000000  0.0   0.0    0.0     0.0         B
# sc5rJUQ024_AAGACCTGTCCGTGAC  0.000000  0.0   0.0    0.0     0.0         B
# ...                               ...  ...   ...    ...     ...       ...
# sc5rJUQ060_TGAGAGGAGTCCTCCT  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGCCCTACAACGCACC  1.109585  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ060_TGTTCCGAGAGCCCAA  0.621233  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_AGTTGGTGTGCAGACA  0.000000  0.0   0.0    0.0     0.0   Tprolif
# sc5rJUQ064_CTCATTAGTAAATACG  0.000000  0.0   0.0    0.0     0.0   Tprolif
#
# [33043 rows x 514 columns]

# %%
celltype  = cell_type1 = pd.read_csv("../../../capital/docs/tutorials/BRCA_EMTAB8107_CellMetainfo_table.tsv",sep="\t")
celltype
# Out:
#                               Cell     UMAP_1    UMAP_2  Cluster  \
# 0      sc5rJUQ024_AAACCTGGTCTCCACT  12.136345 -2.121436        5
# 1      sc5rJUQ024_AAAGATGCAGCGAACA -15.524519 -7.638500        5
# 2      sc5rJUQ024_AACCATGTCCTAGTGA -15.595183 -6.820365        5
# 3      sc5rJUQ024_AACTCAGGTGTGACCC -15.779087 -7.584647        5
# 4      sc5rJUQ024_AAGACCTGTCCGTGAC -14.804107 -7.505053        5
# ...                            ...        ...       ...      ...
# 33038  sc5rJUQ060_TGAGAGGAGTCCTCCT  -7.984505 -1.166239       15
# 33039  sc5rJUQ060_TGCCCTACAACGCACC  -7.716203 -1.429827       15
# 33040  sc5rJUQ060_TGTTCCGAGAGCCCAA  -7.371503 -1.509427       15
# 33041  sc5rJUQ064_AGTTGGTGTGCAGACA -13.337872  0.405348       15
# 33042  sc5rJUQ064_CTCATTAGTAAATACG   2.797375  9.734141       15
#
#       Celltype (malignancy) Celltype (major-lineage) Celltype (minor-lineage)  \
# 0              Immune cells                        B                        B
# 1              Immune cells                        B                        B
# 2              Immune cells                        B                        B
# 3              Immune cells                        B                        B
# 4              Immune cells                        B                        B
# ...                     ...                      ...                      ...
# 33038         Stromal cells                  Tprolif                  Tprolif
# 33039         Stromal cells                  Tprolif                  Tprolif
# 33040         Stromal cells                  Tprolif                  Tprolif
# 33041         Stromal cells                  Tprolif                  Tprolif
# 33042         Stromal cells                  Tprolif                  Tprolif
#
#       Patient    Sample Tissue
# 0         P41  Sample41  Tumor
# 1         P41  Sample41  Tumor
# 2         P41  Sample41  Tumor
# 3         P41  Sample41  Tumor
# 4         P41  Sample41  Tumor
# ...       ...       ...    ...
# 33038     P53  Sample53  Tumor
# 33039     P53  Sample53  Tumor
# 33040     P53  Sample53  Tumor
# 33041     P54  Sample54  Tumor
# 33042     P54  Sample54  Tumor
#
# [33043 rows x 10 columns]

# %%
from scipy.spatial import KDTree
ans_value = []
ans_label = []
true_label = [];
now_labels = adata1['Celltype'].tolist();
c= 13
r= 5
now_label = 0;
now =  datas.values;
while len(now) != 0:
    rnd = np.random.randint(now.shape[0], size=1);
    rand_choice = now[rnd, :].reshape(-1)
    tree = KDTree(now);
    indices = tree.query_ball_point(rand_choice,r)
    points_within_k = now[indices]
    now = now.tolist();
    if(len(points_within_k)-1 < c):
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now_label +=1
            now.remove(i.tolist());
            true_label.append(now_labels[int(rnd)])
    else:
        for i in points_within_k:
            ans_value.append(i.tolist())
            ans_label.append(now_label);
            now.remove(i.tolist());            
            true_label.append(now_labels[int(rnd)])
        now_label+=1;
    now = np.array(now);
    print("remain length: {}".format(len(now)))
    # for i in points_within_k:
    #     if(i == rand_choice).all():
    #         continue;
        
    # now.remove(rand_choice)
    # now.tolist().remove(rand_choice.tolist())
    # now = np.array(now)
    # break
# rand_choice == now
np.save('./datas/try/c_{}_r_{}_label.npy'.format(c,r),np.array(ans_label))
np.save('./datas/try/c_{}_r_{}_value.npy'.format(c,r),np.array(ans_value))
# Out:
# remain length: 33030
# remain length: 33029
# remain length: 33028
# remain length: 33027
# remain length: 32873
# remain length: 32839
# remain length: 30766
# remain length: 26612
# remain length: 26611
# remain length: 26552
# remain length: 26551
# remain length: 25776
# remain length: 25764
# remain length: 25763
# remain length: 25762
# remain length: 25761
# remain length: 25749
# remain length: 25748
# remain length: 25747
# remain length: 25746
# remain length: 25529
# remain length: 25528
# remain length: 25527
# remain length: 24727
# remain length: 24721
# remain length: 24717
# remain length: 24716
# remain length: 24715
# remain length: 24714
# remain length: 24713
# remain length: 24712
# remain length: 24711
# remain length: 24710
# remain length: 24459
# remain length: 24458
# remain length: 24457
# remain length: 24455
# remain length: 24454
# remain length: 24221
# remain length: 24220
# remain length: 24219
# remain length: 24218
# remain length: 24217
# remain length: 24216
# remain length: 24215
# remain length: 24214
# remain length: 24213
# remain length: 24212
# remain length: 24211
# remain length: 24210
# remain length: 24209
# remain length: 24208
# remain length: 24207
# remain length: 24206
# remain length: 24205
# remain length: 24204
# remain length: 24203
# remain length: 23994
# remain length: 23993
# remain length: 23992
# remain length: 23991
# remain length: 23990
# remain length: 23989
# remain length: 23988
# remain length: 23987
# remain length: 23986
# remain length: 23985
# remain length: 23984
# remain length: 23983
# remain length: 23924
# remain length: 23923
# remain length: 23922
# remain length: 23921
# remain length: 23920
# remain length: 23919
# remain length: 23918
# remain length: 23917
# remain length: 23916
# remain length: 23915
# remain length: 23914
# remain length: 23654
# remain length: 23433
# remain length: 23432
# remain length: 23431
# remain length: 23430
# remain length: 23429
# remain length: 22916
# remain length: 22915
# remain length: 22914
# remain length: 22913
# remain length: 22912
# remain length: 22911
# remain length: 22910
# remain length: 22909
# remain length: 22908
# remain length: 22907
# remain length: 22904
# remain length: 22903
# remain length: 22902
# remain length: 22901
# remain length: 22900
# remain length: 22899
# remain length: 22898
# remain length: 22897
# remain length: 22896
# remain length: 22895
# remain length: 22790
# remain length: 22789
# remain length: 22788
# remain length: 22787
# remain length: 22786
# remain length: 22763
# remain length: 22762
# remain length: 22761
# remain length: 22760
# remain length: 22759
# remain length: 22667
# remain length: 22666
# remain length: 22665
# remain length: 22659
# remain length: 22548
# remain length: 22547
# remain length: 22546
# remain length: 22545
# remain length: 22541
# remain length: 22463
# remain length: 22462
# remain length: 22452
# remain length: 22451
# remain length: 20830
# remain length: 20829
# remain length: 20828
# remain length: 20827
# remain length: 20826
# remain length: 20825
# remain length: 20824
# remain length: 20823
# remain length: 20822
# remain length: 20821
# remain length: 20820
# remain length: 20819
# remain length: 20818
# remain length: 20817
# remain length: 20816
# remain length: 20815
# remain length: 20814
# remain length: 20813
# remain length: 20812
# remain length: 20811
# remain length: 20810
# remain length: 20809
# remain length: 20808
# remain length: 20807
# remain length: 20806
# remain length: 20805
# remain length: 20804
# remain length: 20803
# remain length: 20802
# remain length: 20801
# remain length: 20800
# remain length: 20799
# remain length: 20798
# remain length: 20797
# remain length: 20796
# remain length: 20795
# remain length: 20793
# remain length: 20792
# remain length: 20791
# remain length: 20785
# remain length: 20784
# remain length: 20783
# remain length: 20782
# remain length: 20779
# remain length: 20778
# remain length: 20759
# remain length: 20758
# remain length: 20757
# remain length: 20756
# remain length: 20755
# remain length: 20754
# remain length: 20753
# remain length: 20752
# remain length: 20751
# remain length: 20750
# remain length: 20749
# remain length: 20748
# remain length: 20747
# remain length: 20746
# remain length: 20745
# remain length: 20744
# remain length: 20742
# remain length: 20741
# remain length: 20740
# remain length: 20737
# remain length: 20736
# remain length: 20735
# remain length: 20731
# remain length: 20730
# remain length: 20729
# remain length: 20728
# remain length: 20727
# remain length: 20726
# remain length: 20725
# remain length: 20724
# remain length: 20723
# remain length: 20722
# remain length: 20721
# remain length: 20720
# remain length: 20718
# remain length: 20717
# remain length: 20716
# remain length: 20705
# remain length: 20704
# remain length: 20703
# remain length: 20702
# remain length: 20701
# remain length: 20700
# remain length: 20699
# remain length: 20698
# remain length: 20695
# remain length: 20694
# remain length: 20693
# remain length: 20692
# remain length: 20691
# remain length: 20690
# remain length: 20689
# remain length: 20688
# remain length: 20687
# remain length: 20686
# remain length: 20684
# remain length: 20683
# remain length: 20682
# remain length: 20681
# remain length: 20680
# remain length: 20679
# remain length: 20678
# remain length: 20677
# remain length: 20676
# remain length: 20666
# remain length: 20665
# remain length: 20664
# remain length: 20663
# remain length: 20662
# remain length: 20661
# remain length: 20660
# remain length: 20657
# remain length: 20656
# remain length: 20653
# remain length: 20652
# remain length: 20649
# remain length: 20648
# remain length: 20647
# remain length: 20646
# remain length: 20645
# remain length: 20644
# remain length: 20643
# remain length: 20642
# remain length: 20641
# remain length: 20640
# remain length: 20639
# remain length: 20638
# remain length: 20607
# remain length: 20606
# remain length: 20605
# remain length: 20604
# remain length: 20603
# remain length: 20602
# remain length: 20591
# remain length: 20590
# remain length: 20589
# remain length: 20588
# remain length: 20587
# remain length: 20586
# remain length: 20585
# remain length: 20584
# remain length: 20583
# remain length: 20582
# remain length: 20581
# remain length: 20580
# remain length: 20579
# remain length: 20578
# remain length: 20577
# remain length: 20576
# remain length: 20575
# remain length: 20574
# remain length: 20573
# remain length: 20572
# remain length: 20571
# remain length: 20570
# remain length: 20569
# remain length: 20568
# remain length: 20567
# remain length: 20566
# remain length: 20565
# remain length: 20563
# remain length: 20558
# remain length: 20557
# remain length: 20555
# remain length: 20516
# remain length: 20515
# remain length: 20414
# remain length: 20413
# remain length: 20412
# remain length: 20411
# remain length: 20339
# remain length: 20338
# remain length: 20337
# remain length: 20336
# remain length: 20335
# remain length: 20334
# remain length: 20333
# remain length: 20325
# remain length: 20324
# remain length: 20323
# remain length: 20322
# remain length: 20321
# remain length: 20320
# remain length: 20319
# remain length: 20318
# remain length: 20317
# remain length: 20316
# remain length: 20315
# remain length: 20304
# remain length: 20303
# remain length: 20302
# remain length: 20301
# remain length: 20300
# remain length: 20299
# remain length: 20298
# remain length: 20297
# remain length: 20296
# remain length: 20295
# remain length: 20294
# remain length: 20293
# remain length: 20292
# remain length: 20290
# remain length: 20289
# remain length: 20288
# remain length: 20287
# remain length: 20285
# remain length: 20258
# remain length: 20257
# remain length: 20256
# remain length: 20255
# remain length: 20254
# remain length: 20253
# remain length: 20252
# remain length: 20251
# remain length: 20250
# remain length: 20249
# remain length: 20248
# remain length: 20247
# remain length: 20234
# remain length: 20230
# remain length: 20228
# remain length: 20227
# remain length: 20226
# remain length: 20222
# remain length: 20221
# remain length: 20216
# remain length: 20212
# remain length: 20186
# remain length: 20185
# remain length: 20184
# remain length: 20167
# remain length: 20166
# remain length: 20165
# remain length: 20164
# remain length: 20137
# remain length: 20136
# remain length: 20135
# remain length: 20134
# remain length: 20133
# remain length: 20132
# remain length: 20131
# remain length: 20130
# remain length: 20129
# remain length: 20128
# remain length: 20127
# remain length: 20126
# remain length: 20125
# remain length: 20124
# remain length: 20123
# remain length: 20120
# remain length: 20112
# remain length: 20111
# remain length: 20110
# remain length: 20109
# remain length: 20108
# remain length: 20107
# remain length: 20106
# remain length: 20105
# remain length: 20104
# remain length: 20102
# remain length: 20099
# remain length: 20098
# remain length: 20097
# remain length: 20064
# remain length: 20056
# remain length: 20055
# remain length: 20054
# remain length: 20053
# remain length: 20052
# remain length: 20051
# remain length: 20050
# remain length: 20049
# remain length: 20048
# remain length: 20047
# remain length: 20046
# remain length: 20045
# remain length: 20044
# remain length: 20039
# remain length: 20038
# remain length: 20037
# remain length: 20036
# remain length: 20032
# remain length: 20031
# remain length: 20027
# remain length: 20026
# remain length: 20025
# remain length: 19994
# remain length: 19993
# remain length: 19984
# remain length: 19983
# remain length: 19982
# remain length: 19981
# remain length: 19980
# remain length: 19979
# remain length: 19978
# remain length: 19977
# remain length: 19976
# remain length: 19975
# remain length: 19974
# remain length: 19954
# remain length: 19953
# remain length: 19952
# remain length: 19951
# remain length: 19950
# remain length: 19949
# remain length: 19948
# remain length: 19947
# remain length: 19946
# remain length: 19945
# remain length: 19909
# remain length: 19908
# remain length: 19907
# remain length: 19906
# remain length: 19905
# remain length: 19904
# remain length: 19903
# remain length: 19902
# remain length: 19901
# remain length: 19900
# remain length: 19899
# remain length: 19898
# remain length: 19897
# remain length: 19896
# remain length: 19895
# remain length: 19894
# remain length: 19893
# remain length: 19892
# remain length: 19891
# remain length: 19890
# remain length: 19889
# remain length: 19888
# remain length: 19887
# remain length: 19886
# remain length: 19885
# remain length: 19884
# remain length: 19869
# remain length: 19868
# remain length: 19867
# remain length: 19866
# remain length: 19865
# remain length: 19864
# remain length: 152
# remain length: 151
# remain length: 150
# remain length: 149
# remain length: 148
# remain length: 147
# remain length: 146
# remain length: 145
# remain length: 144
# remain length: 143
# remain length: 142
# remain length: 141
# remain length: 140
# remain length: 139
# remain length: 138
# remain length: 137
# remain length: 136
# remain length: 135
# remain length: 134
# remain length: 133
# remain length: 132
# remain length: 131
# remain length: 130
# remain length: 129
# remain length: 128
# remain length: 127
# remain length: 126
# remain length: 125
# remain length: 124
# remain length: 123
# remain length: 122
# remain length: 121
# remain length: 120
# remain length: 119
# remain length: 118
# remain length: 117
# remain length: 116
# remain length: 115
# remain length: 114
# remain length: 113
# remain length: 112
# remain length: 111
# remain length: 110
# remain length: 109
# remain length: 108
# remain length: 107
# remain length: 106
# remain length: 105
# remain length: 104
# remain length: 103
# remain length: 102
# remain length: 101
# remain length: 100
# remain length: 99
# remain length: 98
# remain length: 97
# remain length: 96
# remain length: 95
# remain length: 94
# remain length: 93
# remain length: 92
# remain length: 91
# remain length: 90
# remain length: 89
# remain length: 88
# remain length: 87
# remain length: 86
# remain length: 85
# remain length: 84
# remain length: 83
# remain length: 82
# remain length: 81
# remain length: 80
# remain length: 79
# remain length: 78
# remain length: 77
# remain length: 76
# remain length: 75
# remain length: 74
# remain length: 73
# remain length: 72
# remain length: 71
# remain length: 70
# remain length: 69
# remain length: 68
# remain length: 67
# remain length: 66
# remain length: 65
# remain length: 64
# remain length: 63
# remain length: 62
# remain length: 61
# remain length: 60
# remain length: 59
# remain length: 58
# remain length: 57
# remain length: 56
# remain length: 55
# remain length: 54
# remain length: 53
# remain length: 52
# remain length: 51
# remain length: 50
# remain length: 49
# remain length: 48
# remain length: 47
# remain length: 46
# remain length: 45
# remain length: 44
# remain length: 43
# remain length: 42
# remain length: 41
# remain length: 40
# remain length: 39
# remain length: 38
# remain length: 37
# remain length: 36
# remain length: 35
# remain length: 34
# remain length: 33
# remain length: 32
# remain length: 31
# remain length: 30
# remain length: 29
# remain length: 28
# remain length: 27
# remain length: 26
# remain length: 25
# remain length: 24
# remain length: 23
# remain length: 22
# remain length: 21
# remain length: 20
# remain length: 19
# remain length: 18
# remain length: 17
# remain length: 16
# remain length: 15
# remain length: 14
# remain length: 13
# remain length: 12
# remain length: 11
# remain length: 10
# remain length: 9
# remain length: 8
# remain length: 7
# remain length: 6
# remain length: 5
# remain length: 4
# remain length: 3
# remain length: 2
# remain length: 1
# remain length: 0

# %%
v = pd.DataFrame(ans_value)
v['label'] = ans_label
ann1  = v.groupby("label").mean()

# %%
v1 = pd.DataFrame(true_label)
v1['label'] = ans_label
meta1 = v1.groupby("label").max()

# %%
meta1.shape
# Out:
# (20849, 1)

# %%
meta1.values
# Out:
# array([['Tprolif'],
#        ['Tprolif'],
#        ['Tprolif'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
adata = anndata.AnnData(ann1)
adata.raw = adata
# same as adata = adata[:,adata.var['highly_variable']] but inplace
sc.tl.pca(
    adata,
    n_comps=50
)
sc.pp.neighbors(adata,
                n_neighbors=10,
                n_pcs=50,
                random_state=1234
                )
sc.tl.diffmap(adata,random_state=1234)
sc.tl.umap(adata,random_state=1234)
sc.tl.leiden(adata,random_state=1234)
sc.tl.paga(adata, groups='leiden')
# Out:
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_52720/220074476.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = anndata.AnnData(ann1)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
list(meta1)
# Out:
# [0]

# %%
adata.obs['celltype'] = meta1.values.tolist()

# %%
adata.obs
# Out:
#       leiden   celltype
# label
# 0          6  [Tprolif]
# 1          6  [Tprolif]
# 2          6  [Tprolif]
# 3          6  [Tprolif]
# 4          6  [Tprolif]
# ...      ...        ...
# 20844      7        [B]
# 20845      2        [B]
# 20846      1        [B]
# 20847      0        [B]
# 20848      0        [B]
#
# [20849 rows x 2 columns]

# %%
sc.pl.umap(adata, color="leiden")
# Out:
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
import argparse
import json
import logging
import os
import math
import numpy as np
import torch
import torch.utils.data as data
from tqdm import tqdm

import optim
# from config import config_args
from datasets.hc_dataset import HCDataset
from datasets.loading import load_data
from model.hyphc import HypHC
from utils.metrics import dasgupta_cost
from utils.training import add_flags_from_config, get_savedir

import networkx as nx

import matplotlib.pyplot as plt
from mst import mst

from utils.poincare import project,hyp_dist_djj
from utils.lca import hyp_lca
from utils.math import arctanh, tanh, arcosh

from utils.visualization import plot_tree_from_leaves,plot_geodesic



from utils.lca import hyp_lca

def hyp_lca_numpy(x, y):
    """Computes the hyperbolic LCA in numpy."""
    x = torch.from_numpy(x).view((1, 2))
    y = torch.from_numpy(y).view((1, 2))
    lca = hyp_lca(x, y, return_coord=True)
    return lca.view((2,)).numpy()
def is_leaf(tree, node):
    """check if node is a leaf in tree."""
    return len(list(tree.neighbors(node))) == 0
def complete_tree(tree, leaves_embeddings):
    """Get embeddings of internal nodes from leaves' embeddings using LCA construction."""

    def _complete_tree(embeddings, node):
        children = list(tree.neighbors(node))
        if len(children) == 2:
            left_c, right_c = children
            left_leaf = is_leaf(tree, left_c)
            right_leaf = is_leaf(tree, right_c)
            if left_leaf and right_leaf:
                pass
            elif left_leaf and not right_leaf:
                embeddings = _complete_tree(embeddings, right_c)
            elif right_leaf and not left_leaf:
                embeddings = _complete_tree(embeddings, left_c)
            else:
                embeddings = _complete_tree(embeddings, right_c)
                embeddings = _complete_tree(embeddings, left_c)
            embeddings[node] = hyp_lca_numpy(embeddings[left_c], embeddings[right_c])
        return embeddings

    n = leaves_embeddings.shape[0]
    tree_embeddings = np.zeros((2 * n - 1, 2))
    tree_embeddings[:n, :] = leaves_embeddings
    root = max(list(tree.nodes()))
    tree_embeddings = _complete_tree(tree_embeddings, root)
    return tree_embeddings
def train(model,dataloader,optimizer,similarities,epoches):
    best_cost = np.inf
    best_model = None
    counter = 0
    for epoch in range(epoches):
        model.train()
    total_loss = 0.0
    with tqdm(total=len(dataloader), unit='ex') as bar:
        for step, (triple_ids, triple_similarities) in enumerate(dataloader):
            # triple_ids = triple_ids.cuda()
            # triple_similarities = triple_similarities.cuda()
            loss = model.loss(triple_ids, triple_similarities)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            bar.update(1)
            bar.set_postfix(loss=f'{loss.item():.6f}')
            total_loss += loss
    total_loss = total_loss.item() / (step + 1.0)
    print("\t Epoch {} | average train loss: {:.6f}".format(epoch, total_loss))

    # keep best embeddings
    if (epoch + 1) % 1 == 0:
        tree = model.decode_tree(fast_decoding=1)
        cost = dasgupta_cost(tree, similarities)
        logging.info("{}:\t{:.4f}".format("Dasgupta's cost", cost))
        if cost < best_cost:
            counter = 0
            best_cost = cost
            best_model = model.state_dict()
        else:
            counter += 1
            if counter == 20:
#                 logging.info("Early stopping.")
                return

    # anneal temperature
    if (epoch + 1) % 30 == 0:
        model.anneal_temperature(0.5)
#         logging.info("Annealing temperature to: {}".format(model.temperature))
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.5
            lr = param_group['lr']
        print("Annealing learning rate to: {}".format(lr))

    print("Optimization finished.")
    if best_model is not None:
        # load best model
        model.load_state_dict(best_model)
def dist(x,y):
    return arcosh(1+ 2*( (x-y).norm(dim=-1, p=2, keepdim=True))/((1- y.norm(dim=-1, p=2, keepdim=True))*(1- x.norm(dim=-1, p=2, keepdim=True))));
def plot_tree_from_leaves_djj_1(ax, tree, leaves_embeddings, labels, color_seed=1234):
    """Plots a tree on leaves embeddings using the LCA construction."""
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)
    n = leaves_embeddings.shape[0]
    embeddings = complete_tree(tree, leaves_embeddings)
    colors = get_colors(labels, color_seed)
    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)
    
    for n1, n2 in tree.edges():
        x1 = embeddings[n1]
        x2 = embeddings[n2]
        plot_geodesic(x1, x2, ax)
    # ax.set_xlim(-1.05, 1.05)
    # ax.set_ylim(-1.05, 1.05)
    ax.axis("off")
    return ax
def sl_np_mst_ij(xs, S):
    xs = project(xs).detach().cpu()

    xs0 = xs[None, :, :]
    xs1 = xs[:, None, :]
    sim_mat = S(xs0, xs1)  # (n, n)
    similarities = sim_mat.numpy()
    n = similarities.shape[0]
    similarities=similarities.astype('double')
    ij, _ = mst.mst(similarities, n)
    return ij
class  UnionFind:
    
    def __init__(self, n , pos , c):
        self.n = n
        self.pos = pos
        self.c = c
        self.parent = [i for i in range(n)]
        self.rank = [0 for i in range(n)]
        self.vis = [0 for i in range(2*n-1)]
        self.vis2 = [0 for i in range(2*n-1)]
        self.mer = [-1 for i in range(2*n-1)]
        self._next_id = n
        self._tree = [-1 for i in range(2*n-1)]

        self._id = [i for i in range(n)]

    def _find(self, i):
        if self.parent[i] == i:
            return i
        else:
            self.parent[i] = self._find(self.parent[i])
            return self.parent[i]

    def find(self, i):
        if (i < 0) or (i > self.n):
            raise ValueError("Out of bounds index.")
        return self._find(i)

    def union(self,  i,  j, k=True):
        root_i = self._find(i)
        root_j = self._find(j)
        if root_i == root_j:
            return False
        else:
            
            if self.rank[root_i] < self.rank[root_j]:
                self.parent[root_i] = root_j
                if(k):
                    self._build(root_j, root_i)
                
            elif self.rank[root_i] > self.rank[root_j]:
                self.parent[root_j] = root_i
                if(k):
                    self._build(root_i, root_j)
                
            else:
                
                self.parent[root_j] = root_i
                self.rank[root_i] += 1
                if(k):
                    self._build(root_i, root_j)
                
            return True


    def merge(self,ij):
        for k in range(ij.shape[0]):
            a=ij[k,0];
            b=ij[k,1];
            if(self.mer[a]!=-1):
                a=self.mer[a];
            if(self.mer[b]!=-1):
                b=self.mer[b];
            self.union(a, b)

    def  _build(self, i, j):
#         print(self._tree[0],"----")
#         if(dist(self.pos[self._id[i]],self.pos[self._id[j]])<self.c):
            
            
#             print(i,j,'-',self._id[i],self._id[j]);
#             self.vis[self._id[i]]=1;
#             self.vis[self._id[j]]=1;
                
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self.pos[self._id[i]] = torch.tensor(new);
#             self.pos[self._id[j]] = torch.tensor(new);
            
#             self.search(self._id[i]);
#             self.search(self._id[j]);

#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
            
#         else:
            
#             t=np.array(self.pos).tolist()
#             new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
#             t.append(new);
#             self.pos=torch.tensor(t)
#             self._tree[self._id[i]] = self._next_id
#             self._tree[self._id[j]] = self._next_id
#             self._id[i] = self._next_id
#             self._next_id += 1
        self.vis2[i]=1;
        self.vis2[j]=1;
        
        t=np.array(self.pos).tolist()
        new = np.array(hyp_lca(self.pos[self._id[i]],self.pos[self._id[j]])).tolist()
        t.append(new);
        self.pos=torch.tensor(t)
        
        self._tree[self._id[i]] = self._next_id
        self._tree[self._id[j]] = self._next_id
        self._id[i] = self._next_id
        self.check(i);
        self._next_id += 1

    def search(self,k):
#         for i in range(len(self.parent)):
#             if(self.parent[i]==k):
#                 self.parent[i]=self._next_id;
#         print(k==-1)

        for i in range(len(self._tree)):
            if(self.vis[i]):
                continue;            
            if(self._tree[i]==k):
                # print("sear")
                self._tree[i]=self._next_id;  
                
        for i in range(len(self._id)):
            if(self.vis[i]):
                continue;
            if(self._id[i]==k):
                # print("Sear")
                self._id[i]=self._next_id;  
                
    def check(self,t):
        minnum=math.inf
        minns=None;
        for i in range(self.n):
            if(self.vis[i] or self.vis2[i]):
                continue;
            distance = dist(self.pos[i],self.pos[-1]);
            if(distance<self.c and distance < minnum):
                minnum = distance
                minns = i;
                
#                 print("merge {} in {}".format(i,t))
#                 self.parent[i]=t;
#                 self.vis[i]=1;
#                 self.search(i);
        if(minns != None):
            # print("merge {} in {}".format(minns,self._next_id))
            self.vis[minns]=1;
            self.rank[minns]=-1;
            self.pos[minns] = self.pos[-1]
#             self.search(minns);
            self.mer[minns]=t;
            self.mer[self._next_id] = minns;
#             self.union(t,minns,False);
        
    def parent(self):
        return [self.parent[i] for i in range(self.n)]

    def tree(self):
        return [self._tree[i] for i in range(len(self._tree))]
def get_colors(y, color_seed=1234):
    """random color assignment for label classes."""
    np.random.seed(color_seed)
    colors = {}
    for k in np.unique(y):
        r = np.random.random()
        b = np.random.random()
        g = np.random.random()
        colors[k] = (r, g, b)
    return [colors[k] for k in y]


def get_Hyper_tree(data_path,start,end,lable,epoches,model_path=None,save_path='./',c=-1):
    np.random.seed(1234)
    torch.manual_seed(1234)
    # x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
    x, y_true, similarities = load_data(data_path,start,end,lable)
    print("{} length:{}".format(data_path,len(y_true)));
    dataset = HCDataset(x, y_true, similarities, num_samples=50000)
    dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
    if(model_path ==None):
        model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
        model.to("cpu")
        Optimizer = getattr(optim, 'RAdam')
        optimizer = Optimizer(model.parameters(),0.0005)
        train(model,dataloader,optimizer,similarities,epoches);
        torch.save(model,save_path+'model.pth');
    else:
        params = torch.load((model_path), map_location=torch.device('cpu'))
        model.load_state_dict(params, strict=False)
    model.eval()
    sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
    n=len(x);
    d = model.normalize_embeddings(model.embeddings.weight.data)
    d = project(d).detach().cpu()
    ijs = sl_np_mst_ij(d,sim_fn)
    uf = UnionFind(n,d,c)
    uf.merge(ijs)
    count=0

    tree = nx.DiGraph()
    for i, j in enumerate(uf.tree()[:-1]):
        if(j!=-1):
            tree.add_edge(j, i)
            
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(111)
    circle = plt.Circle((0, 0), 20.0, color='r', alpha=0.1)
    ax.add_artist(circle)

    n = len(d)
    embeddings = np.array(uf.pos)
    # for i in range(len(embeddings)):
    #     if(np.isnan(embeddings[i][0]) or embeddings[i][0] + embeddings[i][1] == 0):
    #         embeddings[i] = embeddings[i-1];
    #     pass;
    # print(embeddings)
    where_are_NaNs = np.isnan(embeddings)
    embeddings[where_are_NaNs] = 0
    vis = uf.vis
    # xlist=[]
    # ylist=[]
    # labels=[]

    # for i in range(n):
    #     if(uf.vis[i]!=1):
    #         xlist.append(embeddings[i,0]*20);
    #         ylist.append(embeddings[i,1]*20);
    #         labels.append(y_true[i]);
    # # colors = get_colors(labels, 1234)
    colors = get_colors(y_true, 1234)

    # ax.scatter(xlist, ylist, c=colors, s=50, alpha=0.6)

    ax.scatter(embeddings[:n, 0]*20, embeddings[:n, 1]*20, c=colors, s=50, alpha=0.6)

    for i in range(len(embeddings)):
        if(i<n):
            continue;
        if(uf.mer[i]!=-1):
            # print(i,'pass')
            pass;
        else:
            ax.scatter(embeddings[i][0]*20,embeddings[i][1]*20,color='black',s=20,alpha=0.7)

        

    for n1, n2 in tree.edges():
    #     if(uf.vis[n1]== 1 or uf.vis[n2]== 1 ):
    # #         print("1")
    #         pass
    #     else:
    #         x1 = embeddings[n1]
    #         x2 = embeddings[n2]
    # #         if(n1>=n):
    # #             if(uf.mer[n1]!=-1):
    # #                 pass;
    # #             else:
    # #                 count+=1;
    # #         if(n2>n):
    # #             if(uf.mer[n1]!=-1):
    # # # 
    # #                 pass;
    # #             else:
    # # #                 ax.scatter(x2[0]*20,x2[1]*20,color='black',s=20,alpha=0.7)
    # #                 count+=1
        
        
    #         plot_geodesic(x1, x2, ax)
    # #         print(x1,x2,n1,n2)
    # #         break
    #         pass

    #     ax.axis("off")
        x1 = embeddings[n1];
        x2 = embeddings[n2];
        plot_geodesic(x1,x2,ax)
    fig.savefig(save_path+"graph.png");
    np.save(save_path+"dataxy.npy",embeddings)
    np.save(save_path+"datalink.npy",list(tree.edges()))
    np.save(save_path+"datamerge.npy",uf.mer)

# %%
def cccfg(
        adata,
        gene_list,
        save_path="./",
    ):
    groupby = adata.uns["capital"]["tree"]["annotation"]
    filtered_data = adata.raw.to_adata()[:]
    filtered_data.to_df().to_csv(save_path+"data_cell.csv");
    adata.obs.to_csv(save_path+"data_type.csv")
    cluster_centroid_data = np.empty((0, filtered_data.n_vars))
    clustername = filtered_data.obs[groupby].unique().tolist()

    for i in clustername:
        a_cluster_data = filtered_data[filtered_data.obs[groupby] == "{}".format(
            i)].to_df()
        a_cluster_median = a_cluster_data.mean(axis=0).values
        cluster_centroid_data = np.vstack(
            (cluster_centroid_data, a_cluster_median)
        )
    cluster_centroid = pd.DataFrame(
        cluster_centroid_data,
        index=clustername,
        columns=filtered_data.var_names
    )
    cluster_centroid.to_csv(save_path+"datas.data",header=None);
    cluster_centroid.to_csv(save_path+"datas.csv");

    return cluster_centroid

# %%
set_initial_condition(adata)

# %%
cccfg(adata,'','./datas/merge2/')
# Out:
#          0         1         2         3         4         5             6    \
# 6   0.051787  0.164336  0.005454  0.583335  0.079963  0.001718  0.000000e+00
# 5   0.043413  0.055474  0.004650  0.520968  0.114527  0.000503  0.000000e+00
# 3   0.030490  0.018790  0.009293  1.519312  0.178544  0.005954  0.000000e+00
# 1   0.030602  0.080987  0.003193  0.686146  0.057702  0.002533  5.339463e-03
# 0   0.030875  0.153110  0.006906  0.145716  0.096075  0.003644  0.000000e+00
# 16  0.300185  0.014248  0.000000  0.882984  0.038230  0.000095  5.428734e-03
# 14  0.751254  0.003830  0.987272  0.119335  0.021834  0.001798  1.329874e-03
# 9   0.204546  0.001484  0.306907  0.105821  0.000276  0.006915  4.094182e-07
# 7   0.186110  0.004079  0.007788  0.179489  0.013076  0.001840  5.013842e-08
# 8   0.651510  0.042638  0.007430  1.373516  0.079107  0.002342  0.000000e+00
# 11  0.037948  0.010186  0.004531  0.379690  0.105887  0.005377  7.335601e-02
# 4   0.036817  0.079457  0.005671  0.218354  0.100599  0.001559  5.147785e-02
# 13  0.050655  0.007504  0.004107  0.601658  0.017904  0.002915  0.000000e+00
# 2   0.036914  0.030554  0.001774  0.913214  0.069760  0.001891  5.837477e-03
# 15  0.570326  0.000877  0.165116  0.090050  0.034947  0.000000  0.000000e+00
# 12  0.145023  0.062337  0.005449  0.578995  0.050758  0.003697  7.035942e-03
# 17  0.943673  0.000166  0.044002  0.117801  0.042854  0.000000  0.000000e+00
# 10  0.065966  0.021808  0.004310  0.455779  0.025934  0.003092  7.361928e-04
# 18  0.073536  0.055243  0.000000  0.140618  0.098192  0.000000  0.000000e+00
# 19  0.028928  0.108492  0.044835  1.232544  0.164569  0.000000  0.000000e+00
# 20  0.117299  0.000000  0.240773  0.122682  0.000000  0.000000  0.000000e+00
#
#          7         8         9    ...           503       504       505  \
# 6   0.071061  0.023447  0.203049  ...  0.000000e+00  0.639251  0.000769
# 5   0.038829  0.036629  0.137419  ...  0.000000e+00  0.914012  0.002835
# 3   0.122020  0.001283  0.035211  ...  1.015864e-03  0.003020  0.001553
# 1   0.042054  0.015159  0.101153  ...  2.691183e-04  0.543717  0.001781
# 0   0.033990  0.026620  0.246021  ...  5.973725e-04  0.656600  0.001626
# 16  0.031036  0.000000  0.493041  ...  0.000000e+00  0.068964  0.000000
# 14  0.026497  0.000000  0.016536  ...  3.117520e-03  0.096587  0.427769
# 9   0.070475  0.000985  0.001322  ...  2.061734e-07  0.008278  0.318556
# 7   0.087212  0.000000  0.006343  ...  3.023263e-03  0.036718  0.042485
# 8   0.032975  0.000790  0.019041  ...  5.579547e-03  0.101074  0.004873
# 11  0.031024  0.002176  0.100972  ...  0.000000e+00  1.174825  0.000000
# 4   0.046169  0.019907  0.142181  ...  4.962831e-04  1.201356  0.003944
# 13  0.035242  0.000023  0.005974  ...  2.642819e-01  0.031089  0.148724
# 2   0.018883  0.012248  0.128345  ...  7.661626e-04  1.050969  0.000963
# 15  0.045020  0.000000  0.008065  ...  2.190448e-03  0.057484  0.105478
# 12  0.217635  0.035188  0.157474  ...  0.000000e+00  0.521035  0.003557
# 17  0.030965  0.000166  0.000246  ...  0.000000e+00  0.000166  0.057935
# 10  0.251395  0.002140  0.011570  ...  0.000000e+00  0.078020  0.005918
# 18  0.008212  0.008695  0.145214  ...  3.257334e-03  0.395266  0.010843
# 19  0.073675  0.000000  0.089277  ...  0.000000e+00  0.556692  0.000000
# 20  0.126536  0.000000  0.000000  ...  2.315353e-01  0.000000  0.154034
#
#              506       507       508       509       510       511       512
# 6   0.000000e+00  0.000000  0.249851  0.000000  0.028660  0.000000  0.005777
# 5   0.000000e+00  0.000000  0.041664  0.001436  0.011340  0.000000  0.001926
# 3   3.748830e-01  0.000000  0.001436  0.000000  0.006822  0.001884  0.002823
# 1   6.028960e-04  0.003366  0.251968  0.001242  0.003379  0.000340  0.025682
# 0   0.000000e+00  0.000000  0.246743  0.000000  0.005812  0.000565  0.002776
# 16  0.000000e+00  0.000000  0.015714  0.000000  0.004248  0.000000  0.011419
# 14  2.344549e-03  0.000000  0.025053  0.000000  0.741251  0.002556  0.004984
# 9   6.518571e-04  0.000000  0.002038  0.001252  0.110120  0.001135  0.020090
# 7   4.729456e-08  0.000000  0.012047  0.002120  0.209155  0.001352  0.008195
# 8   8.356263e-03  0.000000  0.012818  0.001738  0.015180  0.015485  0.655902
# 11  0.000000e+00  0.038681  0.044701  0.000000  0.011309  0.000930  0.316051
# 4   0.000000e+00  0.035285  0.346879  0.001292  0.014985  0.000000  0.007138
# 13  2.506840e-03  0.000000  0.010500  0.181297  0.016573  0.000000  0.004916
# 2   0.000000e+00  0.008775  0.235206  0.000537  0.006664  0.000000  0.010754
# 15  0.000000e+00  0.000000  0.007149  0.012106  0.922206  0.000000  0.003949
# 12  0.000000e+00  0.001095  0.179668  0.000000  0.087028  0.000000  0.022161
# 17  0.000000e+00  0.000000  0.000000  0.000000  0.088250  0.000000  0.000000
# 10  5.768535e-03  0.000000  0.012702  0.000000  0.022075  0.000000  0.013183
# 18  0.000000e+00  0.000000  0.165256  0.000000  0.107042  0.000000  0.000000
# 19  1.987043e-01  0.000000  0.167631  0.000000  0.000000  0.000000  0.000000
# 20  0.000000e+00  0.000000  0.000000  0.122696  1.381750  0.000000  0.000000
#
# [21 rows x 513 columns]

# %%
x, y_true, similarities = load_data('./datas/merge2/datas.data',1,514,0)
data_path = './datas/merge2/datas.data'
start = 1
end =514
lable = 0
model_path = None;
save_path = './datas/merge2/'
epoches=10
c=-1
np.random.seed(1234)
torch.manual_seed(1234)
# x, y_true, similarities = load_data('../../../cityu/HypHC/data/4_8/4_8.data',start,end,lable)
x, y_true, similarities = load_data(data_path,start,end,lable)
print("{} length:{}".format(data_path,len(y_true)));
dataset = HCDataset(x, y_true, similarities, num_samples=50000)
dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
if(model_path ==None):
    model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)
    model.to("cpu")
    Optimizer = getattr(optim, 'RAdam')
    optimizer = Optimizer(model.parameters(),0.0005)
    train(model,dataloader,optimizer,similarities,epoches);
    torch.save(model,save_path+'model.pth');
else:
    params = torch.load((model_path), map_location=torch.device('cpu'))
    model.load_state_dict(params, strict=False)
model.eval()
sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
n=len(x);
d = model.normalize_embeddings(model.embeddings.weight.data)
d = project(d).detach().cpu()
ijs = sl_np_mst_ij(d,sim_fn)
uf = UnionFind(n,d,c)
uf.merge(ijs)
count=0
# Out:
# ./datas/merge2/datas.data length:21
# Generating all pairs superset
# 100%|██████████| 1563/1563 [01:00<00:00, 25.78ex/s, loss=1.453104]
# /var/folders/bm/69jvgsdj3rxch558kx9yp9y00000gn/T/ipykernel_52720/836080252.py:147: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ij, _ = mst.mst(similarities, n)
# 	 Epoch 9 | average train loss: 1.458367
# Optimization finished.

# %%
from alignment import node
from alignment import show_tree
embeddings = np.array(uf.pos)

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break

# %%
def search_tree(now,c):
    if(len(now.son) != 2):
        return now;
    lson = search_tree(now.son[0],c);
    now.son[0] = lson;
    rson = search_tree(now.son[1],c);
    now.son[1] = rson
    # lson = now.son[0]
    # rson = now.son[1]
    if(np.linalg.norm(lson.value-rson.value)<=c):
        if(len(lson.son)>1 and len(rson.son)>1):
            pass
        elif(len(lson.son)>1):
            now = rson;
            now.son.append(lson);
        else:
            now = lson;
            now.son.append(rson)
    # exit(0)
    return now;

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=embeddings[i];
    nodes1[i].subson=0
    # if(i==49):
    #     break
show_tree(nodes1[-1]).show_fig()

# %%
search_tree(nodes1[-1],0.018)
show_tree(nodes1[-1]).show_fig()

# %%
adata.obs.groupby('leiden').max()
# Out:
#              celltype
# leiden
# 0       [Fibroblasts]
# 1       [Fibroblasts]
# 2         [Malignant]
# 3       [Fibroblasts]
# 4       [Fibroblasts]
# 5           [Tprolif]
# 6           [Tprolif]
# 7         [Malignant]
# 8         [Malignant]
# 9       [Fibroblasts]
# 10        [Malignant]
# 11      [Fibroblasts]
# 12           [CD8Tex]
# 13      [Fibroblasts]
# 14      [Fibroblasts]
# 15        [Malignant]
# 16             [Mast]
# 17      [Fibroblasts]
# 18      [Fibroblasts]
# 19           [CD8Tex]
# 20      [Fibroblasts]
