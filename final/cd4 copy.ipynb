# %%
from hyper import *
from alignment import *
from datasets.preprecossing import *
from core import *
from datasets.loading import *
from datasets.hc_dataset import *
from datasets.balance_dataset import *
from utils.linkage import *
from model.balancehc import balancehc

from utils.poincare import *
import scib
import shutil

# %%
cell_path1 = './datas/111/CHOL_GSE142784.h5ad'
folder_path1 = './datas/320/'
radius1 = 0
c1 =0
epoches1 =  50
epoches2 =  10
contin = False
resolution=2
method='average'
alignment=1
n_pca=50
meta_col = 'Celltype..major.lineage.'
mst = False

# %%
adata1 = sc.read_h5ad('./datas/miss/1/'+"save.h5ad")
adata1
# Out:
# AnnData object with n_obs × n_vars = 2452 × 636
#     obs: 'celltype', 'celltype1', 'leiden'
#     var: 'n_cells'

# %%
datas =sc.read_h5ad('./datas/111/BRCA_GSE110686.h5ad')
datas
# Out:
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/orig.ident' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/nCount_RNA' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/nFeature_RNA' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/UMAP_1' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/UMAP_2' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Celltype..malignancy.' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Celltype..major.lineage.' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Celltype..minor.lineage.' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Cluster' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Patient' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Source' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Gender' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/Stage' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/obs/_index' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/h5ad.py:238: OldFormatWarning: Element '/obsm' was written without encoding metadata.
#   d[k] = read_elem(f[k])
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/var/features' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:590: OldFormatWarning: Element '/var/_index' was written without encoding metadata.
#   return read_elem(dataset)
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/h5ad.py:238: OldFormatWarning: Element '/varm' was written without encoding metadata.
#   d[k] = read_elem(f[k])
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/h5ad.py:272: OldFormatWarning: Element '/raw/var' was written without encoding metadata.
#   raw[v] = read_elem(f[f"raw/{v}"])
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/anndata/_io/specs/methods.py:92: OldFormatWarning: Element '/raw/var/_index' was written without encoding metadata.
#   return {k: read_elem(v) for k, v in elem.items()}
# AnnData object with n_obs × n_vars = 6035 × 12750
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'Celltype..malignancy.', 'Celltype..major.lineage.', 'Celltype..minor.lineage.', 'Cluster', 'Patient', 'Source', 'Gender', 'Stage'
#     var: 'features'

# %%
adata = datas[adata1.obs.index.tolist(),[ i for i in adata1.var.index if i in datas.var.index]]

# %%
[ i for i in adata1.var.index if i in datas.var.index]
# Out:
# ['GZMK',
#  'TMSB4X',
#  'CCL5',
#  'RPS27',
#  'MALAT1',
#  'RPL10',
#  'RPL41',
#  'GZMA',
#  'RPS14',
#  'RPS18',
#  'CXCR4',
#  'RPL23A',
#  'RPS29',
#  'RPS2',
#  'RPL13A',
#  'RPL3',
#  'RPS3',
#  'RPL27A',
#  'ANXA1',
#  'RPL34',
#  'RPS15',
#  'ZFP36L2',
#  'RPLP2',
#  'RPL13',
#  'RPS15A',
#  'LYAR',
#  'CD69',
#  'DUSP2',
#  'RPL7',
#  'RPS27A',
#  'FOS',
#  'RPS25',
#  'RPL32',
#  'RPS28',
#  'RPS6',
#  'RPL31',
#  'DUSP1',
#  'BTG1',
#  'NKG7',
#  'RPL18A',
#  'GIMAP4',
#  'KLRG1',
#  'CD52',
#  'JUNB',
#  'RPS12',
#  'RPL39',
#  'RPL28',
#  'GIMAP7',
#  'EIF1',
#  'HCST',
#  'MT-CO3',
#  'ITM2C',
#  'RGCC',
#  'TC2N',
#  'TRAT1',
#  'RPL35A',
#  'TRGC2',
#  'GZMM',
#  'CLEC2B',
#  'MT-CYB',
#  'TXNIP',
#  'H3F3B',
#  'CD8B',
#  'JUN',
#  'RPL30',
#  'DNAJB1',
#  'CST7',
#  'ZFP36',
#  'IER2',
#  'STK17A',
#  'SAMD3',
#  'EOMES',
#  'CTSW',
#  'RPL14',
#  'PLAC8',
#  'KLRD1',
#  'GPR183',
#  'TSC22D3',
#  'MT-ND4',
#  'LINC00861',
#  'ATM',
#  'IL7R',
#  'RPL10A',
#  'CD44',
#  'FOSB',
#  'PIK3R1',
#  'KLF6',
#  'PDE4B',
#  'HLA-E',
#  'RARRES3',
#  'PPP2R5C',
#  'CCDC109B',
#  'CCR7',
#  'PDCD4',
#  'BTG2',
#  'CD8A',
#  'SARAF',
#  'CMC1',
#  'MT-ND2',
#  'PABPC1',
#  'IFI27',
#  'TNFRSF4',
#  'PIM2',
#  'ISG15',
#  'TIGIT',
#  'IL2RA',
#  'CARD16',
#  'COX5A',
#  'TNFRSF18',
#  'SAT1',
#  'CTLA4',
#  'IFI6',
#  'TYMP',
#  'FOXP3',
#  'DNPH1',
#  'ICOS',
#  'GLRX',
#  'SPATS2L',
#  'PMAIP1',
#  'DUSP4',
#  'ISG20',
#  'OAS1',
#  'MX1',
#  'EPSTI1',
#  'BATF',
#  'RTKN2',
#  'STAT1',
#  'RGS1',
#  'IL1R2',
#  'SELL',
#  'C5orf56',
#  'PKM',
#  'GBP2',
#  'HERC5',
#  'TBC1D4',
#  'IFI44L',
#  'LAYN',
#  'CFLAR',
#  'SMS',
#  'ICA1',
#  'SOX4',
#  'SPOCK2',
#  'MIR4435-2HG',
#  'NCF4',
#  'LAP3',
#  'CALM3',
#  'ETV7',
#  'LAIR2',
#  'LY6E',
#  'GATA3',
#  'TNIP1',
#  'EAPP',
#  'ARID5B',
#  'SP100',
#  'ATOX1',
#  'GADD45A',
#  'USP18',
#  'CASP1',
#  'LGALS9',
#  'SFT2D1',
#  'HTATIP2',
#  'PSMA2',
#  'GBP5',
#  'CHMP5',
#  'ZFP36L1',
#  'MAGEH1',
#  'PSMB9',
#  'IFIT3',
#  'TNFRSF1B',
#  'BIRC3',
#  'UBE2L6',
#  'TXN',
#  'SYNGR2',
#  'IFI44',
#  'SERPINB9',
#  'SAMD9',
#  'RAC1',
#  'ACP5',
#  'CD27',
#  'BST2',
#  'CORO1B',
#  'GALM',
#  'IFI16',
#  'HN1',
#  'NDUFB4',
#  'RPS27L',
#  'YWHAE',
#  'PRKAR1A',
#  'UCP2',
#  'TANK',
#  'UBE2N',
#  'PSMB8',
#  'PRDX2',
#  'USP15',
#  'SH3BGRL',
#  'GNG5',
#  'HMGN2',
#  'CCL4',
#  'GZMH',
#  'CCL3',
#  'HLA-DRB1',
#  'CXCL13',
#  'LAG3',
#  'GZMB',
#  'HAVCR2',
#  'APOBEC3G',
#  'HLA-DPA1',
#  'CD74',
#  'HLA-DPB1',
#  'VCAM1',
#  'PRF1',
#  'KLRC1',
#  'GNLY',
#  'HLA-DRA',
#  'FABP5',
#  'KLRC2',
#  'PTMS',
#  'COTL1',
#  'MIR155HG',
#  'ID2',
#  'CD63',
#  'CHST12',
#  'HLA-DQA1',
#  'TNFSF4',
#  'HLA-DQB1',
#  'LYST',
#  'SH2D1A',
#  'IFNG',
#  'FASLG',
#  'ANXA5',
#  'RGS2',
#  'MT2A',
#  'ALOX5AP',
#  'CD38',
#  'C12orf75',
#  'APOBEC3C',
#  'HLA-DMA',
#  'RABAC1',
#  'TOX',
#  'ADGRG1',
#  'ABI3',
#  'AIF1',
#  'ITGB7',
#  'CCR1',
#  'RBPJ',
#  'LGALS1',
#  'TNIP3',
#  'BHLHE40',
#  'CCR5',
#  'GSTP1',
#  'APOBEC3H',
#  'PLA2G16',
#  'ID3',
#  'ITGA1',
#  'CLIC1',
#  'SRI',
#  'OASL',
#  'FKBP1A',
#  'TRG-AS1',
#  'PLSCR1',
#  'LITAF',
#  'PSME2',
#  'LSP1',
#  'YWHAH',
#  'RAB27A',
#  'HERPUD1',
#  'DRAP1',
#  'HMGN3',
#  'SIT1',
#  'TRBC1',
#  'CXCR3',
#  'HMGB2',
#  'GPR171',
#  'EEF1A1',
#  'RPL12',
#  'RPS8',
#  'RPL11',
#  'RPS3A',
#  'RPL36',
#  'RPL29',
#  'RPS7',
#  'LTB',
#  'TPT1',
#  'RPS23',
#  'RPL36A',
#  'RPL18',
#  'RPS16',
#  'RPL9',
#  'RPL22',
#  'TMEM123',
#  'RPS13',
#  'RPLP0',
#  'RPL37',
#  'PASK',
#  'CD40LG',
#  'SLC2A3',
#  'CTSL',
#  'RPS21',
#  'UBA52',
#  'RPL24',
#  'GNB2L1',
#  'RPL5',
#  'FXYD5',
#  'GLTSCR2',
#  'RPSA',
#  'TNRC6B',
#  'RPL7A',
#  'KLRB1',
#  'PFDN5',
#  'RPL38',
#  'LEF1',
#  'RPL37A',
#  'SOCS3',
#  'LDHB',
#  'S100A11',
#  'TNFRSF25',
#  'AQP3',
#  'TNFSF13B',
#  'EEF1B2',
#  'RPL4',
#  'RPL27',
#  'BTF3',
#  'RPS10',
#  'TIMP1',
#  'RNASET2',
#  'EML4',
#  'TNFAIP8',
#  'ARHGAP15',
#  'TNFSF10',
#  'SNHG8',
#  'NR3C1',
#  'EIF3E',
#  'GSTK1',
#  'OCIAD2',
#  'ZNF683',
#  'XCL1',
#  'RPL21',
#  'TRDC',
#  'HOPX',
#  'TRGC1',
#  'XCL2',
#  'CD300A',
#  'CD7',
#  'IFITM3',
#  'CD99',
#  'FGFBP2',
#  'EVL',
#  'MATK',
#  'FCRL6',
#  'NUCB2',
#  'C1orf162',
#  'PTGDR',
#  'CD9',
#  'BIN2',
#  'AOAH',
#  'SCML4',
#  'MYL12A',
#  'RPS24',
#  'DSTN',
#  'CRTAM',
#  'MBP',
#  'LDLRAD4',
#  'CHD9',
#  'LINC00869',
#  'FAM173A',
#  'XBP1',
#  'STOM',
#  'GIMAP1',
#  'GTF3A',
#  'TPST2',
#  'TSEN54',
#  'CTSD',
#  'CAPG',
#  'JAML',
#  'CYBA',
#  'CALM1',
#  'VIM',
#  'EMP3',
#  'IFITM2',
#  'CTSA',
#  'DHRS7',
#  'PSMA3-AS1',
#  'EIF2S3',
#  'TTC39C',
#  'CD79B',
#  'POLR2J3',
#  'RBM6',
#  'CTNNB1',
#  'NGFRAP1',
#  'CUL9',
#  'PBXIP1',
#  'S100A4',
#  'ADI1',
#  'ANKRD10',
#  'TCEAL4',
#  'PHACTR2',
#  'FCMR',
#  'HNRNPH1',
#  'CD4',
#  'MAF',
#  'TNFRSF9',
#  'NABP1',
#  'STK17B',
#  'TPR',
#  'UGP2',
#  'HADHB',
#  'TRAF1',
#  'NEAT1',
#  'SET',
#  'PIM3',
#  'PARK7',
#  'SOD1',
#  'PPM1G',
#  'NOP58',
#  'PPA1',
#  'CHMP2A',
#  'PIK3IP1',
#  'RGS10',
#  'NAP1L1',
#  'VMP1',
#  'DYNLL1',
#  'ATP5G2',
#  'RBMX',
#  'HSPA1A',
#  'CKLF',
#  'GAPDH',
#  'CXCR6',
#  'PDCD1',
#  'KRT86',
#  'FAM118A',
#  'TPI1',
#  'CCL4L2',
#  'PTPN7',
#  'IL26',
#  'LINC00969',
#  'SUPT3H',
#  'PGAM1',
#  'SRGAP3',
#  'DAPK2',
#  'RHOA',
#  'PLEKHF1',
#  'BLOC1S1',
#  'CD3G',
#  'ANKRD28',
#  'PHYKPL',
#  'RAC2',
#  'RHOC',
#  'LGALS3',
#  'ARL3',
#  'IKZF3',
#  'RUNX3',
#  'SIRPG',
#  'RGS16',
#  'CD6',
#  'SLC16A3',
#  'LINC00152',
#  'FAM3C',
#  'CD82',
#  'ACAP1',
#  'PTPN6',
#  'CD247',
#  'LAPTM5',
#  'IFI27L2',
#  'LDHA',
#  'TMEM167A',
#  'YWHAQ',
#  'PA2G4',
#  'TSPO',
#  'PGK1',
#  'RAP1B',
#  'CAPZB',
#  'ATP5G3',
#  'DDIT4',
#  'NDUFA3',
#  'HSPB1',
#  'SBDS',
#  'LMNA',
#  'ZNF331',
#  'CREM',
#  'NR4A2',
#  'NAMPT',
#  'NR4A1',
#  'GEM',
#  'NFKBIA',
#  'SDCBP',
#  'KDM6B',
#  'CDKN1A',
#  'PFKFB3',
#  'CD83',
#  'SELK',
#  'SOD2',
#  'C15orf48',
#  'GADD45B',
#  'AUP1',
#  'PLK3',
#  'CCDC47',
#  'PLIN2',
#  'MT-ATP6',
#  'HSP90AB1',
#  'REL',
#  'STAT3',
#  'TAGLN2',
#  'GPX4',
#  'CHMP1B',
#  'S100A10',
#  'RAP1A',
#  'TPM4',
#  'ALDOA',
#  'CTSB',
#  'C4orf48',
#  'RPL23',
#  'PSMB6',
#  'HSPA5',
#  'CRIP1',
#  'SEC61G',
#  'SOCS1',
#  'EIF4A1',
#  'VDAC1',
#  'UBE2B',
#  'RBM8A',
#  'SRGN',
#  'PRDX1',
#  'NDFIP1',
#  'TNFAIP3',
#  'GNAS',
#  'MIF',
#  'EZR',
#  'YBX1',
#  'SERBP1',
#  'KCNN4',
#  'LINC01588',
#  'GTF3C6',
#  'COMMD3',
#  'APLP2',
#  'H3F3A',
#  'GPX1',
#  'TXNDC17',
#  'ENO1',
#  'FAS',
#  'NDUFA6',
#  'PPP4C',
#  'SLAMF1',
#  'CCDC167',
#  'COX6A1',
#  'MRPL20',
#  'NDUFC2',
#  'NDUFA4',
#  'CD59',
#  'CNIH1',
#  'MAP2K3',
#  'ARL6IP5',
#  'MPC2',
#  'TCEA1',
#  'COX7B',
#  'RORA',
#  'C14orf166',
#  'SEC61B',
#  'ATP5G1',
#  'SH2D2A',
#  'SNRPC',
#  'ARPC1B',
#  'VCP',
#  'C1QBP',
#  'TUBB',
#  'YWHAB',
#  'NDUFV2',
#  'SLA',
#  'RPS11',
#  'RPL6',
#  'RPL35',
#  'ZNRF1',
#  'MT-ND3',
#  'RPS17',
#  'ACTG1',
#  'PPT1',
#  'CTSC',
#  'NBEAL1',
#  'ANAPC16',
#  'ATP5EP2',
#  'CD53',
#  'CCL20',
#  'TMEM173',
#  'KDSR',
#  'CD3E',
#  'NDUFS5',
#  'RPS5',
#  'PIM1',
#  'EEF2',
#  'PRNP',
#  'IL27RA',
#  'EIF4B',
#  'FNBP1',
#  'OXNAD1',
#  'MT-ND1',
#  'LAT',
#  'NDUFA11',
#  'RNF213',
#  'TOMM7',
#  'CD48',
#  'C11orf31',
#  'CYTIP',
#  'HNRNPC',
#  'EPC1',
#  'METTL9',
#  'DYNLRB1',
#  'PTTG1',
#  'SUMO2',
#  'MRPS34',
#  'MRPL51',
#  'PHLDA1',
#  'UQCRH',
#  'MIEN1',
#  'PHPT1',
#  'C9orf16',
#  'SNRPB',
#  'ATP5A1',
#  'ICAM3',
#  'COPZ1',
#  'ARPC4',
#  'NOP10',
#  'UBE2D2',
#  'NDUFA1',
#  'EDF1',
#  'ATP5C1',
#  'C12orf57',
#  'ISCU',
#  'COX8A']

# %%
adata1.var.index
# Out:
# Index(['GZMK', 'TMSB4X', 'CCL5', 'RPS27', 'MALAT1', 'RPL10', 'RPL41', 'GZMA',
#        'RPS14', 'RPS18',
#        ...
#        'COPZ1', 'ARPC4', 'NOP10', 'UBE2D2', 'NDUFA1', 'EDF1', 'ATP5C1',
#        'C12orf57', 'ISCU', 'COX8A'],
#       dtype='object', length=636)

# %%
adata1.obs
# Out:
#                    celltype celltype1 leiden
#
# CTCCTAGTCTGGCGTG-2      Tfh  CD4Tconv      6
# TGTATTCTCCCATTTA-2      Th2  CD4Tconv     28
# GACCTGGAGTAATCCC-3     Th17  CD4Tconv     13
# ATCTGCCAGTGTCCAT-3    CD4Tn  CD4Tconv     31
# GGGAGATAGGCATGGT-2    CD4Tn  CD4Tconv     43
# ...                     ...       ...    ...
# ACGGAGAAGAAGGCCT-1    CD4Tn  CD4Tconv      7
# CGATCGGTCATCTGTT-1     Th17  CD4Tconv      5
# AACTCTTAGCCACCTG-3     Th17  CD4Tconv     13
# GGGAGATGTAGTGAAT-1    CD4Tn  CD4Tconv     31
# GGATTACTCCAGTAGT-2      Tfh  CD4Tconv     10
#
# [2452 rows x 3 columns]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 2452 × 627
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'Celltype..malignancy.', 'Celltype..major.lineage.', 'Celltype..minor.lineage.', 'Cluster', 'Patient', 'Source', 'Gender', 'Stage'
#     var: 'features'

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 2452 × 627
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'Celltype..malignancy.', 'Celltype..major.lineage.', 'Celltype..minor.lineage.', 'Cluster', 'Patient', 'Source', 'Gender', 'Stage'
#     var: 'features'

# %%
adata.to_df()
# Out:
#                         GZMK    TMSB4X      CCL5     RPS27    MALAT1  \
# CTCCTAGTCTGGCGTG-2  0.000000  6.141558  0.000000  4.521100  6.443277
# TGTATTCTCCCATTTA-2  3.696171  5.711236  3.027539  4.529185  6.942841
# GACCTGGAGTAATCCC-3  0.000000  5.198000  4.510365  3.583033  6.814044
# ATCTGCCAGTGTCCAT-3  0.000000  5.483167  0.000000  5.224442  6.529682
# GGGAGATAGGCATGGT-2  0.000000  5.701265  2.920139  5.068242  7.114013
# ...                      ...       ...       ...       ...       ...
# ACGGAGAAGAAGGCCT-1  0.000000  6.053254  0.000000  4.515970  6.875535
# CGATCGGTCATCTGTT-1  0.000000  5.693110  3.119940  2.736315  6.677903
# AACTCTTAGCCACCTG-3  0.000000  5.482457  0.000000  4.701888  6.926190
# GGGAGATGTAGTGAAT-1  0.000000  5.707110  0.000000  4.017202  7.444302
# GGATTACTCCAGTAGT-2  1.035740  5.913205  3.044003  4.139708  6.265621
#
#                        RPL10     RPL41      GZMA     RPS14     RPS18  ...  \
# CTCCTAGTCTGGCGTG-2  4.121058  4.300672  0.000000  3.838771  4.121058  ...
# TGTATTCTCCCATTTA-2  4.197020  4.721436  2.021387  4.721436  4.597459  ...
# GACCTGGAGTAATCCC-3  3.713084  3.931335  3.044046  3.583033  3.433503  ...
# ATCTGCCAGTGTCCAT-3  4.829385  4.998756  0.000000  4.252545  4.331493  ...
# GGGAGATAGGCATGGT-2  4.485477  5.068242  0.000000  4.381369  4.665919  ...
# ...                      ...       ...       ...       ...       ...  ...
# ACGGAGAAGAAGGCCT-1  3.755455  4.153092  3.085428  4.436838  4.838351  ...
# CGATCGGTCATCTGTT-1  3.790760  3.790760  2.736315  3.612944  3.790760  ...
# AACTCTTAGCCACCTG-3  4.527741  4.565082  2.923465  3.682167  4.362650  ...
# GGGAGATGTAGTGAAT-1  4.780650  4.520800  3.620698  3.838474  4.416647  ...
# GGATTACTCCAGTAGT-2  3.948959  3.462363  1.864324  3.620167  3.341372  ...
#
#                        COPZ1     ARPC4     NOP10    UBE2D2    NDUFA1  \
# CTCCTAGTCTGGCGTG-2  0.000000  1.394069  0.000000  0.000000  2.311908
# TGTATTCTCCCATTTA-2  0.000000  0.000000  0.000000  0.000000  0.000000
# GACCTGGAGTAATCCC-3  0.000000  0.000000  0.000000  1.791343  0.000000
# ATCTGCCAGTGTCCAT-3  0.000000  0.000000  1.357595  0.000000  0.000000
# GGGAGATAGGCATGGT-2  0.000000  0.000000  2.279514  2.279514  2.279514
# ...                      ...       ...       ...       ...       ...
# ACGGAGAAGAAGGCCT-1  0.000000  0.000000  0.000000  0.000000  0.000000
# CGATCGGTCATCTGTT-1  2.736315  2.105963  2.105963  2.105963  2.736315
# AACTCTTAGCCACCTG-3  0.000000  0.000000  1.508761  0.000000  0.000000
# GGGAGATGTAGTGAAT-1  2.311635  2.311635  0.000000  0.000000  0.000000
# GGATTACTCCAGTAGT-2  0.000000  1.035740  2.112485  1.035740  0.000000
#
#                         EDF1    ATP5C1  C12orf57      ISCU     COX8A
# CTCCTAGTCTGGCGTG-2  2.311908  2.311908  0.000000  1.954791  1.954791
# TGTATTCTCCCATTTA-2  0.000000  0.000000  0.000000  0.000000  0.000000
# GACCTGGAGTAATCCC-3  1.791343  0.000000  0.000000  1.791343  2.397441
# ATCTGCCAGTGTCCAT-3  1.357595  1.357595  0.000000  1.913043  0.000000
# GGGAGATAGGCATGGT-2  0.000000  0.000000  0.000000  0.000000  2.279514
# ...                      ...       ...       ...       ...       ...
# ACGGAGAAGAAGGCCT-1  0.000000  0.000000  0.000000  0.000000  0.000000
# CGATCGGTCATCTGTT-1  0.000000  2.105963  2.736315  2.105963  0.000000
# AACTCTTAGCCACCTG-3  1.508761  0.000000  1.508761  1.508761  1.508761
# GGGAGATGTAGTGAAT-1  0.000000  0.000000  0.000000  0.000000  0.000000
# GGATTACTCCAGTAGT-2  1.533503  1.533503  0.000000  1.533503  1.533503
#
# [2452 rows x 627 columns]

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
sc.pp.normalize_total(adata, exclude_highly_expressed=True)
sc.pp.log1p(adata)
adata
# Out:
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:140: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['n_genes'] = number
# /Users/dongjiajie/opt/anaconda3/lib/python3.8/contextlib.py:120: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   next(self.gen)
# AnnData object with n_obs × n_vars = 1803 × 627
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'Celltype..malignancy.', 'Celltype..major.lineage.', 'Celltype..minor.lineage.', 'Cluster', 'Patient', 'Source', 'Gender', 'Stage', 'n_genes'
#     var: 'features', 'n_cells'
#     uns: 'log1p'

# %%
sc.pp.highly_variable_genes(
    adata,
    min_mean=0.0125,
    max_mean=3,
    min_disp=0.5,
    n_top_genes=2000
)
adata.raw = adata
adata._inplace_subset_var(adata.var['highly_variable'])
adata.to_df()
# Out:
#                         GZMK    TMSB4X      CCL5     RPS27    MALAT1  \
# CTCCTAGTCTGGCGTG-2  0.000000  1.921308  0.000000  1.666132  1.962387
# GACCTGGAGTAATCCC-3  0.000000  1.840963  1.722969  1.537971  2.073319
# ATCTGCCAGTGTCCAT-3  0.000000  1.926578  0.000000  1.885430  2.077634
# GTCCTCAAGTGCCATT-2  0.000000  1.886820  0.000000  1.505638  2.003457
# CTGCCTATCGACGGAA-2  1.500692  1.840829  0.000000  1.712664  2.012981
# ...                      ...       ...       ...       ...       ...
# CCCAGTTGTTGCCTCT-1  0.000000  1.839163  0.000000  1.425017  1.967950
# TCGTACCTCCGGGTGT-2  1.063754  1.878248  1.269226  1.760878  2.216599
# CGATCGGTCATCTGTT-1  0.000000  1.984022  1.490012  1.389917  2.123082
# AACTCTTAGCCACCTG-3  0.000000  1.838000  0.000000  1.710487  2.038023
# GGATTACTCCAGTAGT-2  0.606950  1.752005  1.239395  1.467109  1.800092
#
#                        RPL10     RPL41      GZMA     RPS14     RPS18  ...  \
# CTCCTAGTCTGGCGTG-2  1.591665  1.625788  0.000000  1.535567  1.591665  ...
# GACCTGGAGTAATCCC-3  1.566072  1.611526  1.412280  1.537971  1.504655  ...
# ATCTGCCAGTGTCCAT-3  1.819139  1.848099  0.000000  1.713696  1.728801  ...
# GTCCTCAAGTGCCATT-2  1.402717  1.546978  0.000000  1.337273  1.428529  ...
# CTGCCTATCGACGGAA-2  1.759788  1.752875  1.187163  1.693138  1.824428  ...
# ...                      ...       ...       ...       ...       ...  ...
# CCCAGTTGTTGCCTCT-1  1.570438  1.555748  0.000000  1.347443  1.596426  ...
# TCGTACCTCCGGGTGT-2  1.771520  1.760878  1.504371  1.634852  1.815990  ...
# CGATCGGTCATCTGTT-1  1.644066  1.644066  1.389917  1.605485  1.644066  ...
# AACTCTTAGCCACCTG-3  1.679675  1.686362  1.339627  1.514875  1.649562  ...
# GGATTACTCCAGTAGT-2  1.431013  1.332558  0.917362  1.365561  1.306495  ...
#
#                        COPZ1     ARPC4     NOP10    UBE2D2    NDUFA1  \
# CTCCTAGTCTGGCGTG-2  0.000000  0.842998  0.000000  0.000000  1.161456
# GACCTGGAGTAATCCC-3  0.000000  0.000000  0.000000  1.039355  0.000000
# ATCTGCCAGTGTCCAT-3  0.000000  0.000000  0.897057  0.000000  0.000000
# GTCCTCAAGTGCCATT-2  1.053973  0.849874  0.849874  0.849874  1.053973
# CTGCCTATCGACGGAA-2  0.000000  0.982330  0.000000  0.982330  0.982330
# ...                      ...       ...       ...       ...       ...
# CCCAGTTGTTGCCTCT-1  0.000000  1.110478  0.907109  0.000000  1.110478
# TCGTACCTCCGGGTGT-2  0.000000  0.000000  1.063754  0.000000  0.000000
# CGATCGGTCATCTGTT-1  1.389917  1.199988  1.199988  1.199988  1.389917
# AACTCTTAGCCACCTG-3  0.000000  0.000000  0.897775  0.000000  0.000000
# GGATTACTCCAGTAGT-2  0.000000  0.606950  0.994252  0.606950  0.000000
#
#                         EDF1    ATP5C1  C12orf57      ISCU     COX8A
# CTCCTAGTCTGGCGTG-2  1.161456  1.161456  0.000000  1.049278  1.049278
# GACCTGGAGTAATCCC-3  1.039355  0.000000  0.000000  1.039355  1.237123
# ATCTGCCAGTGTCCAT-3  0.897057  0.897057  0.000000  1.114027  0.000000
# GTCCTCAAGTGCCATT-2  1.053973  0.000000  0.000000  1.053973  1.164785
# CTGCCTATCGACGGAA-2  0.982330  0.000000  0.000000  0.000000  0.000000
# ...                      ...       ...       ...       ...       ...
# CCCAGTTGTTGCCTCT-1  0.907109  0.000000  0.000000  0.000000  0.907109
# TCGTACCTCCGGGTGT-2  1.063754  0.000000  0.000000  0.000000  0.000000
# CGATCGGTCATCTGTT-1  0.000000  1.199988  1.389917  1.199988  0.000000
# AACTCTTAGCCACCTG-3  0.897775  0.000000  0.897775  0.897775  0.897775
# GGATTACTCCAGTAGT-2  0.804703  0.804703  0.000000  0.804703  0.804703
#
# [1803 rows x 627 columns]

# %%
adata.obs
# Out:
#                     orig.ident   nCount_RNA  nFeature_RNA    UMAP_1    UMAP_2  \
# CTCCTAGTCTGGCGTG-2           0  2409.541365          1405  2.992545  3.168246
# GACCTGGAGTAATCCC-3           0  2226.756313          1101  3.686147 -1.859115
# ATCTGCCAGTGTCCAT-3           0  1857.854626          1074 -3.040782  0.519949
# GTCCTCAAGTGCCATT-2           0  2440.234683          1427  1.320840  5.552480
# CTGCCTATCGACGGAA-2           0  1913.285794           970 -4.121430 -1.908579
# ...                        ...          ...           ...       ...       ...
# CCCAGTTGTTGCCTCT-1           0  2472.163358          1366  3.413327  5.009843
# TCGTACCTCCGGGTGT-2           0  1691.378687           819 -6.709521 -1.649546
# CGATCGGTCATCTGTT-1           0  1859.160207           795  3.785981  0.446794
# AACTCTTAGCCACCTG-3           0  2109.047983          1141  1.876789 -0.730666
# GGATTACTCCAGTAGT-2           0  2905.413294          2082  2.242367  6.717527
#
#                    Celltype..malignancy. Celltype..major.lineage.  \
# CTCCTAGTCTGGCGTG-2          Immune cells                 CD4Tconv
# GACCTGGAGTAATCCC-3          Immune cells                 CD4Tconv
# ATCTGCCAGTGTCCAT-3          Immune cells                 CD4Tconv
# GTCCTCAAGTGCCATT-2          Immune cells                 CD4Tconv
# CTGCCTATCGACGGAA-2          Immune cells                 CD4Tconv
# ...                                  ...                      ...
# CCCAGTTGTTGCCTCT-1          Immune cells                 CD4Tconv
# TCGTACCTCCGGGTGT-2          Immune cells                 CD4Tconv
# CGATCGGTCATCTGTT-1          Immune cells                 CD4Tconv
# AACTCTTAGCCACCTG-3          Immune cells                 CD4Tconv
# GGATTACTCCAGTAGT-2          Immune cells                 CD4Tconv
#
#                    Celltype..minor.lineage.  Cluster Patient Source  Gender  \
# CTCCTAGTCTGGCGTG-2                      Tfh       10    BRCA  Tumor  Female
# GACCTGGAGTAATCCC-3                     Th17        6    BRCA  Tumor  Female
# ATCTGCCAGTGTCCAT-3                    CD4Tn        0    BRCA  Tumor  Female
# GTCCTCAAGTGCCATT-2                      Tfh        5    BRCA  Tumor  Female
# CTGCCTATCGACGGAA-2                    CD4Tn        0    BRCA  Tumor  Female
# ...                                     ...      ...     ...    ...     ...
# CCCAGTTGTTGCCTCT-1                      Tfh        5    BRCA  Tumor  Female
# TCGTACCTCCGGGTGT-2                      Th2        7    BRCA  Tumor  Female
# CGATCGGTCATCTGTT-1                     Th17        6    BRCA  Tumor  Female
# AACTCTTAGCCACCTG-3                     Th17        6    BRCA  Tumor  Female
# GGATTACTCCAGTAGT-2                      Tfh        5    BRCA  Tumor  Female
#
#                       Stage  n_genes
# CTCCTAGTCTGGCGTG-2  Primary      306
# GACCTGGAGTAATCCC-3  Primary      263
# ATCTGCCAGTGTCCAT-3  Primary      244
# GTCCTCAAGTGCCATT-2  Primary      325
# CTGCCTATCGACGGAA-2  Primary      241
# ...                     ...      ...
# CCCAGTTGTTGCCTCT-1  Primary      301
# TCGTACCTCCGGGTGT-2  Primary      219
# CGATCGGTCATCTGTT-1  Primary      223
# AACTCTTAGCCACCTG-3  Primary      278
# GGATTACTCCAGTAGT-2  Primary      418
#
# [1803 rows x 14 columns]

# %%
resolution = 5
n_pca = 10
preprocessing_cluster(adata,N_pcs=n_pca,resolution=resolution)

inter_gene = sort_data(adata,adata)

tmp1 = calculate_cluster_centroid_for_genes(adata,inter_gene,folder_path1)
meta_list1 = calculate_cluster_celltype(adata,meta_col='Celltype..minor.lineage.');
tmp1.shape
# Out:
# (37, 10)

# %%
adata.obs['Celltype..minor.lineage.'].describe()
# Out:
# count     1803
# unique       4
# top        Tfh
# freq       799
# Name: Celltype..minor.lineage., dtype: object

# %%
len(meta_list1)
# Out:
# 80

# %%
tmp1.shape
# Out:
# (80, 10)

# %%
data_path = folder_path1 + 'datas.data'

# %%
np.random.seed(1234)
torch.manual_seed(1234)
x, y_true, similarities = load_data(data_path,1,tmp1.shape[1]+1,0)
print("{} length:{}".format(data_path,len(y_true)));
dataset = HCDataset(x, y_true, similarities, num_samples=50000)
dataloader = data.DataLoader(dataset, batch_size=32, shuffle=True, pin_memory=True)
model = HypHC(dataset.n_nodes, 2, 5e-2, 5e-2 ,0.999)

# model.to("cpu")
Optimizer = getattr(optim, 'RAdam')
optimizer = Optimizer(model.parameters(),0.0005)
train(model,dataloader,optimizer,similarities,30);
# Out:
# ./datas/320/datas.data length:37
# Generating all pairs superset
# 	 Epoch 0 | average train loss: 0.945043
# Optimization finished.
# 	 Epoch 1 | average train loss: 0.927333
# Optimization finished.
# 	 Epoch 2 | average train loss: 0.920946
# Optimization finished.
# 	 Epoch 3 | average train loss: 0.919639
# Optimization finished.
# 	 Epoch 4 | average train loss: 0.919899
# Optimization finished.
# 	 Epoch 5 | average train loss: 0.916583
# Optimization finished.
# 	 Epoch 6 | average train loss: 0.915098
# Optimization finished.
# 	 Epoch 7 | average train loss: 0.914727
# Optimization finished.
# 	 Epoch 8 | average train loss: 0.914730
# Optimization finished.
# 	 Epoch 9 | average train loss: 0.914526
# Optimization finished.
# 	 Epoch 10 | average train loss: 0.915057
# Optimization finished.
# 	 Epoch 11 | average train loss: 0.914613
# Optimization finished.
# 	 Epoch 12 | average train loss: 0.914959
# Optimization finished.
# 	 Epoch 13 | average train loss: 0.914715
# Optimization finished.
# 	 Epoch 14 | average train loss: 0.915077
# Optimization finished.
# 	 Epoch 15 | average train loss: 0.914581
# Optimization finished.
# 	 Epoch 16 | average train loss: 0.914761
# Optimization finished.
# 	 Epoch 17 | average train loss: 0.914704
# Optimization finished.
# 	 Epoch 18 | average train loss: 0.915228
# Optimization finished.
# 	 Epoch 19 | average train loss: 0.914568
# Optimization finished.
# 	 Epoch 20 | average train loss: 0.915054
# Optimization finished.
# 	 Epoch 21 | average train loss: 0.914739
# Optimization finished.
# 	 Epoch 22 | average train loss: 0.914634
# Optimization finished.
# 	 Epoch 23 | average train loss: 0.914734
# Optimization finished.
# 	 Epoch 24 | average train loss: 0.914886
# Optimization finished.
# 	 Epoch 25 | average train loss: 0.914833
# Optimization finished.
# 	 Epoch 26 | average train loss: 0.914868
# early stopping.

# %%
torch.save(model.state_dict(),folder_path1+'model3.pth');

# %%
params = torch.load((folder_path1+'model4.pth'), map_location=torch.device('cpu'))
model = HypHC(len(tmp1), 2, 5e-2, 5e-2 ,0.999)
model
# Out:
# HypHC(
#   (embeddings): Embedding(80, 2)
# )

# %%
model.eval()

sim_fn = lambda x, y: torch.sum(x * y, dim=-1)
n=len(x);
leaves_embeddings = model.normalize_embeddings(model.embeddings.weight.data)
leaves_embeddings = project(leaves_embeddings).detach().cpu()
ijs = sl_np_mst_ij(leaves_embeddings,sim_fn)
uf = UnionFind(n)
uf.merge(ijs)

tree = nx.DiGraph()
for i, j in enumerate(uf.tree()[:-1]):
    if(j!=-1):
        tree.add_edge(j, i)

n = len(leaves_embeddings)
embeddings = complete_tree(tree, leaves_embeddings)
# Out:
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/utils/mst.py:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ij = np.empty((n - 1, 2), dtype=np.int)
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/utils/mst.py:10: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   merged = np.zeros(n, dtype=np.int)
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/utils/mst.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   j = np.empty(n, dtype=np.int)

# %%
colors = get_colors(meta_list1, 1234)
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
circle = plt.Circle((0, 0), 1.0, color='r', alpha=0.1)
ax.add_artist(circle)
ax.scatter(embeddings[:n, 0], embeddings[:n, 1], c=colors, s=50, alpha=0.6)
# ax.scatter(embeddings[n:,0],embeddings[n:,1],color ='black',s=20,alpha=0.6)
for n1, n2 in tree.edges():
    x1 = embeddings[n1];
    x2 = embeddings[n2]
    plot_geodesic(x1,x2,ax)

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i in range(n):
    nodes1[i].subson=[i];
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=torch.tensor(embeddings[i]);
    nodes1[i].hyper=torch.tensor(embeddings[i])
root = nodes1[-1];

# %%
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# {'empty': '#fff', 'CD4Tn': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'Th17': '#52b69a'}

# %%
def rotate(nodes,embeddings,epoches2,n,similarities):
    deep_search_tree(root,0,[],root)
    result1 = []
    result2 = []

    distances = []
    for i in nodes:
        if(int(i)>=n):
            if(int(i.son[0]) <n and int(i.son[1])<n ):
                for i1,j1 in itertools.combinations(i.subson,2):
                    for j in i.rest(n):
                        result1.append([[i1,j1],j,int(i),1,int(j)])
                    
    for i in nodes[:-1]:
        if(int(i)>=n and len(i.son)>=2):
            for i1 in range(len(i.subson)):
                for i2 in range(i1+1,len(i.subson)):
                    for j in i.rest(n):
                        result2.append([[i.subson[i1],i.subson[i2]],j,int(i),0,int(i.f)])
            
    for i in nodes:
        distances.append(i.distance_to_root);
    distances = torch.tensor(distances)
    dataset_test1 = balance_dataset(similarities,len(result1),embeddings,distances,result1)
    dataloader1 = data.DataLoader(dataset_test1, batch_size=1, shuffle=True, pin_memory=True)
    
    dataset_test2 = balance_dataset(similarities,10000,embeddings,distances,result2)
    dataloader2 = data.DataLoader(dataset_test2, batch_size=1, shuffle=True, pin_memory=True)    
    
    model2 = balancehc(nodes1,torch.tensor(embeddings),hyperparamter = 1)
    
    Optimizer = getattr(optim, 'RAdam')
    optimizer = Optimizer(model2.parameters(),0.0005)
    train2(model2,dataloader1,dataloader2,optimizer,epoches2)
    temp = model2.embeddings.weight.data
    return temp

# %%
temp = rotate(nodes1,embeddings,10,n,similarities)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
root = nodes1[-1]
# Out:
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/datasets/balance_dataset.py:54: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:22: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 0 | average train loss1: 0.493268
# 	 Epoch 0 | average train loss2: 0.455292
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:46: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 1 | average train loss1: 0.506174
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:71: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:92: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 1 | average train loss2: 0.455156
# 	 Epoch 2 | average train loss1: 0.504825
# 	 Epoch 2 | average train loss2: 0.454895
# 	 Epoch 3 | average train loss1: 0.507705
# 	 Epoch 3 | average train loss2: 0.455216
# 	 Epoch 4 | average train loss1: 0.507692
# 	 Epoch 4 | average train loss2: 0.455521
# 	 Epoch 5 | average train loss1: 0.506697
# 	 Epoch 5 | average train loss2: 0.455166
# 	 Epoch 6 | average train loss1: 0.508306
# 	 Epoch 6 | average train loss2: 0.454789
# 	 Epoch 7 | average train loss1: 0.507003
# 	 Epoch 7 | average train loss2: 0.454932
# 	 Epoch 8 | average train loss1: 0.502890
# 	 Epoch 8 | average train loss2: 0.454795
# 	 Epoch 9 | average train loss1: 0.501293
# 	 Epoch 9 | average train loss2: 0.454349

# %%
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# {'empty': '#fff', 'CD4Tn': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'Th17': '#52b69a'}

# %%
root.hyper
# Out:
# tensor([-0.0017,  0.0018], dtype=torch.float64)

# %%
def find_distances(now,distances):
    if(len(now.son)<=1):
        return 
    for son in now.son:
        dis = hyp_dist(son.hyper,now.hyper).numpy()
        distances.append(dis)
        find_distances(son,distances);
ans=[]
find_distances(root,ans)
ans =np.array(ans)
percentile_25 = np.percentile(ans, 25)
percentile_75 = np.percentile(ans, 75)

percentile_25,percentile_75

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,5,percentile_25,percentile_75,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 41 5
# 50 14
# 43 21
# 39 15
# 38 24
# 42 20
# 37 2
# 48 29
# 47 8
# False
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/datasets/balance_dataset.py:54: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:22: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 0 | average train loss1: 0.494031
# 	 Epoch 0 | average train loss2: 0.485377
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:46: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 1 | average train loss1: 0.507200
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:71: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:92: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 1 | average train loss2: 0.485565
# 	 Epoch 2 | average train loss1: 0.507873
# 	 Epoch 2 | average train loss2: 0.488149
# 	 Epoch 3 | average train loss1: 0.504228
# 	 Epoch 3 | average train loss2: 0.484646
# 	 Epoch 4 | average train loss1: 0.506019
# 	 Epoch 4 | average train loss2: 0.485116
# {'empty': '#fff', 'CD4Tn': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'Th17': '#52b69a'}

# %%
def find_distances(now,distances):
    if(len(now.son)<=1):
        return 
    for son in now.son:
        dis = hyp_dist(son.hyper,now.hyper).numpy()
        distances.append(dis)
        find_distances(son,distances);
ans=[]
find_distances(root,ans)
ans =np.array(ans)
percentile_25 = np.percentile(ans, 25)
percentile_5 = np.percentile(ans, 50)

percentile_25,percentile_5
# Out:
# (1.1321417584988485, 1.3910132840566192)

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,5,percentile_25,percentile_5,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 44 6
# 45 15
# 40 25
# False
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/datasets/balance_dataset.py:54: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:22: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 0 | average train loss1: 0.491942
# 	 Epoch 0 | average train loss2: 0.485771
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:46: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 1 | average train loss1: 0.513323
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:71: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:92: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 	 Epoch 1 | average train loss2: 0.482785
# 	 Epoch 2 | average train loss1: 0.505419
# 	 Epoch 2 | average train loss2: 0.483716
# 	 Epoch 3 | average train loss1: 0.503896
# 	 Epoch 3 | average train loss2: 0.484765
# 	 Epoch 4 | average train loss1: 0.515379
# 	 Epoch 4 | average train loss2: 0.483249
# {'empty': '#fff', 'CD4Tn': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'Th17': '#52b69a'}

# %%
hyp_dist(nodes1[24].hyper,nodes1[61].hyper)
# Out:
# tensor([1.2698], dtype=torch.float64)

# %%
hyp_dist(nodes1[10].hyper,nodes1[61].hyper)
# Out:
# tensor([1.1039], dtype=torch.float64)

# %%
hyp_dist(nodes1[10].hyper,nodes1[24].hyper)
# Out:
# tensor([1.6157], dtype=torch.float64)

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,5,percentile_25,percentile_5,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 49 21
# 46 4
# 54 3
# False
# 	 Epoch 0 | average train loss1: 0.491394
# 	 Epoch 0 | average train loss2: 0.483972
# 	 Epoch 1 | average train loss1: 0.508127
# 	 Epoch 1 | average train loss2: 0.482337
# 	 Epoch 2 | average train loss1: 0.507021
# 	 Epoch 2 | average train loss2: 0.484586
# 	 Epoch 3 | average train loss1: 0.505048
# 	 Epoch 3 | average train loss2: 0.491244
# 	 Epoch 4 | average train loss1: 0.504809
# 	 Epoch 4 | average train loss2: 0.488919
# {'empty': '#fff', 'CD4Tn': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'Th17': '#52b69a'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,5,percentile_25,percentile_5,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 57 8
# False
# 	 Epoch 0 | average train loss1: 0.492093
# 	 Epoch 0 | average train loss2: 0.485328
# 	 Epoch 1 | average train loss1: 0.506967
# 	 Epoch 1 | average train loss2: 0.482523
# 	 Epoch 2 | average train loss1: 0.505072
# 	 Epoch 2 | average train loss2: 0.483681
# 	 Epoch 3 | average train loss1: 0.510186
# 	 Epoch 3 | average train loss2: 0.484231
# 	 Epoch 4 | average train loss1: 0.501369
# 	 Epoch 4 | average train loss2: 0.484233
# {'empty': '#fff', 'CD4Tn': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'Th17': '#52b69a'}

# %%
def merge_points(similarities,root,nodes,embeddings,epoches,c1,c2,n):
    root,_ = search_tree(root,c1,c2,n)
    if(_ == True):
        return embeddings,root
    nodes_merge = [];
    add_meta(root,[],nodes_merge)
    for i in nodes_merge:
        if(int(i)<n):
            i.subson = [int(i)]
        else:
            i.subson=[]
        result1 = []
    result2 = []

    distances = []
    for i in nodes:
        if(int(i)>=n):
            if(int(i.son[0]) <n and int(i.son[1])<n ):
                for i1,j1 in itertools.combinations(i.subson,2):
                    for j in i.rest(n):
                        result1.append([[i1,j1],j,int(i),1,int(j)])
                    
    for i in nodes[:-1]:
        if(int(i)>=n and len(i.son)>=2):
            for i1 in range(len(i.subson)):
                for i2 in range(i1+1,len(i.subson)):
                    for j in i.rest(n):
                        result2.append([[i.subson[i1],i.subson[i2]],j,int(i),0,int(i.f)])
            
    for i in nodes:
        distances.append(i.distance_to_root);
    distances = torch.tensor(distances)
    dataset_test1 = balance_dataset(similarities,len(result1),embeddings,distances,result1)
    dataloader1 = data.DataLoader(dataset_test1, batch_size=1, shuffle=True, pin_memory=True)
    
    dataset_test2 = balance_dataset(similarities,5000,embeddings,distances,result2)
    dataloader2 = data.DataLoader(dataset_test2, batch_size=1, shuffle=True, pin_memory=True)    
    
    model2 = balancehc(nodes1,torch.tensor(embeddings),hyperparamter = 1)
    
    Optimizer = getattr(optim, 'RAdam')
    optimizer = Optimizer(model2.parameters(),0.0005)
    train2(model2,dataloader1,dataloader2,optimizer,epoches)
    temp = model2.embeddings.weight.data
    return temp,nodes_merge[0]

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,10,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 144 61
# 120 4
# 125 56
# 117 53
# 133 79
# 118 2
# 123 48
# 137 25
# 127 63
# 135 9
# 146 70
# 124 64
# 130 40
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,10,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 132 4
# 150 39
# 140 25
# 154 40
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,11,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 156 4
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,11,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 158 4
# False
# {'CD4Tn': '#184e77', 'Tfh': '#1a759f', 'Th2': '#168aad', 'Th17': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,1,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 112 56
# 101 18
# 115 47
# 107 60
# 104 21
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
embeddings
# Out:
# array([[ 0.5394955228, -0.4836163598],
#        [-0.3963078733, -0.6064502006],
#        [ 0.5034241345, -0.5152922438],
#        [-0.7187210852, -0.0584935101],
#        [-0.3604043424, -0.6288076639],
#        [-0.0355067865, -0.7154793093],
#        [ 0.6625706553,  0.2937524617],
#        [ 0.5415572524, -0.4816701114],
#        [ 0.5676193635, -0.4465909742],
#        [ 0.5150767565,  0.5098884702],
#        [-0.5469122529, -0.4755810797],
#        [ 0.5368868885, -0.4854316466],
#        [-0.649928424 ,  0.3309901572],
#        [-0.6524631977,  0.3155663908],
#        [ 0.2041319939,  0.6912052226],
#        [ 0.6606987903, -0.2952002591],
#        [-0.491638386 ,  0.5193089025],
#        [ 0.5890838023,  0.4110527547],
#        [-0.043205034 , -0.7234803438],
#        [ 0.5873692928,  0.4101834414],
#        [ 0.2002224075, -0.6935958477],
#        [-0.5011567946,  0.5206645237],
#        [-0.4151184602,  0.5887882943],
#        [ 0.4318082703,  0.5754370808],
#        [-0.7165454894, -0.074186785 ],
#        [ 0.452007503 ,  0.5591310007],
#        [ 0.383449465 ,  0.6150259376],
#        [-0.5128340776,  0.4983779261],
#        [ 0.2244217035,  0.6850474712],
#        [ 0.7113984738, -0.133756039 ],
#        [-0.7245702744, -0.0169798713],
#        [ 0.3298529088, -0.6453583837],
#        [-0.6490874287,  0.3279306932],
#        [ 0.6070136428,  0.3960110843],
#        [-0.4810253401, -0.5361711395],
#        [ 0.5112296865, -0.5102340569],
#        [-0.1062422693, -0.7169399858],
#        [-0.4442795217, -0.5726308823],
#        [-0.2566086948,  0.6778217554],
#        [ 0.6768009663, -0.2592889667],
#        [-0.5153741241,  0.5095879436],
#        [ 0.6092423799, -0.3860631564],
#        [-0.1811905851, -0.6998007621],
#        [-0.4903490695, -0.5277721651],
#        [ 0.21012361  , -0.6905918615],
#        [-0.1839613994, -0.6966836671],
#        [-0.0561775389, -0.7204516483],
#        [ 0.5566266179, -0.4641735256],
#        [ 0.5983596619, -0.4016113723],
#        [-0.3797365538, -0.6079740674],
#        [ 0.3101133108,  0.6550726295],
#        [-0.5744409561, -0.4419366717],
#        [-0.084035973 , -0.7179190043],
#        [-0.0783561835, -0.7093817896],
#        [ 0.5608729709, -0.4517835889],
#        [ 0.5537598208,  0.4672636494],
#        [-0.5334769487, -0.4906044304],
#        [-0.0555467456, -0.7151091087],
#        [-0.6822582478,  0.2378385292],
#        [-0.5644850968,  0.4448624226],
#        [-0.6520627709,  0.2937871215],
#        [ 0.113800101 , -0.7157791853],
#        [-0.520556208 , -0.4994575132],
#        [ 0.6299712658,  0.3583665192],
#        [-0.6264534593,  0.3644810319],
#        [-0.4370821448,  0.5740125163],
#        [-0.6601949761,  0.2920196502],
#        [-0.5192830775,  0.5035604171],
#        [-0.5172114798, -0.4991123255],
#        [ 0.7171872816, -0.0581789681],
#        [-0.704636991 , -0.1696380079],
#        [ 0.051818978 ,  0.7229143381],
#        [ 0.6534009666, -0.3013377047],
#        [ 0.5526487792,  0.4653207871],
#        [-0.5607898038,  0.4554909695],
#        [-0.0357771477, -0.7159060172],
#        [ 0.7131947279,  0.1290100515],
#        [-0.6767198346,  0.2453691093],
#        [ 0.6358098388, -0.3479025364],
#        [-0.2389086187, -0.6842609048],
#        [-0.6444812406,  0.3271731274],
#        [-0.5224694137, -0.5023107502],
#        [-0.0341967111, -0.7174645149],
#        [-0.1753607039, -0.706342333 ],
#        [ 0.5417851772,  0.4580130438],
#        [ 0.5949131891,  0.4139603477],
#        [-0.0563424863, -0.7225714464],
#        [-0.5203622201,  0.5121663525],
#        [-0.0842715748, -0.7198406956],
#        [ 0.5362335308, -0.487568439 ],
#        [ 0.5374091077, -0.4862488103],
#        [ 0.5694070576, -0.4483670065],
#        [-0.5031643909,  0.5262784538],
#        [-0.6734510703,  0.2478927438],
#        [-0.6535485772,  0.2938135029],
#        [ 0.6706536899, -0.295793121 ],
#        [ 0.5262867012, -0.5125331291],
#        [-0.0511948103, -0.7173538903],
#        [-0.5228345495,  0.4926295517],
#        [ 0.2106442094, -0.6886148457],
#        [-0.56338872  ,  0.4558290203],
#        [-0.0500952414, -0.7262665532],
#        [-0.3956359291, -0.6155952434],
#        [-0.6399960966,  0.3139057492],
#        [-0.5112513268,  0.5138162444],
#        [-0.479333861 , -0.5379298891],
#        [-0.5258765603, -0.4910013305],
#        [-0.6544307238,  0.3040417523],
#        [-0.7220472419, -0.0609112476],
#        [ 0.5511868395, -0.4502106461],
#        [ 0.6101293348, -0.3908252069],
#        [-0.0951067049, -0.7182212923],
#        [-0.537687209 , -0.485242105 ],
#        [ 0.2096441931,  0.6935496628],
#        [ 0.5983634288,  0.4062644281],
#        [ 0.5492345401, -0.4724833419],
#        [-0.4242062286,  0.5832622213],
#        [-0.0751596075, -0.7200586149],
#        [ 0.5254088767, -0.4944161258],
#        [ 0.4510583563,  0.5598325525],
#        [-0.3887973341, -0.6052380506],
#        [-0.7220923128, -0.0323323676],
#        [ 0.6712674346, -0.2707834195],
#        [ 0.6171800923, -0.3750149491],
#        [-0.6369761835,  0.3336434823],
#        [-0.4981578583, -0.5139029514],
#        [-0.5369514859, -0.4647996765],
#        [ 0.6139577188,  0.3764591311],
#        [-0.6498378203,  0.289897143 ],
#        [-0.4776800046, -0.5208759461],
#        [-0.5337957333,  0.4810770475],
#        [ 0.6359960674, -0.316121175 ],
#        [-0.431911041 , -0.5428609261],
#        [-0.2195526978, -0.6873948929],
#        [ 0.5671927345, -0.4148072443],
#        [ 0.5397000391,  0.491807057 ],
#        [ 0.569150621 ,  0.4362132975],
#        [ 0.4224131901,  0.5948957888],
#        [ 0.7118005596, -0.084656857 ],
#        [ 0.5911233947,  0.3529018002],
#        [ 0.4770952203,  0.4766469509],
#        [-0.1567057031, -0.7009528418],
#        [ 0.406971617 ,  0.4936276517],
#        [-0.470437532 ,  0.5275768486],
#        [ 0.142071245 , -0.7143494082],
#        [ 0.3309046985,  0.5207061985],
#        [-0.7088652917, -0.1106144477],
#        [-0.5286266415,  0.4277911927],
#        [ 0.2235528424, -0.6666672337],
#        [-0.2526585962, -0.6076091427],
#        [ 0.6068172646, -0.2462191042],
#        [-0.1090392766, -0.5836287852],
#        [ 0.2194668022,  0.5574438284],
#        [ 0.4029220685,  0.2997660662],
#        [-0.4077679423,  0.4811373007],
#        [ 0.4195041074,  0.126109023 ],
#        [ 0.1682565949, -0.1593903678],
#        [-0.4581502586,  0.207405489 ],
#        [-0.0152804511, -0.0283853254]])

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,1,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 117 52
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/datasets/balance_dataset.py:54: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /Users/dongjiajie/Desktop/alignment/fyp/hyperalignment/final/model/balancehc.py:22: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 144 61
# 125 34
# 141 52
# 118 35
# 131 39
# 138 69
# 137 26
# 127 63
# 135 73
# 146 70
# 124 64
# 130 74
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 148 31
# 126 51
# 134 35
# 136 73
# 128 77
# 143 22
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 129 37
# 150 69
# 139 6
# 147 22
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 132 37
# 140 26
# 154 22
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 149 37
# 142 26
# 157 22
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 151 37
# 145 26
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
temp,root = merge_points(similarities,root,nodes1,embeddings,0,3,100,n)
for i in nodes1:
    i.hyper = temp[int(i)]
    i.value =  temp[int(i)]
embeddings = temp.numpy();
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# 153 26
# False
# {'CD4Tn': '#184e77', 'Th17': '#1a759f', 'Th2': '#168aad', 'Tfh': '#34a0a4', 'empty': '#fff'}

# %%
colors = get_colors(meta_list1, 1234)
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
circle = plt.Circle((0, 0), 1.0, color='r', alpha=0.1)
ax.add_artist(circle)
ax.scatter(embeddings[:n, 0], embeddings[:n, 1], c=colors, s=50, alpha=0.6)
# ax.scatter(embeddings[n:,0],embeddings[n:,1],color ='black',s=20,alpha=0.6)
for n1, n2 in tree.edges():
    x1 = embeddings[n1];
    x2 = embeddings[n2]
    plot_geodesic(x1,x2,ax)

# %%
nodes1 = [node(name=str(i),son=[]) for i in range(len(uf.tree()))]
for i in range(n):
    nodes1[i].subson=[i];
for i,j in enumerate(uf.tree()):
    if(j!=-1):
        nodes1[j].son.append(nodes1[i])
    nodes1[i].value=torch.tensor(embeddings[i]);
    nodes1[i].hyper=torch.tensor(embeddings[i])
root = nodes1[-1];

# %%
add_meta(root,meta_list1,[])
show_tree(root,color=['#184e77','#1a759f','#168aad',"#34a0a4",'#52b69a','#99d98c','#76c893','#99d98c']).show_fig()
remove_meta(root);
# Out:
# {'Th2': '#184e77', 'Tfh': '#1a759f', 'empty': '#fff', 'Th17': '#34a0a4', 'CD4Tn': '#52b69a'}

# %%
subset = np.random.choice(np.arange(len(temp)), 5, replace=False)
temp = temp[subset]
temp
# Out:
# array([[0.1174433897, 0.3937823523],
#        [0.4353322526, 0.5694786566],
#        [0.6892356429, 0.9295459365],
#        [0.8135289285, 0.6465523236],
#        [0.4527298093, 0.5381478353]])

# %%
temp = np.random.random((10,2))
temp
# Out:
# array([[0.1174433897, 0.3937823523],
#        [0.4527298093, 0.5381478353],
#        [0.7906221026, 0.4658363429],
#        [0.4353322526, 0.5694786566],
#        [0.9692589998, 0.0405561488],
#        [0.5481195726, 0.4625766032],
#        [0.3764722289, 0.3279120842],
#        [0.8135289285, 0.6465523236],
#        [0.0474264775, 0.9949575676],
#        [0.6892356429, 0.9295459365]])
